# %% [markdown]
# ## metrics analysis using Braket

# %% [markdown]
# | Algorithm                       |     Simulator                  | Min Qubits | Max Qubits |                      Benchmark Results                             |                       Volumetric Positioning                          |
# |---------------------------------|--------------------------------|------------|------------|--------------------------------------------------------------------|-----------------------------------------------------------------------|
# |  **Deutsch-Jozsa**              | StateVectorSimulator (without noise) | 2          |     30     | ![image.png](attachment:78b1ddb1-782a-4383-ae74-c0466548e5e2.png) | |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# | **Bernstein-Vazirani-Algorithm**| StateVectorSimulator (without noise) | 2          |     30     | ![image.png](attachment:a399e9e5-38ff-488a-ae17-8f59052826a7.png) |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# |  **Hidden-Shift**               | StateVectorSimulator (without noise) | 2          |     28     | ![image.png](attachment:e22b4e2c-ee71-47cf-8870-fefa89f7c865.png) |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# | **Quantum-Fourier-Transform**   | StateVectorSimulator (without noise) | 2          |     29     | ![image.png](attachment:ea4c493c-bf2c-4eba-9d16-c126b1206fb2.png) |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# |  **Hamiltonian Simulation**     | StateVectorSimulator (without noise) | 2          |     30     | ![image.png](attachment:e502d383-c46e-4341-b8d5-3a3ce541a365.png) |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# |  **Phase Estimation**            | StateVectorSimulator (without noise) | 2          |     28     |  |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
# |  **Grover's Search**            | StateVectorSimulator (without noise) | 2          |     30     |  |  |
# |                                 | StateVectorSimulator (with noise)    | 2          |     30     |  |  |
# |                                 |                            |            |            |     |   |
# |                                 |                            |            |            |     |   |
