# %%
"""
Quantum Fourier Transform Benchmark Program - Qiskit
"""

import math
import sys
import time

import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

sys.path[1:1] = [ "_common", "_common/qiskit" ]
sys.path[1:1] = [ "../../_common", "../../_common/qiskit" ]
import execute as ex
import metrics as metrics

# Benchmark Name
benchmark_name = "Quantum Fourier Transform"

np.random.seed(0)

verbose = False

# saved circuits for display
num_gates = 0
depth = 0
QC_ = None
QFT_ = None
QFTI_ = None

# %%
############### Circuit Definition

def QuantumFourierTransform (num_qubits, secret_int, method=1):
    global num_gates, depth
    # Size of input is one less than available qubits
    input_size = num_qubits
    num_gates = 0
    depth = 0
    
    # allocate qubits
    qr = QuantumRegister(num_qubits); cr = ClassicalRegister(num_qubits)
    qc = QuantumCircuit(qr, cr, name=f"qft({method})-{num_qubits}-{secret_int}")

    if method==1:

        # Perform X on each qubit that matches a bit in secret string
        s = ('{0:0'+str(input_size)+'b}').format(secret_int)
        for i_qubit in range(input_size):
            if s[input_size-1-i_qubit]=='1':
                qc.x(qr[i_qubit])
                num_gates += 1

        depth += 1

        qc.barrier()

        # perform QFT on the input
        qc.append(qft_gate(input_size).to_instruction(), qr)

        # End with Hadamard on all qubits (to measure the z rotations)
        ''' don't do this unless NOT doing the inverse afterwards
        for i_qubit in range(input_size):
             qc.h(qr[i_qubit])

        qc.barrier()
        '''

        qc.barrier()
        
        # some compilers recognize the QFT and IQFT in series and collapse them to identity;
        # perform a set of rotations to add one to the secret_int to avoid this collapse
        for i_q in range(0, num_qubits):
            divisor = 2 ** (i_q)
            qc.rz( 1 * math.pi / divisor , qr[i_q])
            num_gates+=1
        
        qc.barrier()

        # to revert back to initial state, apply inverse QFT
        qc.append(inv_qft_gate(input_size).to_instruction(), qr)

        qc.barrier()

    elif method == 2:

        for i_q in range(0, num_qubits):
            qc.h(qr[i_q])
            num_gates += 1

        for i_q in range(0, num_qubits):
            divisor = 2 ** (i_q)
            qc.rz(secret_int * math.pi / divisor, qr[i_q])
            num_gates += 1

        depth += 1

        qc.append(inv_qft_gate(input_size).to_instruction(), qr)

    # This method is a work in progress
    elif method==3:

        for i_q in range(0, secret_int):
            qc.h(qr[i_q])
            num_gates+=1

        for i_q in range(secret_int, num_qubits):
            qc.x(qr[i_q])
            num_gates+=1
            
        depth += 1
        
        qc.append(inv_qft_gate(input_size).to_instruction(), qr)
        
    else:
        exit("Invalid QFT method")

    # measure all qubits
    qc.measure(qr, cr)
    num_gates += num_qubits
    depth += 1

    # save smaller circuit example for display
    global QC_    
    if QC_ == None or num_qubits <= 5:
        if num_qubits < 9: QC_ = qc
        
    # return a handle on the circuit
    return qc

# %%
############### QFT Circuit

def qft_gate(input_size):
    global QFT_, num_gates, depth
    qr = QuantumRegister(input_size); qc = QuantumCircuit(qr, name="qft")
    
    # Generate multiple groups of diminishing angle CRZs and H gate
    for i_qubit in range(0, input_size):
    
        # start laying out gates from highest order qubit (the hidx)
        hidx = input_size - i_qubit - 1
        
        # if not the highest order qubit, add multiple controlled RZs of decreasing angle
        if hidx < input_size - 1:   
            num_crzs = i_qubit
            for j in range(0, num_crzs):
                divisor = 2 ** (num_crzs - j)
                qc.crz( math.pi / divisor , qr[hidx], qr[input_size - j - 1])
                num_gates += 1
                depth += 1
            
        # followed by an H gate (applied to all qubits)
        qc.h(qr[hidx])
        num_gates += 1
        depth += 1
        
        qc.barrier()
    
    if QFT_ == None or input_size <= 5:
        if input_size < 9: QFT_ = qc
        
    return qc

# %%
############### Inverse QFT Circuit

def inv_qft_gate(input_size):
    global QFTI_, num_gates, depth
    qr = QuantumRegister(input_size); qc = QuantumCircuit(qr, name="inv_qft")
    
    # Generate multiple groups of diminishing angle CRZs and H gate
    for i_qubit in reversed(range(0, input_size)):
    
        # start laying out gates from highest order qubit (the hidx)
        hidx = input_size - i_qubit - 1
        
        # precede with an H gate (applied to all qubits)
        qc.h(qr[hidx])
        num_gates += 1
        depth += 1
        
        # if not the highest order qubit, add multiple controlled RZs of decreasing angle
        if hidx < input_size - 1:   
            num_crzs = i_qubit
            for j in reversed(range(0, num_crzs)):
                divisor = 2 ** (num_crzs - j)
                qc.crz( -math.pi / divisor , qr[hidx], qr[input_size - j - 1])
                num_gates += 1
                depth += 1
            
        qc.barrier()  
    
    if QFTI_ == None or input_size <= 5:
        if input_size < 9: QFTI_= qc
        
    return qc
    
# Define expected distribution calculated from applying the iqft to the prepared secret_int state
def expected_dist(num_qubits, secret_int, counts):
    dist = {}
    s = num_qubits - secret_int
    for key in counts.keys():
        if key[(num_qubits-secret_int):] == ''.zfill(secret_int):
            dist[key] = 1/(2**s)
    return dist

# %%
############### Result Data Analysis

# Analyze and print measured results
def analyze_and_print_result (qc, result, num_qubits, secret_int, num_shots, method):

    # obtain counts from the result object
    counts = result.get_counts(qc)

    # For method 1, expected result is always the secret_int
    if method==1:
        
        # add one to the secret_int to compensate for the extra rotations done between QFT and IQFT
        secret_int_plus_one = (secret_int + 1) % (2 ** num_qubits)

        # create the key that is expected to have all the measurements (for this circuit)
        key = format(secret_int_plus_one, f"0{num_qubits}b")

        # correct distribution is measuring the key 100% of the time
        correct_dist = {key: 1.0}
        
    # For method 2, expected result is always the secret_int
    elif method==2:

        # create the key that is expected to have all the measurements (for this circuit)
        key = format(secret_int, f"0{num_qubits}b")

        # correct distribution is measuring the key 100% of the time
        correct_dist = {key: 1.0}
    
    # For method 3, correct_dist is a distribution with more than one value
    elif method==3:

        # correct_dist is from the expected dist
        correct_dist = expected_dist(num_qubits, secret_int, counts)
            
    # use our polarization fidelity rescaling
    fidelity = metrics.polarization_fidelity(counts, correct_dist)

    if verbose: print(f"For secret int {secret_int} measured: {counts} fidelity: {fidelity}")

    return counts, fidelity

# %%
################ Benchmark Loop

# Execute program with default parameters
def run (min_qubits = 2, max_qubits = 31, max_circuits = 3, skip_qubits=1, num_shots = 1000,
        method=3, input_value=None, 
        backend_id='qasm_simulator', provider_backend=None,
        hub="ibm-q", group="open", project="main", exec_options=None,
        context=None):

    print(f"{benchmark_name} ({method}) Benchmark Program - Qiskit")

    # validate parameters (smallest circuit is 2 qubits)
    max_qubits = max(2, max_qubits)
    min_qubits = min(max(2, min_qubits), max_qubits)
    skip_qubits = max(1, skip_qubits)
    #print(f"min, max qubits = {min_qubits} {max_qubits}")
    
    # create context identifier
    if context is None: context = f"{benchmark_name} ({method}) Benchmark"
    
    ##########
    
    # Initialize metrics module
    metrics.init_metrics()

    # Define custom result handler
    def execution_handler (qc, result, input_size, s_int, num_shots):  
     
        # determine fidelity of result set
        num_qubits = int(input_size)
        counts, fidelity = analyze_and_print_result(qc, result, num_qubits, int(s_int), num_shots, method)
        metrics.store_metric(input_size, s_int, 'fidelity', fidelity)

    # Initialize execution module using the execution result handler above and specified backend_id
    ex.init_execution(execution_handler)
    ex.set_execution_target(backend_id, provider_backend=provider_backend,
            hub=hub, group=group, project=project, exec_options=exec_options,
            context=context)

    ##########
    
    # Execute Benchmark Program N times for multiple circuit sizes
    # Accumulate metrics asynchronously as circuits complete
    for input_size in range(min_qubits, max_qubits + 1, skip_qubits):
        
        # reset random seed 
        np.random.seed(0)

        num_qubits = input_size

        # determine number of circuits to execute for this group
        # and determine range of secret strings to loop over
        if method == 1 or method == 2:
            num_circuits = min(2 ** (input_size), max_circuits)
        
            if 2**(input_size) <= max_circuits:
                s_range = list(range(num_circuits))
            else:
                s_range = np.random.randint(0, 2**(input_size), num_circuits + 2)
                s_range = list(set(s_range))[0:num_circuits]
         
        elif method == 3:
            num_circuits = min(input_size, max_circuits)

            if input_size <= max_circuits:
                s_range = list(range(num_circuits))
            else:
                s_range = np.random.choice(range(input_size), num_circuits, False)
                # s_range = np.random.randint(0, 2**(input_size), num_circuits + 2)    #this will give error
                # s_range = list(set(s_range))[0:num_circuits]
        
        else:
            sys.exit("Invalid QFT method")

        print(f"************\nExecuting [{num_circuits}] circuits with num_qubits = {num_qubits}")
        
        # loop over limited # of secret strings for this
        for s_int in s_range:
            s_int = int(s_int)

            # if user specifies input_value, use it instead
            # DEVNOTE: if max_circuits used, this will generate separate bar for each num_circuits
            if input_value is not None:
                s_int = input_value
                
            # create the circuit for given qubit size and secret string, store time metric
            ts = time.time()
            qc = QuantumFourierTransform(num_qubits, s_int, method=method)
            metrics.store_metric(input_size, s_int, 'create_time', time.time()-ts)

            # collapse the sub-circuits used in this benchmark (for qiskit)
            qc2 = qc.decompose()
            
            # submit circuit for execution on target (simulator, cloud simulator, or hardware)

            ex.submit_circuit(qc2, input_size, s_int, num_shots)
        
        print(f"... number of gates, depth = {num_gates}, {depth}")
        
        # Wait for some active circuits to complete; report metrics when groups complete
        ex.throttle_execution(metrics.finalize_group)

    # Wait for all active circuits to complete; report metrics when groups complete
    ex.finalize_execution(metrics.finalize_group)
    
    ##########
    
    # print a sample circuit created (if not too large)
    print("Sample Circuit:"); print(QC_ if QC_ != None else "  ... too large!")
    if method==1:
        print("\nQFT Circuit ="); print(QFT_)
    print("\nInverse QFT Circuit ="); print(QFTI_)
     
    # Plot metrics for all circuit sizes
    metrics.plot_metrics(f"Benchmark Results - {benchmark_name} ({method}) - Qiskit")

# if main, execute method 1
if __name__ == '__main__': run()
# Out:
# Quantum Fourier Transform (3) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 05:20:26 UTC
# ************
# Executing [2] circuits with num_qubits = 2
# ... number of gates, depth = 7, 5
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 12, 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 5, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.268, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.098, 0.002 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.999, 0.498
#
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 18, 12
# /home/cdac/Desktop/Quantum_Accelerator_Project/Quantum_Computing/Quantum_Computing_Benchmarks/qc-app-oriented-benchmarks/quantum-fourier-transform/qiskit/../../_common/metrics.py:744: RuntimeWarning: divide by zero encountered in double_scalars
#   rescaled_fidelity = (1-new_floor_fidelity)/(1-floor_fidelity) * (fidelity - 1) + 1
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 8, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.327, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.309, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.999, 0.665
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 25, 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 12, 0.429
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.364, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 0.568, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.999, 0.998
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 33, 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 17, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.382, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 0.572, 0.002 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.996, 0.663
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 42, 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 23, 0.556
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 58, 0.4, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.002, 0.579, 0.003 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.997, 0.994
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 52, 38
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 30, 0.6
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 78, 0.412, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.001, 0.587, 0.002 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.991, 0.983
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 63, 47
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 38, 0.636
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.421, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.595, 0.003 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.978, 0.961
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 75, 57
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 47, 0.667
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.429, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.003, 0.621, 0.004 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.972, 0.951
#
# ************
# Executing [3] circuits with num_qubits = 11
# ... number of gates, depth = 88, 68
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 57, 0.692
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 156, 0.435, 90.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.002, 0.639, 0.005 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.974, 0.967
#
# ************
# Executing [3] circuits with num_qubits = 12
# ... number of gates, depth = 102, 80
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 68, 0.714
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 188, 0.44, 110.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.003, 0.654, 0.005 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.964, 0.957
#
# ************
# Executing [3] circuits with num_qubits = 13
# ... number of gates, depth = 117, 93
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 80, 0.733
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 223, 0.444, 132.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.003, 0.681, 0.009 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.972, 0.971
#
# ************
# Executing [3] circuits with num_qubits = 14
# ... number of gates, depth = 133, 107
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 93, 0.75
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 261, 0.448, 156.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.003, 0.74, 0.011 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.966, 0.964
#
# ************
# Executing [3] circuits with num_qubits = 15
# ... number of gates, depth = 150, 122
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 107, 0.765
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 302, 0.452, 182.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.004, 1.318, 0.023 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.956, 0.954
#
# ************
# Executing [3] circuits with num_qubits = 16
# ... number of gates, depth = 168, 138
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 122, 0.778
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 346, 0.455, 210.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.005, 2.872, 0.843 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.965, 0.964
#
# ************
# Executing [3] circuits with num_qubits = 17
# ... number of gates, depth = 187, 155
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 138, 0.789
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 393, 0.457, 240.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.283, 1.939, 0.665 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.965, 0.965
#
# ************
# Executing [3] circuits with num_qubits = 18
# ... number of gates, depth = 207, 173
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 155, 0.8
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 443, 0.459, 272.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.057, 2.676, 0.837 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.965, 0.965
#
# ************
# Executing [3] circuits with num_qubits = 19
# ... number of gates, depth = 228, 192
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 173, 0.81
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 496, 0.462, 306.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.379, 1.661, 0.119 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.977, 0.977
#
# ************
# Executing [3] circuits with num_qubits = 20
# ... number of gates, depth = 250, 212
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 192, 0.818
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 552, 0.463, 342.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.056, 3.31, 0.772 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.966, 0.966
#
# ************
# Executing [3] circuits with num_qubits = 21
# ... number of gates, depth = 273, 233
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 212, 0.826
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 611, 0.465, 380.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.133, 5.353, 1.601 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [3] circuits with num_qubits = 22
# ... number of gates, depth = 297, 255
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 233, 0.833
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 673, 0.467, 420.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.01, 5.94, 1.729 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.982, 0.982
#
# ************
# Executing [3] circuits with num_qubits = 23
# ... number of gates, depth = 322, 278
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 255, 0.84
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 738, 0.468, 462.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.587, 7.155, 2.031 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.973, 0.973
#
# ************
# Executing [3] circuits with num_qubits = 24
# ... number of gates, depth = 348, 302
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 278, 0.846
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 806, 0.469, 506.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.012, 9.735, 2.715 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.99, 0.99
#
# ************
# Executing [3] circuits with num_qubits = 25
# ... number of gates, depth = 375, 327
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 302, 0.852
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 877, 0.471, 552.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.014, 13.231, 3.669 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.995, 0.995
#
# ************
# Executing [3] circuits with num_qubits = 26
# ... number of gates, depth = 403, 353
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 327, 0.857
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 951, 0.472, 600.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 1.202, 20.36, 5.337 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 0.996, 0.996
#
# ************
# Executing [3] circuits with num_qubits = 27
# ... number of gates, depth = 432, 380
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 353, 0.862
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 1028, 0.473, 650.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 1.796, 35.664, 9.056 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.988, 0.988
#
# ************
# Executing [3] circuits with num_qubits = 28
# ... number of gates, depth = 462, 408
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 380, 0.867
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 1108, 0.474, 702.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 3.033, 67.823, 16.691 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.997, 0.997
#
# ************
# Executing [3] circuits with num_qubits = 29
# ... number of gates, depth = 493, 437
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 408, 0.871
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 1191, 0.475, 756.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 5.513, 136.723, 32.979 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.993, 0.993
#
# ************
# Executing [3] circuits with num_qubits = 30
# ... number of gates, depth = 525, 467
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 437, 0.875
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 1277, 0.475, 812.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 10.656, 280.645, 67.01 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 0.972, 0.972
#
# ************
# Executing [3] circuits with num_qubits = 31
# ... number of gates, depth = 558, 498
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 467, 0.879
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 1366, 0.476, 870.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 21.001, 611.757, 138.93 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 498, 0.882
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 1458, 0.477, 930.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 42.462, 493.692, 308.996 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 1.0, 1.0
#
# ... execution complete at Sep 18, 2024 05:50:27 UTC in 1800.682 secs
#
# Sample Circuit:
#         ┌───┐┌──────────┐┌─┐
# q113_0: ┤ H ├┤0         ├┤M├────────────
#         ├───┤│          │└╥┘┌─┐
# q113_1: ┤ X ├┤1         ├─╫─┤M├─────────
#         ├───┤│          │ ║ └╥┘┌─┐
# q113_2: ┤ X ├┤2 inv_qft ├─╫──╫─┤M├──────
#         ├───┤│          │ ║  ║ └╥┘┌─┐
# q113_3: ┤ X ├┤3         ├─╫──╫──╫─┤M├───
#         ├───┤│          │ ║  ║  ║ └╥┘┌─┐
# q113_4: ┤ X ├┤4         ├─╫──╫──╫──╫─┤M├
#         └───┘└──────────┘ ║  ║  ║  ║ └╥┘
#  c10: 5/══════════════════╩══╩══╩══╩══╩═
#                           0  1  2  3  4
#
# Inverse QFT Circuit =
#         ┌───┐                                                  ░      »
# q114_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q114_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q114_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                          └──────────┘┌────┴─────┐      │       ░      »
# q114_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                      └──────────┘┌─────┴─────┐ ░      »
# q114_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                  └───────────┘ ░      »
# «                                             ░                              »
# «q114_0: ─────────────────────────────────────░──────────────────────────────»
# «                                             ░                              »
# «q114_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «        ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q114_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «        └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q114_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                    └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q114_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                └──────────┘ ░                  └──────────┘»
# «         ░                   ░       ░
# «q114_0: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q114_1: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q114_2: ─░───────────────────░───────░─
# «         ░ ┌───┐             ░       ░
# «q114_3: ─░─┤ H ├─────■───────░───────░─
# «         ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q114_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         ░      └──────────┘ ░ └───┘ ░
