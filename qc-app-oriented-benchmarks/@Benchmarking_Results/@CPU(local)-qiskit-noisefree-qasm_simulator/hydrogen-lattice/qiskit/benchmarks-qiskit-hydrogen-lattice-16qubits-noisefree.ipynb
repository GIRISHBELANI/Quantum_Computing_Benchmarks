# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit - Hydrogen Lattice
#
# The notebook contains specific examples for the Hydrogen Lattice benchmark program.
# Configure and run the cell below with the desired execution settings.
# Then configure and run the remaining cell(s), each one a variation of this benchmark.

# %%
min_qubits=2
max_qubits=16
max_circuits=1
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = {}

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples create a provider instance and get a backend from it

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import sys
# sys.path.insert(1, "../..")
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":'cpu' }

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# %%
# Custom optimization options can be specified in this cell (below is an example)

import sys
sys.path.insert(1, "../../")

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

##################
# Addition options for exploring Hydrogen Lattice

import sys
sys.path.insert(1, "../../_common")
sys.path.insert(1, "../../_common/qiskit")

# Set these True to enable verbose and verbose_time execution
import execute
execute.verbose=False
execute.verbose_time=False

# Set noise model to None.  This way the Sampler version uses same noise model as Estimator version
execute.noise=None

# Appendage for storing the data files and identifying the plots
import metrics
metrics.data_suffix=""

# %% [markdown]
# ### Hydrogen Lattice - Method 1 - Fidelity of Ansatz
#
# This benchmark is similar to benchmarks at the top-level in that it executes a quantum circuit to measure its fidelity of execution on a specific backend system.
# Here, the circuit tested is a pUCCD ansatz used in a quantum simulation of a hydrogen lattice.

# %%
import sys
sys.path.insert(1, "hydrogen-lattice/qiskit")
import hydrogen_lattice_benchmark

# Arguments applicable to Hydrogen Lattice benchmark method (1)
hl_app_args = dict(
    
    radius=0.75,                # select single problem radius, None = use max_circuits problem
    
    thetas_array=None,          # specify a custom thetas_array
    parameter_mode=1,           # 1 - use single theta parameter, 2 - map multiple thetas to pairs
    parameterized=True,        # use Parameter objects in circuit, cache transpiled circuits for performance
    use_estimator=False,        # use the Estimator for execution of objective function
)

# Run the benchmark in method 1
hydrogen_lattice_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=1,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options,
    **hl_app_args)
# Out:
# Hydrogen Lattice (1) Benchmark Program - Qiskit
# Validating user inputs...
# ... execution starting at Aug 07, 2024 12:14:56 UTC
# ************
# Executing [1] circuits for num_qubits = 2
# ************
# Executing [1] circuits for num_qubits = 4
# ************
# Executing [1] circuits for num_qubits = 6
# ************
# Executing [1] circuits for num_qubits = 8
# ************
# Executing [1] circuits for num_qubits = 10
# ************
# Executing [1] circuits for num_qubits = 12
# ************
# Executing [1] circuits for num_qubits = 14
# ************
# Executing [1] circuits for num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.182
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.182, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.004, 2.043, 0.003 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 20, 0.19
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 14, 0.267, 8.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.007, 2.051, 0.003 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.999, 0.999
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 32, 0.194
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 20, 0.316, 18.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.011, 2.31, 0.006 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.996, 0.995
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 44, 0.195
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 26, 0.348, 32.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.012, 1.075, 0.008 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.995, 0.995
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 56, 0.196
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 32, 0.37, 50.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.019, 1.179, 0.011 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.993, 0.993
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 68, 0.197
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 38, 0.387, 72.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.027, 1.012, 0.018 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.991, 0.991
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 80, 0.197
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 44, 0.4, 98.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.027, 2.755, 0.084 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.989, 0.989
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 92, 0.198
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 50, 0.41, 128.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.047, 2.423, 2.079 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.989, 0.989
#
# ... execution complete at Aug 07, 2024 12:15:03 UTC in 7.09 secs
#
# Sample Circuit:
#         ┌───┐┌───┐┌───┐┌──────────┐┌───┐┌─────┐ ┌───┐ ┌───┐┌──────────┐     »
#    q_0: ┤ X ├┤ S ├┤ X ├┤ Ry(t[0]) ├┤ X ├┤ Sdg ├─┤ S ├─┤ X ├┤ Ry(t[1]) ├─────»
#         ├───┤├───┤└─┬─┘└──────────┘└─┬─┘└─────┘ └───┘ └─┬─┘└──────────┘     »
#    q_1: ┤ X ├┤ S ├──┼────────────────┼──────────────────┼───────────────────»
#         ├───┤├───┤  │  ┌──────────┐  │   ┌───┐ ┌─────┐  │     ┌───┐    ┌───┐»
#    q_2: ┤ S ├┤ H ├──■──┤ Ry(t[0]) ├──■───┤ H ├─┤ Sdg ├──┼─────┤ S ├────┤ H ├»
#         ├───┤├───┤     └──────────┘      └───┘ └─────┘  │  ┌──┴───┴───┐└───┘»
#    q_3: ┤ S ├┤ H ├──────────────────────────────────────■──┤ Ry(t[1]) ├─────»
#         └───┘└───┘                                         └──────────┘     »
# meas: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «        ┌───┐┌─────┐                                                     »
# «   q_0: ┤ X ├┤ Sdg ├─────────────────────────────────────────────────────»
# «        └─┬─┘└┬───┬┘┌──────────┐┌───┐┌─────┐ ┌───┐ ┌───┐┌──────────┐┌───┐»
# «   q_1: ──┼───┤ X ├─┤ Ry(t[2]) ├┤ X ├┤ Sdg ├─┤ S ├─┤ X ├┤ Ry(t[3]) ├┤ X ├»
# «          │   └─┬─┘ ├──────────┤└─┬─┘└┬───┬┘┌┴───┴┐└─┬─┘└──────────┘└─┬─┘»
# «   q_2: ──┼─────■───┤ Ry(t[2]) ├──■───┤ H ├─┤ Sdg ├──┼────────────────┼──»
# «          │   ┌───┐ └─┬─────┬──┘┌───┐ ├───┤ └─────┘  │  ┌──────────┐  │  »
# «   q_3: ──■───┤ H ├───┤ Sdg ├───┤ S ├─┤ H ├──────────■──┤ Ry(t[3]) ├──■──»
# «              └───┘   └─────┘   └───┘ └───┘             └──────────┘     »
# «meas: 4/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                       ░ ┌───┐ ░ ┌─┐
# «   q_0: ───────────────░─┤ H ├─░─┤M├─────────
# «        ┌─────┐        ░ ├───┤ ░ └╥┘┌─┐
# «   q_1: ┤ Sdg ├────────░─┤ H ├─░──╫─┤M├──────
# «        └─────┘        ░ ├───┤ ░  ║ └╥┘┌─┐
# «   q_2: ───────────────░─┤ H ├─░──╫──╫─┤M├───
# «         ┌───┐ ┌─────┐ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# «   q_3: ─┤ H ├─┤ Sdg ├─░─┤ H ├─░──╫──╫──╫─┤M├
# «         └───┘ └─────┘ ░ └───┘ ░  ║  ║  ║ └╥┘
# «meas: 4/══════════════════════════╩══╩══╩══╩═
# «                                  0  1  2  3

# %% [markdown]
# ### Hydrogen Lattice - Method 2 - Energy as Objective Function
#
# This method executes the benchmark as a Variational Quantum Eigensolver (VQE) that uses the ansatz tested in method (1).

# %%
import sys
sys.path.insert(1, "hydrogen-lattice/qiskit")
import hydrogen_lattice_benchmark

# Arguments specific to Hydrogen Lattice benchmark method (2)
hl_app_args = dict(
    
    radius=0.75,                # select single problem radius, None = use max_circuits problems
  
    thetas_array=None,          # specify a custom thetas_array
    parameter_mode=1,           # 1 - use single theta parameter, 2 - map multiple thetas to pairs
    parameterized=False,        # use Parameter objects in circuit, cache transpiled circuits for performance
    use_estimator=False,        # use the Estimator for execution of objective function
    
    max_iter=30,                # maximum minimizer iterations to perform
    minimizer_tolerance=0.001,  # tolerance passed to the minimizer
    comfort=True,               # show 'comfort dots' during execution
)

# Run the benchmark in method 2
hydrogen_lattice_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options,
    **hl_app_args)
# Out:
# Hydrogen Lattice (2) Benchmark Program - Qiskit
# Validating user inputs...
# ... execution starting at Aug 07, 2024 12:15:07 UTC
# ************
# Executing [1] restarts for num_qubits = 2
#
# .................
# Classically Computed Energies from solution file for 2 qubits and radius 0.75
#   DOCI calculated energy : -1.1371170673457325
#   FCI calculated energy : -1.1371170673457325
#   Hartree-Fock calculated energy : -1.1161514489386022
#   Random Solution calculated energy : 0.23161540155929444
# Computed Energies for 2 qubits and radius 0.75
#   Solution Energy : -1.1378845749962043
#   Accuracy Ratio : 0.9994392566349465, Solution Quality : 0.9997851538151984
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.182
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.182, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.002, 0.022, 0.004 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 4
#
# ...................
# Classically Computed Energies from solution file for 4 qubits and radius 0.75
#   DOCI calculated energy : -2.1288045079865525
#   FCI calculated energy : -2.145110647186226
#   Hartree-Fock calculated energy : -2.103290822999875
#   Random Solution calculated energy : 1.1635282831450988
# Computed Energies for 4 qubits and radius 0.75
#   Solution Energy : -2.1276954273345776
#   Accuracy Ratio : 0.9947364399022216, Solution Quality : 0.9974157947476581
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 20, 0.19
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 14, 0.267, 8.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.004, 0.049, 0.011 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 6
#
# .................
# Classically Computed Energies from solution file for 6 qubits and radius 0.75
#   DOCI calculated energy : -3.1190941516390347
#   FCI calculated energy : -3.1553048004765425
#   Hartree-Fock calculated energy : -3.0916972640398352
#   Random Solution calculated energy : 2.0833438078697335
# Computed Energies for 6 qubits and radius 0.75
#   Solution Energy : -3.0962589900789306
#   Accuracy Ratio : 0.9887288087420982, Solution Quality : 0.9940435812278842
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 32, 0.194
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 20, 0.316, 18.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.003, 0.035, 0.008 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 8
#
# ...............
# Classically Computed Energies from solution file for 8 qubits and radius 0.75
#   DOCI calculated energy : -4.109867706089972
#   FCI calculated energy : -4.167414047319331
#   Hartree-Fock calculated energy : -4.0815811726722995
#   Random Solution calculated energy : 2.958729421222468
# Computed Energies for 8 qubits and radius 0.75
#   Solution Energy : -4.08176218628569
#   Accuracy Ratio : 0.9879806151234888, Solution Quality : 0.9934580835585083
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 44, 0.195
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 26, 0.348, 32.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.012, 0.082, 0.022 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 10
#
# ...................
# Classically Computed Energies from solution file for 10 qubits and radius 0.75
#   DOCI calculated energy : -5.10112523043154
#   FCI calculated energy : -5.180667158366846
#   Hartree-Fock calculated energy : -5.072331892067394
#   Random Solution calculated energy : 3.8172742304437923
# Computed Energies for 10 qubits and radius 0.75
#   Solution Energy : -5.065120927052506
#   Accuracy Ratio : 0.9871585925800731, Solution Quality : 0.9929009175658758
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 56, 0.196
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 32, 0.37, 50.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.008, 0.044, 0.013 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 12
#
# .................
# Classically Computed Energies from solution file for 12 qubits and radius 0.75
#   DOCI calculated energy : -6.0926657876350205
#   FCI calculated energy : -6.194627856364143
#   Hartree-Fock calculated energy : -6.06359727834754
#   Random Solution calculated energy : 4.654561062397755
# Computed Energies for 12 qubits and radius 0.75
#   Solution Energy : -6.054388462247203
#   Accuracy Ratio : 0.9870737439298878, Solution Quality : 0.9927941306225295
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 68, 0.197
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 38, 0.387, 72.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.029, 0.144, 0.057 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 14
#
# ................
# Classically Computed Energies from solution file for 14 qubits and radius 0.75
#   DOCI calculated energy : -7.084414257618491
#   FCI calculated energy : -7.209049696074953
#   Hartree-Fock calculated energy : -7.05518164249731
#   Random Solution calculated energy : 5.473094452417363
# Computed Energies for 14 qubits and radius 0.75
#   Solution Energy : -7.072892334064156
#   Accuracy Ratio : 0.9892638531452914, Solution Quality : 0.9939882581000584
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 80, 0.197
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 44, 0.4, 98.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.042, 0.261, 0.153 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 16
#
# .................
# Classically Computed Energies from solution file for 16 qubits and radius 0.75
#   DOCI calculated energy : -8.076288353180047
#   FCI calculated energy : -8.22378616525954
#   Hartree-Fock calculated energy : -8.046971675958524
#   Random Solution calculated energy : 6.3008656580185285
# Computed Energies for 16 qubits and radius 0.75
#   Solution Energy : -8.054174339862662
#   Accuracy Ratio : 0.9883224859734643, Solution Quality : 0.9934352369957694
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 92, 0.198
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 50, 0.41, 128.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.18, 7.022, 6.913 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0, 0
#
# ... execution complete at Aug 07, 2024 12:17:48 UTC in 160.645 secs
# ----- Cumulative Plots for all qubit groups -----

# %% [markdown]
# ### Hydrogen Lattice - Method 2 - Energy as Objective Function - using Estimator
#
# This method executes the benchmark as a Variational Quantum Eigensolver (VQE) that uses the ansatz tested in method (1).

# %%
import sys
sys.path.insert(1, "hydrogen-lattice/qiskit")
import hydrogen_lattice_benchmark

# DEVNOTE: Estimator is using no noise by default
import execute
execute.noise = None

# Arguments specific to Hydrogen Lattice benchmark method (2)
hl_app_args = dict(
    
    radius=0.75,                # select single problem radius, None = use max_circuits problems
  
    thetas_array=None,          # specify a custom thetas_array
    parameter_mode=1,           # 1 - use single theta parameter, 2 - map multiple thetas to pairs
    parameterized=False,        # use Parameter objects in circuit, cache transpiled circuits for performance
    use_estimator=True,         # use the Estimator for execution of objective function
    
    max_iter=30,                # maximum minimizer iterations to perform
    minimizer_tolerance=0.001,  # tolerance passed to the minimizer
    comfort=True,               # show 'comfort dots' during execution
)

# Run the benchmark in method 2
hydrogen_lattice_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options,
    **hl_app_args)
# Out:
# Hydrogen Lattice (2) Benchmark Program - Qiskit
# Validating user inputs...
# ... execution starting at Aug 07, 2024 12:18:06 UTC
# ************
# Executing [1] restarts for num_qubits = 2
#
# ...............
# Classically Computed Energies from solution file for 2 qubits and radius 0.75
#   DOCI calculated energy : -1.1371170673457325
#   FCI calculated energy : -1.1371170673457325
#   Hartree-Fock calculated energy : -1.1161514489386022
#   Random Solution calculated energy : 0.23161540155929444
# Computed Energies for 2 qubits and radius 0.75
#   Solution Energy : -1.1285744974649243
#   Accuracy Ratio : 0.9937587731168224, Solution Quality : 0.9976087144094153
# ************
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 0.122, 0.121 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 4
#
# ..................
# Classically Computed Energies from solution file for 4 qubits and radius 0.75
#   DOCI calculated energy : -2.1288045079865525
#   FCI calculated energy : -2.145110647186226
#   Hartree-Fock calculated energy : -2.103290822999875
#   Random Solution calculated energy : 1.1635282831450988
# Computed Energies for 4 qubits and radius 0.75
#   Solution Energy : -2.1216324845034684
#   Accuracy Ratio : 0.9929039816138516, Solution Quality : 0.9965161439580988
# ************
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 0.113, 0.113 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 6
#
# ...............
# Classically Computed Energies from solution file for 6 qubits and radius 0.75
#   DOCI calculated energy : -3.1190941516390347
#   FCI calculated energy : -3.1553048004765425
#   Hartree-Fock calculated energy : -3.0916972640398352
#   Random Solution calculated energy : 2.0833438078697335
# Computed Energies for 6 qubits and radius 0.75
#   Solution Energy : -3.109081617202163
#   Accuracy Ratio : 0.991176506246146, Solution Quality : 0.9953370485519701
# ************
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 0.058, 0.058 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 8
#
# ................
# Classically Computed Energies from solution file for 8 qubits and radius 0.75
#   DOCI calculated energy : -4.109867706089972
#   FCI calculated energy : -4.167414047319331
#   Hartree-Fock calculated energy : -4.0815811726722995
#   Random Solution calculated energy : 2.958729421222468
# Computed Energies for 8 qubits and radius 0.75
#   Solution Energy : -4.106324844298751
#   Accuracy Ratio : 0.99142745254986, Solution Quality : 0.9953340491607456
# ************
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.065, 0.065 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 10
#
# .................
# Classically Computed Energies from solution file for 10 qubits and radius 0.75
#   DOCI calculated energy : -5.10112523043154
#   FCI calculated energy : -5.180667158366846
#   Hartree-Fock calculated energy : -5.072331892067394
#   Random Solution calculated energy : 3.8172742304437923
# Computed Energies for 10 qubits and radius 0.75
#   Solution Energy : -5.084396236103158
#   Accuracy Ratio : 0.9893007835788522, Solution Quality : 0.9940851045644276
# ************
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.005, 0.591, 0.591 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 12
#
# ..................
# Classically Computed Energies from solution file for 12 qubits and radius 0.75
#   DOCI calculated energy : -6.0926657876350205
#   FCI calculated energy : -6.194627856364143
#   Hartree-Fock calculated energy : -6.06359727834754
#   Random Solution calculated energy : 4.654561062397755
# Computed Energies for 12 qubits and radius 0.75
#   Solution Energy : -6.075788297773903
#   Accuracy Ratio : 0.989046226452493, Solution Quality : 0.9938936370125211
# ************
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.006, 0.658, 0.658 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 14
#
# .................
# Classically Computed Energies from solution file for 14 qubits and radius 0.75
#   DOCI calculated energy : -7.084414257618491
#   FCI calculated energy : -7.209049696074953
#   Hartree-Fock calculated energy : -7.05518164249731
#   Random Solution calculated energy : 5.473094452417363
# Computed Energies for 14 qubits and radius 0.75
#   Solution Energy : -7.040242715883253
#   Accuracy Ratio : 0.986689397453997, Solution Quality : 0.9925468018761175
# ************
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.009, 0.874, 0.873 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0, 0
#
# ************
# Executing [1] restarts for num_qubits = 16
#
# .................
# Classically Computed Energies from solution file for 16 qubits and radius 0.75
#   DOCI calculated energy : -8.076288353180047
#   FCI calculated energy : -8.22378616525954
#   Hartree-Fock calculated energy : -8.046971675958524
#   Random Solution calculated energy : 6.3008656580185285
# Computed Energies for 16 qubits and radius 0.75
#   Solution Energy : -8.05831656839716
#   Accuracy Ratio : 0.9886076720546796, Solution Quality : 0.9935955494677885
# ************
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.004, 0.256, 0.255 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0, 0
#
# ... execution complete at Aug 07, 2024 12:19:15 UTC in 68.493 secs
# ----- Cumulative Plots for all qubit groups -----
