# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
min_qubits=8
max_qubits=31
skip_qubits=1
max_circuits=1
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub="ibm-q"; group="open"; project="main"
provider_backend = None
# exec_options = {}

# firstly install ---> pip install qiskit-aer-gpu==0.13.2
# exec_options = {"device" : "GPU"}                         # to use single GPU 
exec_options = {"device" : "GPU", "blocking_qubits":15}     # to use multiple GPU

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples illustrate other backend execution options

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider (backend_id=CPU/QPU, device=cpu/qpu)
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":"cpu" }

# # An example using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # Fire Opal can be used to manage executions on other backends, as illustrated here
# import _common.executors.fire_opal_executor as fire_opal_executor
# from _common.executors.fire_opal_executor import FireOpalBackend
# ibm_backend_id = "ibmq_jakarta"
# backend_id = f"fire_opal_{ibm_backend_id}"
# provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
# exec_options = {"executor": fire_opal_executor.run}

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### using IBMQ hardware

# %%
# # # *** If using IBMQ hardware, run this once to authenticate

# from qiskit_ibm_provider import IBMProvider
# IBMProvider.save_account(token='Your-API-Token', overwrite = True)

# provider = IBMProvider()

# # display current supported backends
# # print(provider.backends())   #[<IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_kyoto')>, <IBMBackend('ibm_sherbrooke')>, <IBMBackend('ibm_kyiv')>]

# backend_id = "ibm_brisbane"

# %% [markdown]
# ### If qiskit-provider-aer module not found error is coming, try to uninstall and re-install qiskit-aer module

# %%
# pip uninstall qiskit-aer -y

# %%
# pip install qiskit-aer

# %%
# import sys
# sys.path.insert(1, "_common")
# import metrics
# ### Plot Metrics for a specific application

# metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Deutsch-Jozsa", apiname="Qiskit", filters=None, options=None, suffix="")
# # metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Bernstein-Vazirani (1)", apiname="Qiskit", filters=None, options=None, suffix="")

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:53:03 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.583, 0.553 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.001, 0.044, 0.003 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.043, 0.003 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.001, 0.046, 0.003 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.001, 0.047, 0.003 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.001, 0.048, 0.003 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.001, 0.051, 0.003 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.001, 0.057, 0.003 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.001, 0.065, 0.004 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.001, 0.134, 0.063 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.001, 0.182, 0.082 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.001, 0.131, 0.08 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.001, 0.127, 0.083 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.001, 0.112, 0.051 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.001, 0.119, 0.065 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.001, 0.114, 0.064 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 25
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.001, 0.139, 0.083 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.001, 0.163, 0.106 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.001, 0.211, 0.152 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.001, 0.704, 0.644 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 29
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.001, 0.647, 0.583 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 0.001, 1.262, 1.192 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 0.002, 2.513, 2.454 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 0.001, 17.342, 17.321 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 1.0, 1.0
#
# ... execution complete at Sep 05, 2024 03:53:28 UTC in 24.576 secs
#
# Sample Circuit:
#       ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q1_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├──────────────────
#       ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q1_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├───────────────
#       ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q1_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├────────────
#       ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q1_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├─────────
#       ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q1_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├──────
#       ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║ └╥┘┌─┐
# q1_5: ┤ H ├──────░─┤5    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫─┤M├───
#       ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# q1_6: ┤ H ├──────░─┤6    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫──╫─┤M├
#       ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║  ║  ║ └╥┘
# q1_7: ┤ X ├┤ H ├─░─┤7    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫──╫──╫─
#       └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║  ║  ║
# c0: 7/═════════════════════════════════════╩══╩══╩══╩══╩══╩══╩═
#                                            0  1  2  3  4  5  6
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
# q_6:
#
# q_7:
#
#
# Balanced Oracle 'Uf' =
#  ... too large or not used!

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:53:31 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 7, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 7, 0.062, 2.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.075, 0.007 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 8, 0.13
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 8, 0.081, 3.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.001, 0.079, 0.003 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 9, 0.154
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 9, 0.095, 4.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.075, 0.003 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 12, 0.226
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 12, 0.143, 7.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.001, 0.077, 0.003 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 9, 0.133
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 9, 0.08, 4.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.001, 0.374, 0.003 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 11, 0.176
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 11, 0.107, 6.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.001, 0.38, 0.295 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 9, 0.118
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 9, 0.069, 4.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.001, 0.093, 0.003 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 9, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 9, 0.065, 4.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.001, 0.137, 0.004 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 14, 0.209
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 14, 0.127, 9.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.001, 0.194, 0.045 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.503, 0.503
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 11, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 11, 0.083, 6.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.001, 0.214, 0.053 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.483, 0.483
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 11, 0.136
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 11, 0.079, 6.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.001, 0.26, 0.045 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.487, 0.487
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 13, 0.167
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 13, 0.098, 8.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.001, 0.304, 0.058 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 12, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 12, 0.082, 7.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.001, 0.33, 0.107 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 13, 0.154
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 13, 0.089, 8.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.001, 0.318, 0.139 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 18, 0.22
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 18, 0.131, 13.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.001, 0.316, 0.091 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.127, 0.127
#
# ************
# Executing [1] circuits with num_qubits = 25
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 13, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 13, 0.082, 8.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.001, 0.346, 0.122 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.515, 0.515
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 17, 0.194
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 17, 0.113, 12.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.001, 0.521, 0.128 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 16, 0.175
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 16, 0.101, 11.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.001, 0.838, 0.292 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 16, 0.169
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 16, 0.097, 11.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.001, 1.417, 0.435 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 29
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 17, 0.176
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 17, 0.102, 12.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.001, 3.167, 0.872 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 18, 0.183
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 18, 0.106, 13.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.002, 6.042, 2.186 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 16, 0.155
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 16, 0.088, 11.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 0.001, 9.081, 3.744 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 16, 0.151
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 16, 0.085, 11.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 0.002, 17.704, 5.22 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.5, 0.5
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 18, 0.169
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 18, 0.096, 13.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 0.002, 12.542, 12.42 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 0.518, 0.518
#
# ... execution complete at Sep 05, 2024 03:53:58 UTC in 27.331 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q243_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├──────────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q243_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├───────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q243_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q243_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├─────────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q243_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├──────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║ └╥┘┌─┐
# q243_5: ┤ H ├──────░─┤5    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# q243_6: ┤ H ├──────░─┤6    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║  ║  ║ └╥┘
# q243_7: ┤ X ├┤ H ├─░─┤7    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║  ║  ║
#  c24: 7/═════════════════════════════════════╩══╩══╩══╩══╩══╩══╩═
#                                              0  1  2  3  4  5  6
#
# Quantum Oracle 'Uf' =
#
# q244_0: ──────────
#
# q244_1: ──────────
#
# q244_2: ──────────
#
# q244_3: ──────────
#
# q244_4: ──■───────
#           │
# q244_5: ──┼────■──
#           │    │
# q244_6: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q244_7: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (2) Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:54:01 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 28, 0.19
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 35, 0.143, 4.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.176, 0.143 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 24, 0.125
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 27, 0.105, 2.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.164, 0.132 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 32, 0.174
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 39, 0.133, 4.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.316, 0.148 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 28, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 31, 0.095, 2.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.346, 0.155 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 45, 0.206
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 58, 0.149, 7.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.001, 0.217, 0.184 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 41, 0.172
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 50, 0.132, 5.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.001, 0.522, 0.492 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 46, 0.182
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 57, 0.136, 6.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.001, 0.246, 0.211 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 51, 0.189
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 64, 0.14, 7.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.001, 0.268, 0.225 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 50, 0.171
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 61, 0.13, 6.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.001, 0.388, 0.239 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 61, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 78, 0.145, 9.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.001, 0.426, 0.255 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 51, 0.147
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 60, 0.116, 5.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.001, 0.338, 0.256 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 53, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 62, 0.114, 5.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.001, 0.292, 0.257 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 58, 0.154
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 69, 0.12, 6.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.001, 0.327, 0.289 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 69, 0.184
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 86, 0.136, 9.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.001, 0.675, 0.639 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 56, 0.114
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 63, 0.095, 4.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.001, 0.344, 0.306 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 91, 0.217
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 120, 0.153, 15.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.001, 0.39, 0.345 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 25
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 78, 0.182
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 97, 0.135, 10.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.001, 0.774, 0.377 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 83, 0.186
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 104, 0.138, 11.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.001, 0.405, 0.366 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 85, 0.183
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 106, 0.136, 11.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.001, 0.42, 0.372 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 90, 0.188
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 113, 0.138, 12.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.001, 0.438, 0.387 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 29
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 86, 0.169
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 105, 0.128, 10.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.001, 0.44, 0.399 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 112, 0.214
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 147, 0.151, 18.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 0.001, 0.482, 0.436 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 99, 0.186
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 124, 0.137, 13.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 0.001, 0.479, 0.426 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 110, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 141, 0.144, 16.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 0.001, 0.566, 0.452 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 1.0, 1.0
#
# ... execution complete at Sep 05, 2024 03:54:10 UTC in 8.408 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q243_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├──────────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q243_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├───────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q243_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q243_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├─────────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q243_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├──────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║ └╥┘┌─┐
# q243_5: ┤ H ├──────░─┤5    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# q243_6: ┤ H ├──────░─┤6    ├─░─┤ H ├──────░──╫──╫──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║  ║  ║ └╥┘
# q243_7: ┤ X ├┤ H ├─░─┤7    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║  ║  ║
#  c24: 7/═════════════════════════════════════╩══╩══╩══╩══╩══╩══╩═
#                                              0  1  2  3  4  5  6

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:54:12 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.211
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 17, 0.089, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.045, 0.004 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 8, 0.208
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 17, 0.094, 10.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.05, 0.004 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 17, 0.094, 12.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.001, 0.051, 0.004 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 8, 0.212
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 17, 0.09, 14.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.001, 0.058, 0.005 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 8, 0.216
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 17, 0.092, 16.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.001, 0.128, 0.064 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 8, 0.205
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 17, 0.093, 18.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.002, 0.153, 0.049 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 8, 0.208
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 17, 0.093, 20.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.002, 0.121, 0.062 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 8, 0.208
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 17, 0.093, 22.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.002, 0.118, 0.054 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 17, 0.091, 24.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.002, 0.151, 0.083 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 8, 0.206
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 17, 0.092, 26.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.002, 0.71, 0.653 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 8, 0.209
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 17, 0.09, 28.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.002, 1.231, 1.158 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 8, 0.203
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 17, 0.091, 30.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 0.003, 16.496, 16.381 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.0, 0.0
#
# ... execution complete at Sep 05, 2024 03:54:32 UTC in 19.192 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q843_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├─────────────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q843_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├──────────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q843_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├───────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q843_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├────────────
#         ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q843_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├─────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q843_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├──────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# q843_6: ┤ H ├─░─┤6    ├─░─┤ H ├─░─┤6    ├─░─┤ H ├─░──╫──╫──╫──╫──╫──╫─┤M├───
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# q843_7: ┤ H ├─░─┤7    ├─░─┤ H ├─░─┤7    ├─░─┤ H ├─░──╫──╫──╫──╫──╫──╫──╫─┤M├
#         └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║  ║  ║ └╥┘
#  c72: 8/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩══╩══╩═
#                                                      0  1  2  3  4  5  6  7
#
# Quantum Oracle 'Uf' =
#         ┌───┐   ┌───┐
# q844_0: ┤ X ├─■─┤ X ├
#         └───┘ │ └───┘
# q844_1: ──────■──────
#
# q844_2: ──■──────────
#           │
# q844_3: ──■──────────
#
# q844_4: ──■──────────
#           │
# q844_5: ──■──────────
#         ┌───┐   ┌───┐
# q844_6: ┤ X ├─■─┤ X ├
#         ├───┤ │ ├───┤
# q844_7: ┤ X ├─■─┤ X ├
#         └───┘   └───┘
#
# Quantum Oracle 'Ug' =
#
# q845_0: ─■─
#          │
# q845_1: ─■─
#
# q845_2: ─■─
#          │
# q845_3: ─■─
#
# q845_4: ─■─
#          │
# q845_5: ─■─
#
# q845_6: ─■─
#          │
# q845_7: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:54:34 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# ************
# Executing [1] circuits with num_qubits = 9
# ... number of gates, depth = 112, 92
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 75, 0.667
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.418, 112.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.004, 0.099, 0.025 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... number of gates, depth = 135, 112
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 93, 0.699
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 263, 0.427, 144.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.004, 0.111, 0.011 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ... number of gates, depth = 159, 134
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 113, 0.72
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 322, 0.434, 180.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.005, 0.126, 0.011 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... number of gates, depth = 186, 158
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 135, 0.743
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 387, 0.44, 220.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.012, 0.144, 0.012 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ... number of gates, depth = 214, 184
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 159, 0.759
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 458, 0.444, 264.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.013, 0.44, 0.278 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... number of gates, depth = 244, 212
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 185, 0.776
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 535, 0.449, 312.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.28, 0.185, 0.017 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ... number of gates, depth = 276, 242
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 213, 0.791
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 618, 0.453, 364.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.009, 0.316, 0.023 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... number of gates, depth = 310, 274
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 243, 0.805
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 707, 0.456, 420.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.016, 0.245, 0.022 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ... number of gates, depth = 347, 308
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 275, 0.816
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 802, 0.459, 480.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.01, 0.337, 0.08 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.248, 0.248
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... number of gates, depth = 386, 344
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 309, 0.824
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 903, 0.461, 544.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.012, 0.426, 0.112 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.235, 0.235
#
# ************
# Executing [1] circuits with num_qubits = 19
# ... number of gates, depth = 427, 382
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 345, 0.832
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 1010, 0.463, 612.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.013, 0.456, 0.083 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... number of gates, depth = 470, 422
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 383, 0.838
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 1123, 0.465, 684.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.088, 0.406, 0.096 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ... number of gates, depth = 515, 464
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 423, 0.844
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 1242, 0.466, 760.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.092, 0.479, 0.122 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ... number of gates, depth = 562, 508
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 465, 0.85
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 1367, 0.468, 840.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.022, 0.605, 0.139 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ... number of gates, depth = 611, 554
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 509, 0.856
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 1498, 0.469, 924.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.228, 0.545, 0.118 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... number of gates, depth = 661, 602
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 555, 0.861
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 1635, 0.47, 1012.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.137, 0.873, 0.437 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 25
# ... number of gates, depth = 713, 652
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 603, 0.867
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 1778, 0.472, 1104.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.351, 1.537, 0.334 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 26
# ... number of gates, depth = 767, 704
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 653, 0.872
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 1927, 0.473, 1200.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.337, 2.874, 0.649 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ... number of gates, depth = 824, 758
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 705, 0.877
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 2082, 0.474, 1300.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.029, 2.265, 1.625 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ... number of gates, depth = 883, 814
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 759, 0.881
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 2243, 0.475, 1404.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.031, 3.446, 2.767 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.002, 0.002
#
# ************
# Executing [1] circuits with num_qubits = 29
# ... number of gates, depth = 943, 872
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 815, 0.884
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 2410, 0.476, 1512.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 2.786, 6.267, 5.542 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ... number of gates, depth = 1005, 932
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 873, 0.888
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 2583, 0.477, 1624.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 5.558, 12.247, 11.471 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ... number of gates, depth = 1069, 994
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 933, 0.892
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 2762, 0.477, 1740.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 11.563, 29.195, 28.355 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.002, 0.002
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 995, 0.896
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 2947, 0.478, 1860.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 28.459, 73.913, 73.592 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 0.0, 0.0
#
# ... execution complete at Sep 05, 2024 03:56:47 UTC in 132.645 secs
#
# Sample Circuit:
#               ░ ┌──────┐ ░   ┌───────┐   ░ ┌──────────┐ ░ ┌─┐                  »
# q999_0: ──────░─┤0     ├─░───┤ Rz(π) ├───░─┤0         ├─░─┤M├──────────────────»
#               ░ │      │ ░  ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐               »
# q999_1: ──────░─┤1     ├─░──┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├───────────────»
#         ┌───┐ ░ │      │ ░  ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐            »
# q999_2: ┤ X ├─░─┤2     ├─░──┤ Rz(π/4) ├──░─┤2         ├─░──╫──╫─┤M├────────────»
#         ├───┤ ░ │      │ ░  ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐         »
# q999_3: ┤ X ├─░─┤3     ├─░──┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├─────────»
#         └───┘ ░ │  qft │ ░  ├─────────┴┐ ░ │  inv_qft │ ░  ║  ║  ║ └╥┘┌─┐      »
# q999_4: ──────░─┤4     ├─░──┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├──────»
#         ┌───┐ ░ │      │ ░  ├──────────┤ ░ │          │ ░  ║  ║  ║  ║ └╥┘┌─┐   »
# q999_5: ┤ X ├─░─┤5     ├─░──┤ Rz(π/32) ├─░─┤5         ├─░──╫──╫──╫──╫──╫─┤M├───»
#         └───┘ ░ │      │ ░  ├──────────┤ ░ │          │ ░  ║  ║  ║  ║  ║ └╥┘┌─┐»
# q999_6: ──────░─┤6     ├─░──┤ Rz(π/64) ├─░─┤6         ├─░──╫──╫──╫──╫──╫──╫─┤M├»
#         ┌───┐ ░ │      │ ░ ┌┴──────────┤ ░ │          │ ░  ║  ║  ║  ║  ║  ║ └╥┘»
# q999_7: ┤ X ├─░─┤7     ├─░─┤ Rz(π/128) ├─░─┤7         ├─░──╫──╫──╫──╫──╫──╫──╫─»
#         └───┘ ░ └──────┘ ░ └───────────┘ ░ └──────────┘ ░  ║  ║  ║  ║  ║  ║  ║ »
#  c84: 8/═══════════════════════════════════════════════════╩══╩══╩══╩══╩══╩══╩═»
#                                                            0  1  2  3  4  5  6 »
# «
# «q999_0: ───
# «
# «q999_1: ───
# «
# «q999_2: ───
# «
# «q999_3: ───
# «
# «q999_4: ───
# «
# «q999_5: ───
# «
# «q999_6: ───
# «        ┌─┐
# «q999_7: ┤M├
# «        └╥┘
# « c84: 8/═╩═
# «         7
#
# QFT Circuit =
#                ░                  ░                             ░            »
# q1000_0: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1000_1: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1000_2: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1000_3: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1000_4: ──────░──────────────────░─────────────────────────────░──────■─────»
#                ░                  ░                       ┌───┐ ░      │     »
# q1000_5: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q1000_6: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q1000_7: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                     ░                                   »
# «q1000_0: ────────────────────────────░───────────────────────────────────»
# «                                     ░                                   »
# «q1000_1: ────────────────────────────░───────────────────────────────────»
# «                                     ░                                   »
# «q1000_2: ────────────────────────────░───────────────────────────────────»
# «                                     ░                                   »
# «q1000_3: ────────────────────────────░──────■───────────■──────────■─────»
# «                               ┌───┐ ░      │           │          │     »
# «q1000_4: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «              │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q1000_5: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «         ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q1000_6: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «         └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q1000_7: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                     ░ └──────────┘                      »
# «                          ░                                               »
# «q1000_0: ─────────────────░───────────────────────────────────────────────»
# «                          ░                                               »
# «q1000_1: ─────────────────░───────────────────────────────────────────────»
# «                          ░                                               »
# «q1000_2: ─────────────────░──────■───────────■───────────■──────────■─────»
# «                    ┌───┐ ░      │           │           │          │     »
# «q1000_3: ─────■─────┤ H ├─░──────┼───────────┼───────────┼──────────┼─────»
# «         ┌────┴────┐└───┘ ░      │           │           │     ┌────┴────┐»
# «q1000_4: ┤ Rz(π/2) ├──────░──────┼───────────┼───────────┼─────┤ Rz(π/4) ├»
# «         └─────────┘      ░      │           │      ┌────┴────┐└─────────┘»
# «q1000_5: ─────────────────░──────┼───────────┼──────┤ Rz(π/8) ├───────────»
# «                          ░      │      ┌────┴─────┐└─────────┘           »
# «q1000_6: ─────────────────░──────┼──────┤ Rz(π/16) ├──────────────────────»
# «                          ░ ┌────┴─────┐└──────────┘                      »
# «q1000_7: ─────────────────░─┤ Rz(π/32) ├──────────────────────────────────»
# «                          ░ └──────────┘                                  »
# «                          ░                                                »
# «q1000_0: ─────────────────░────────────────────────────────────────────────»
# «                          ░                                                »
# «q1000_1: ─────────────────░──────■───────────■───────────■───────────■─────»
# «                    ┌───┐ ░      │           │           │           │     »
# «q1000_2: ─────■─────┤ H ├─░──────┼───────────┼───────────┼───────────┼─────»
# «         ┌────┴────┐└───┘ ░      │           │           │           │     »
# «q1000_3: ┤ Rz(π/2) ├──────░──────┼───────────┼───────────┼───────────┼─────»
# «         └─────────┘      ░      │           │           │      ┌────┴────┐»
# «q1000_4: ─────────────────░──────┼───────────┼───────────┼──────┤ Rz(π/8) ├»
# «                          ░      │           │      ┌────┴─────┐└─────────┘»
# «q1000_5: ─────────────────░──────┼───────────┼──────┤ Rz(π/16) ├───────────»
# «                          ░      │      ┌────┴─────┐└──────────┘           »
# «q1000_6: ─────────────────░──────┼──────┤ Rz(π/32) ├───────────────────────»
# «                          ░ ┌────┴─────┐└──────────┘                       »
# «q1000_7: ─────────────────░─┤ Rz(π/64) ├───────────────────────────────────»
# «                          ░ └──────────┘                                   »
# «                                     ░                                      »
# «q1000_0: ────────────────────────────░───────■───────────■───────────■──────»
# «                               ┌───┐ ░       │           │           │      »
# «q1000_1: ─────■──────────■─────┤ H ├─░───────┼───────────┼───────────┼──────»
# «              │     ┌────┴────┐└───┘ ░       │           │           │      »
# «q1000_2: ─────┼─────┤ Rz(π/2) ├──────░───────┼───────────┼───────────┼──────»
# «         ┌────┴────┐└─────────┘      ░       │           │           │      »
# «q1000_3: ┤ Rz(π/4) ├─────────────────░───────┼───────────┼───────────┼──────»
# «         └─────────┘                 ░       │           │           │      »
# «q1000_4: ────────────────────────────░───────┼───────────┼───────────┼──────»
# «                                     ░       │           │      ┌────┴─────┐»
# «q1000_5: ────────────────────────────░───────┼───────────┼──────┤ Rz(π/32) ├»
# «                                     ░       │      ┌────┴─────┐└──────────┘»
# «q1000_6: ────────────────────────────░───────┼──────┤ Rz(π/64) ├────────────»
# «                                     ░ ┌─────┴─────┐└──────────┘            »
# «q1000_7: ────────────────────────────░─┤ Rz(π/128) ├────────────────────────»
# «                                     ░ └───────────┘                        »
# «                                                      ┌───┐ ░
# «q1000_0: ─────■───────────■──────────■──────────■─────┤ H ├─░─
# «              │           │          │     ┌────┴────┐└───┘ ░
# «q1000_1: ─────┼───────────┼──────────┼─────┤ Rz(π/2) ├──────░─
# «              │           │     ┌────┴────┐└─────────┘      ░
# «q1000_2: ─────┼───────────┼─────┤ Rz(π/4) ├─────────────────░─
# «              │      ┌────┴────┐└─────────┘                 ░
# «q1000_3: ─────┼──────┤ Rz(π/8) ├────────────────────────────░─
# «         ┌────┴─────┐└─────────┘                            ░
# «q1000_4: ┤ Rz(π/16) ├───────────────────────────────────────░─
# «         └──────────┘                                       ░
# «q1000_5: ───────────────────────────────────────────────────░─
# «                                                            ░
# «q1000_6: ───────────────────────────────────────────────────░─
# «                                                            ░
# «q1000_7: ───────────────────────────────────────────────────░─
# «                                                            ░
#
# Inverse QFT Circuit =
#          ┌───┐                                                              »
# q1001_0: ┤ H ├─────■───────────■───────────■────────────■────────────■──────»
#          └───┘┌────┴─────┐     │           │            │            │      »
# q1001_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼────────────┼──────»
#               └──────────┘┌────┴─────┐     │            │            │      »
# q1001_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼────────────┼──────»
#                           └──────────┘┌────┴─────┐      │            │      »
# q1001_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼────────────┼──────»
#                                       └──────────┘┌─────┴─────┐      │      »
# q1001_4: ─────────────────────────────────────────┤ Rz(-π/16) ├──────┼──────»
#                                                   └───────────┘┌─────┴─────┐»
# q1001_5: ──────────────────────────────────────────────────────┤ Rz(-π/32) ├»
#                                                                └───────────┘»
# q1001_6: ───────────────────────────────────────────────────────────────────»
#                                                                             »
# q1001_7: ───────────────────────────────────────────────────────────────────»
#                                                                             »
# «                                     ░                              »
# «q1001_0: ──────■────────────■────────░──────────────────────────────»
# «               │            │        ░ ┌───┐                        »
# «q1001_1: ──────┼────────────┼────────░─┤ H ├─────■───────────■──────»
# «               │            │        ░ └───┘┌────┴─────┐     │      »
# «q1001_2: ──────┼────────────┼────────░──────┤ Rz(-π/2) ├─────┼──────»
# «               │            │        ░      └──────────┘┌────┴─────┐»
# «q1001_3: ──────┼────────────┼────────░──────────────────┤ Rz(-π/4) ├»
# «               │            │        ░                  └──────────┘»
# «q1001_4: ──────┼────────────┼────────░──────────────────────────────»
# «               │            │        ░                              »
# «q1001_5: ──────┼────────────┼────────░──────────────────────────────»
# «         ┌─────┴─────┐      │        ░                              »
# «q1001_6: ┤ Rz(-π/64) ├──────┼────────░──────────────────────────────»
# «         └───────────┘┌─────┴──────┐ ░                              »
# «q1001_7: ─────────────┤ Rz(-π/128) ├─░──────────────────────────────»
# «                      └────────────┘ ░                              »
# «                                                             ░      »
# «q1001_0: ────────────────────────────────────────────────────░──────»
# «                                                             ░      »
# «q1001_1: ─────■────────────■────────────■────────────■───────░──────»
# «              │            │            │            │       ░ ┌───┐»
# «q1001_2: ─────┼────────────┼────────────┼────────────┼───────░─┤ H ├»
# «              │            │            │            │       ░ └───┘»
# «q1001_3: ─────┼────────────┼────────────┼────────────┼───────░──────»
# «         ┌────┴─────┐      │            │            │       ░      »
# «q1001_4: ┤ Rz(-π/8) ├──────┼────────────┼────────────┼───────░──────»
# «         └──────────┘┌─────┴─────┐      │            │       ░      »
# «q1001_5: ────────────┤ Rz(-π/16) ├──────┼────────────┼───────░──────»
# «                     └───────────┘┌─────┴─────┐      │       ░      »
# «q1001_6: ─────────────────────────┤ Rz(-π/32) ├──────┼───────░──────»
# «                                  └───────────┘┌─────┴─────┐ ░      »
# «q1001_7: ──────────────────────────────────────┤ Rz(-π/64) ├─░──────»
# «                                               └───────────┘ ░      »
# «                                                                        ░ »
# «q1001_0: ───────────────────────────────────────────────────────────────░─»
# «                                                                        ░ »
# «q1001_1: ───────────────────────────────────────────────────────────────░─»
# «                                                                        ░ »
# «q1001_2: ─────■───────────■───────────■────────────■────────────■───────░─»
# «         ┌────┴─────┐     │           │            │            │       ░ »
# «q1001_3: ┤ Rz(-π/2) ├─────┼───────────┼────────────┼────────────┼───────░─»
# «         └──────────┘┌────┴─────┐     │            │            │       ░ »
# «q1001_4: ────────────┤ Rz(-π/4) ├─────┼────────────┼────────────┼───────░─»
# «                     └──────────┘┌────┴─────┐      │            │       ░ »
# «q1001_5: ────────────────────────┤ Rz(-π/8) ├──────┼────────────┼───────░─»
# «                                 └──────────┘┌─────┴─────┐      │       ░ »
# «q1001_6: ────────────────────────────────────┤ Rz(-π/16) ├──────┼───────░─»
# «                                             └───────────┘┌─────┴─────┐ ░ »
# «q1001_7: ─────────────────────────────────────────────────┤ Rz(-π/32) ├─░─»
# «                                                          └───────────┘ ░ »
# «                                                                ░      »
# «q1001_0: ───────────────────────────────────────────────────────░──────»
# «                                                                ░      »
# «q1001_1: ───────────────────────────────────────────────────────░──────»
# «                                                                ░      »
# «q1001_2: ───────────────────────────────────────────────────────░──────»
# «         ┌───┐                                                  ░      »
# «q1001_3: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
# «         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# «q1001_4: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
# «              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# «q1001_5: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
# «                          └──────────┘┌────┴─────┐      │       ░      »
# «q1001_6: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
# «                                      └──────────┘┌─────┴─────┐ ░      »
# «q1001_7: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
# «                                                  └───────────┘ ░      »
# «                                              ░                              »
# «q1001_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_1: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_2: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_3: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_4: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1001_5: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1001_6: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1001_7: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1001_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_2: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_3: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_4: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_5: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1001_6: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1001_7: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (2) Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:56:50 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ... number of gates, depth = 60, 38
# ************
# Executing [1] circuits with num_qubits = 9
# ... number of gates, depth = 72, 47
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 39, 0.538
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.421, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.002, 0.07, 0.024 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... number of gates, depth = 85, 57
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 48, 0.571
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.429, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.002, 0.177, 0.004 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ... number of gates, depth = 99, 68
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 58, 0.6
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 156, 0.435, 90.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.002, 0.18, 0.005 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... number of gates, depth = 114, 80
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 69, 0.625
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 188, 0.44, 110.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.003, 0.08, 0.005 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ... number of gates, depth = 130, 93
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 81, 0.647
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 223, 0.444, 132.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.003, 0.096, 0.011 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... number of gates, depth = 147, 107
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 94, 0.667
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 261, 0.448, 156.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.004, 0.131, 0.012 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ... number of gates, depth = 165, 122
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 108, 0.684
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 302, 0.452, 182.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.004, 0.178, 0.012 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... number of gates, depth = 184, 138
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 123, 0.7
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 346, 0.455, 210.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.008, 0.162, 0.014 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ... number of gates, depth = 204, 155
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 139, 0.714
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 393, 0.457, 240.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.009, 0.223, 0.072 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.02, 0.02
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... number of gates, depth = 225, 173
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 156, 0.727
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 443, 0.459, 272.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.006, 0.254, 0.069 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.002, 0.002
#
# ************
# Executing [1] circuits with num_qubits = 19
# ... number of gates, depth = 247, 192
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 174, 0.739
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 496, 0.461, 306.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.007, 0.324, 0.067 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.01, 0.01
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... number of gates, depth = 270, 212
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 193, 0.75
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 552, 0.463, 342.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.012, 0.386, 0.115 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ... number of gates, depth = 294, 233
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 213, 0.76
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 611, 0.465, 380.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.009, 0.335, 0.068 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.013, 0.013
#
# ************
# Executing [1] circuits with num_qubits = 22
# ... number of gates, depth = 319, 255
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 234, 0.769
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 673, 0.466, 420.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.014, 0.389, 0.105 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.006, 0.006
#
# ************
# Executing [1] circuits with num_qubits = 23
# ... number of gates, depth = 345, 278
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 256, 0.778
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 738, 0.468, 462.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.015, 0.308, 0.11 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.005, 0.005
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... number of gates, depth = 372, 302
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 279, 0.786
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 806, 0.469, 506.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.013, 0.348, 0.131 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 25
# ... number of gates, depth = 400, 327
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 303, 0.793
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 877, 0.47, 552.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.011, 0.562, 0.258 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.268, 0.268
#
# ************
# Executing [1] circuits with num_qubits = 26
# ... number of gates, depth = 429, 353
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 328, 0.8
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 951, 0.471, 600.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.261, 0.602, 0.357 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ... number of gates, depth = 459, 380
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 354, 0.806
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 1028, 0.472, 650.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.014, 2.516, 0.841 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.268, 0.268
#
# ************
# Executing [1] circuits with num_qubits = 28
# ... number of gates, depth = 490, 408
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 381, 0.812
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 1108, 0.473, 702.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.852, 1.789, 1.412 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.002, 0.002
#
# ************
# Executing [1] circuits with num_qubits = 29
# ... number of gates, depth = 522, 437
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 409, 0.818
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 1191, 0.474, 756.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.016, 3.206, 2.909 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.009, 0.009
#
# ************
# Executing [1] circuits with num_qubits = 30
# ... number of gates, depth = 555, 467
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 438, 0.824
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 1277, 0.475, 812.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 2.899, 6.624, 6.232 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ... number of gates, depth = 589, 498
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 468, 0.829
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 1366, 0.476, 870.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 6.234, 12.822, 12.403 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.068, 0.068
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 499, 0.833
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 1458, 0.477, 930.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 12.413, 34.618, 34.432 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 0.004, 0.004
#
# ... execution complete at Sep 05, 2024 03:57:53 UTC in 63.38 secs
#
# Sample Circuit:
#               ░ ┌──────┐ ░   ┌───────┐   ░ ┌──────────┐ ░ ┌─┐                  »
# q999_0: ──────░─┤0     ├─░───┤ Rz(π) ├───░─┤0         ├─░─┤M├──────────────────»
#               ░ │      │ ░  ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐               »
# q999_1: ──────░─┤1     ├─░──┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├───────────────»
#         ┌───┐ ░ │      │ ░  ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐            »
# q999_2: ┤ X ├─░─┤2     ├─░──┤ Rz(π/4) ├──░─┤2         ├─░──╫──╫─┤M├────────────»
#         ├───┤ ░ │      │ ░  ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐         »
# q999_3: ┤ X ├─░─┤3     ├─░──┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├─────────»
#         └───┘ ░ │  qft │ ░  ├─────────┴┐ ░ │  inv_qft │ ░  ║  ║  ║ └╥┘┌─┐      »
# q999_4: ──────░─┤4     ├─░──┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├──────»
#         ┌───┐ ░ │      │ ░  ├──────────┤ ░ │          │ ░  ║  ║  ║  ║ └╥┘┌─┐   »
# q999_5: ┤ X ├─░─┤5     ├─░──┤ Rz(π/32) ├─░─┤5         ├─░──╫──╫──╫──╫──╫─┤M├───»
#         └───┘ ░ │      │ ░  ├──────────┤ ░ │          │ ░  ║  ║  ║  ║  ║ └╥┘┌─┐»
# q999_6: ──────░─┤6     ├─░──┤ Rz(π/64) ├─░─┤6         ├─░──╫──╫──╫──╫──╫──╫─┤M├»
#         ┌───┐ ░ │      │ ░ ┌┴──────────┤ ░ │          │ ░  ║  ║  ║  ║  ║  ║ └╥┘»
# q999_7: ┤ X ├─░─┤7     ├─░─┤ Rz(π/128) ├─░─┤7         ├─░──╫──╫──╫──╫──╫──╫──╫─»
#         └───┘ ░ └──────┘ ░ └───────────┘ ░ └──────────┘ ░  ║  ║  ║  ║  ║  ║  ║ »
#  c84: 8/═══════════════════════════════════════════════════╩══╩══╩══╩══╩══╩══╩═»
#                                                            0  1  2  3  4  5  6 »
# «
# «q999_0: ───
# «
# «q999_1: ───
# «
# «q999_2: ───
# «
# «q999_3: ───
# «
# «q999_4: ───
# «
# «q999_5: ───
# «
# «q999_6: ───
# «        ┌─┐
# «q999_7: ┤M├
# «        └╥┘
# « c84: 8/═╩═
# «         7
#
# Inverse QFT Circuit =
#          ┌───┐                                                              »
# q1001_0: ┤ H ├─────■───────────■───────────■────────────■────────────■──────»
#          └───┘┌────┴─────┐     │           │            │            │      »
# q1001_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼────────────┼──────»
#               └──────────┘┌────┴─────┐     │            │            │      »
# q1001_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼────────────┼──────»
#                           └──────────┘┌────┴─────┐      │            │      »
# q1001_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼────────────┼──────»
#                                       └──────────┘┌─────┴─────┐      │      »
# q1001_4: ─────────────────────────────────────────┤ Rz(-π/16) ├──────┼──────»
#                                                   └───────────┘┌─────┴─────┐»
# q1001_5: ──────────────────────────────────────────────────────┤ Rz(-π/32) ├»
#                                                                └───────────┘»
# q1001_6: ───────────────────────────────────────────────────────────────────»
#                                                                             »
# q1001_7: ───────────────────────────────────────────────────────────────────»
#                                                                             »
# «                                     ░                              »
# «q1001_0: ──────■────────────■────────░──────────────────────────────»
# «               │            │        ░ ┌───┐                        »
# «q1001_1: ──────┼────────────┼────────░─┤ H ├─────■───────────■──────»
# «               │            │        ░ └───┘┌────┴─────┐     │      »
# «q1001_2: ──────┼────────────┼────────░──────┤ Rz(-π/2) ├─────┼──────»
# «               │            │        ░      └──────────┘┌────┴─────┐»
# «q1001_3: ──────┼────────────┼────────░──────────────────┤ Rz(-π/4) ├»
# «               │            │        ░                  └──────────┘»
# «q1001_4: ──────┼────────────┼────────░──────────────────────────────»
# «               │            │        ░                              »
# «q1001_5: ──────┼────────────┼────────░──────────────────────────────»
# «         ┌─────┴─────┐      │        ░                              »
# «q1001_6: ┤ Rz(-π/64) ├──────┼────────░──────────────────────────────»
# «         └───────────┘┌─────┴──────┐ ░                              »
# «q1001_7: ─────────────┤ Rz(-π/128) ├─░──────────────────────────────»
# «                      └────────────┘ ░                              »
# «                                                             ░      »
# «q1001_0: ────────────────────────────────────────────────────░──────»
# «                                                             ░      »
# «q1001_1: ─────■────────────■────────────■────────────■───────░──────»
# «              │            │            │            │       ░ ┌───┐»
# «q1001_2: ─────┼────────────┼────────────┼────────────┼───────░─┤ H ├»
# «              │            │            │            │       ░ └───┘»
# «q1001_3: ─────┼────────────┼────────────┼────────────┼───────░──────»
# «         ┌────┴─────┐      │            │            │       ░      »
# «q1001_4: ┤ Rz(-π/8) ├──────┼────────────┼────────────┼───────░──────»
# «         └──────────┘┌─────┴─────┐      │            │       ░      »
# «q1001_5: ────────────┤ Rz(-π/16) ├──────┼────────────┼───────░──────»
# «                     └───────────┘┌─────┴─────┐      │       ░      »
# «q1001_6: ─────────────────────────┤ Rz(-π/32) ├──────┼───────░──────»
# «                                  └───────────┘┌─────┴─────┐ ░      »
# «q1001_7: ──────────────────────────────────────┤ Rz(-π/64) ├─░──────»
# «                                               └───────────┘ ░      »
# «                                                                        ░ »
# «q1001_0: ───────────────────────────────────────────────────────────────░─»
# «                                                                        ░ »
# «q1001_1: ───────────────────────────────────────────────────────────────░─»
# «                                                                        ░ »
# «q1001_2: ─────■───────────■───────────■────────────■────────────■───────░─»
# «         ┌────┴─────┐     │           │            │            │       ░ »
# «q1001_3: ┤ Rz(-π/2) ├─────┼───────────┼────────────┼────────────┼───────░─»
# «         └──────────┘┌────┴─────┐     │            │            │       ░ »
# «q1001_4: ────────────┤ Rz(-π/4) ├─────┼────────────┼────────────┼───────░─»
# «                     └──────────┘┌────┴─────┐      │            │       ░ »
# «q1001_5: ────────────────────────┤ Rz(-π/8) ├──────┼────────────┼───────░─»
# «                                 └──────────┘┌─────┴─────┐      │       ░ »
# «q1001_6: ────────────────────────────────────┤ Rz(-π/16) ├──────┼───────░─»
# «                                             └───────────┘┌─────┴─────┐ ░ »
# «q1001_7: ─────────────────────────────────────────────────┤ Rz(-π/32) ├─░─»
# «                                                          └───────────┘ ░ »
# «                                                                ░      »
# «q1001_0: ───────────────────────────────────────────────────────░──────»
# «                                                                ░      »
# «q1001_1: ───────────────────────────────────────────────────────░──────»
# «                                                                ░      »
# «q1001_2: ───────────────────────────────────────────────────────░──────»
# «         ┌───┐                                                  ░      »
# «q1001_3: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
# «         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# «q1001_4: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
# «              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# «q1001_5: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
# «                          └──────────┘┌────┴─────┐      │       ░      »
# «q1001_6: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
# «                                      └──────────┘┌─────┴─────┐ ░      »
# «q1001_7: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
# «                                                  └───────────┘ ░      »
# «                                              ░                              »
# «q1001_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_1: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_2: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_3: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1001_4: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1001_5: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1001_6: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1001_7: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1001_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_2: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_3: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_4: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1001_5: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1001_6: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1001_7: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=15, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 03:57:56 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 122, 0.045
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 15279, 0.492, 9120.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.014, 3.713, 0.024 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 206, 0.038
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 43387, 0.495, 25976.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.018, 10.726, 0.022 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.999, 0.999
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 252, 0.037
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 127803, 0.497, 76600.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.028, 30.195, 0.028 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.999, 0.999
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 352, 0.033
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 358123, 0.499, 214760.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.041, 85.705, 0.069 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 502, 0.03
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 1023603, 0.499, 614000.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.09, 235.534, 0.126 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 854, 0.028
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 2907666, 0.5, 1744328.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.168, 671.469, 0.154 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 1202, 0.027
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 8191303, 0.5, 4914400.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.197, 1929.497, 0.219 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 1422, 0.023
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 23264289, 0.5, 13958032.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.28, 0.838, 0.452 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ... execution complete at Sep 05, 2024 04:47:25 UTC in 2968.437 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q1695_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_2: ┤ H ├─░─┤2        ├┤2          ├─░─┤2        ├┤2          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#          ├───┤ ░ │  oracle ││  diffuser │ ░ │  oracle ││  diffuser │ ░ »
# q1695_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_5: ┤ H ├─░─┤5        ├┤5          ├─░─┤5        ├┤5          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_6: ┤ H ├─░─┤6        ├┤6          ├─░─┤6        ├┤6          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1695_7: ┤ H ├─░─┤7        ├┤7          ├─░─┤7        ├┤7          ├─░─»
#          └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#  c132: 8/══════════════════════════════════════════════════════════════»
#                                                                        »
# «         ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐»
# «q1695_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤0        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─┤1        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_2: ┤2        ├┤2          ├─░─┤2        ├┤2          ├─░─┤2        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─┤3        ├»
# «         │  oracle ││  diffuser │ ░ │  oracle ││  diffuser │ ░ │  oracle │»
# «q1695_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─┤4        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_5: ┤5        ├┤5          ├─░─┤5        ├┤5          ├─░─┤5        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_6: ┤6        ├┤6          ├─░─┤6        ├┤6          ├─░─┤6        ├»
# «         │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_7: ┤7        ├┤7          ├─░─┤7        ├┤7          ├─░─┤7        ├»
# «         └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ └─────────┘»
# « c132: 8/═════════════════════════════════════════════════════════════════»
# «                                                                          »
# «         ┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐»
# «q1695_0: ┤0          ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_1: ┤1          ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_2: ┤2          ├─░─┤2        ├┤2          ├─░─┤2        ├┤2          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_3: ┤3          ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├»
# «         │  diffuser │ ░ │  oracle ││  diffuser │ ░ │  oracle ││  diffuser │»
# «q1695_4: ┤4          ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_5: ┤5          ├─░─┤5        ├┤5          ├─░─┤5        ├┤5          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_6: ┤6          ├─░─┤6        ├┤6          ├─░─┤6        ├┤6          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_7: ┤7          ├─░─┤7        ├┤7          ├─░─┤7        ├┤7          ├»
# «         └───────────┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘»
# « c132: 8/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐»
# «q1695_0: ─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤0        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_1: ─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─┤1        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_2: ─░─┤2        ├┤2          ├─░─┤2        ├┤2          ├─░─┤2        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_3: ─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─┤3        ├»
# «          ░ │  oracle ││  diffuser │ ░ │  oracle ││  diffuser │ ░ │  oracle │»
# «q1695_4: ─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─┤4        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_5: ─░─┤5        ├┤5          ├─░─┤5        ├┤5          ├─░─┤5        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_6: ─░─┤6        ├┤6          ├─░─┤6        ├┤6          ├─░─┤6        ├»
# «          ░ │         ││           │ ░ │         ││           │ ░ │         │»
# «q1695_7: ─░─┤7        ├┤7          ├─░─┤7        ├┤7          ├─░─┤7        ├»
# «          ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ └─────────┘»
# « c132: 8/════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «         ┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐»
# «q1695_0: ┤0          ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_1: ┤1          ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_2: ┤2          ├─░─┤2        ├┤2          ├─░─┤2        ├┤2          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_3: ┤3          ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├»
# «         │  diffuser │ ░ │  oracle ││  diffuser │ ░ │  oracle ││  diffuser │»
# «q1695_4: ┤4          ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_5: ┤5          ├─░─┤5        ├┤5          ├─░─┤5        ├┤5          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_6: ┤6          ├─░─┤6        ├┤6          ├─░─┤6        ├┤6          ├»
# «         │           │ ░ │         ││           │ ░ │         ││           │»
# «q1695_7: ┤7          ├─░─┤7        ├┤7          ├─░─┤7        ├┤7          ├»
# «         └───────────┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘»
# « c132: 8/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─┐
# «q1695_0: ─░─┤M├─────────────────────
# «          ░ └╥┘┌─┐
# «q1695_1: ─░──╫─┤M├──────────────────
# «          ░  ║ └╥┘┌─┐
# «q1695_2: ─░──╫──╫─┤M├───────────────
# «          ░  ║  ║ └╥┘┌─┐
# «q1695_3: ─░──╫──╫──╫─┤M├────────────
# «          ░  ║  ║  ║ └╥┘┌─┐
# «q1695_4: ─░──╫──╫──╫──╫─┤M├─────────
# «          ░  ║  ║  ║  ║ └╥┘┌─┐
# «q1695_5: ─░──╫──╫──╫──╫──╫─┤M├──────
# «          ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q1695_6: ─░──╫──╫──╫──╫──╫──╫─┤M├───
# «          ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q1695_7: ─░──╫──╫──╫──╫──╫──╫──╫─┤M├
# «          ░  ║  ║  ║  ║  ║  ║  ║ └╥┘
# « c132: 8/════╩══╩══╩══╩══╩══╩══╩══╩═
# «             0  1  2  3  4  5  6  7
#
# Oracle =
#          ┌───┐           ░ ┌───┐
# q1696_0: ┤ X ├──■────────░─┤ X ├
#          └───┘  │        ░ └───┘
# q1696_1: ───────■────────░──────
#                 │        ░
# q1696_2: ───────■────────░──────
#                 │        ░
# q1696_3: ───────■────────░──────
#                 │        ░
# q1696_4: ───────■────────░──────
#          ┌───┐  │        ░ ┌───┐
# q1696_5: ┤ X ├──■────────░─┤ X ├
#          ├───┤  │        ░ ├───┤
# q1696_6: ┤ X ├──■────────░─┤ X ├
#          ├───┤┌─┴─┐┌───┐ ░ └───┘
# q1696_7: ┤ H ├┤ X ├┤ H ├─░──────
#          └───┘└───┘└───┘ ░
#
# Diffuser =
#          ┌───┐┌───┐                ░ ┌───┐┌───┐
# q1697_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_4: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_5: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1697_6: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q1697_7: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#          └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 04:47:27 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 109, 0.378, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.012, 0.102, 0.011 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 127, 0.426
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 124, 0.388, 66.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.01, 0.128, 0.011 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 156, 0.433
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 162, 0.398, 88.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.011, 0.137, 0.032 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 188, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 199, 0.406, 110.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.013, 0.138, 0.012 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 223, 0.443
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 235, 0.412, 132.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.014, 0.156, 0.012 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 261, 0.447
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 274, 0.418, 156.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.015, 0.187, 0.025 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 302, 0.45
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 312, 0.424, 180.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.016, 0.23, 0.011 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 346, 0.454
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 357, 0.428, 208.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.018, 0.262, 0.019 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 393, 0.456
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 405, 0.432, 238.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.019, 0.33, 0.084 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.005, 0.005
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 443, 0.459
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 460, 0.435, 272.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.021, 0.404, 0.088 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.009, 0.009
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 496, 0.461
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 510, 0.439, 304.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.023, 0.493, 0.077 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.006, 0.006
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 552, 0.463
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 567, 0.442, 340.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.024, 0.606, 0.081 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.014, 0.014
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 611, 0.465
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 631, 0.444, 380.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.026, 0.966, 0.162 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.006, 0.006
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 673, 0.466
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 694, 0.446, 420.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.028, 1.716, 0.09 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.007, 0.007
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 738, 0.468
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 760, 0.449, 462.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.03, 2.37, 0.132 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.006, 0.006
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 806, 0.469
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 829, 0.451, 506.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.031, 4.305, 0.173 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.012, 0.012
#
# ************
# Executing [1] circuits with num_qubits = 25
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 877, 0.47
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 901, 0.452, 552.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.033, 37.343, 0.219 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.004, 0.004
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 951, 0.471
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 976, 0.454, 600.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.036, 97.468, 0.341 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 0.064, 0.064
#
# ************
# Executing [1] circuits with num_qubits = 27
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 1028, 0.472
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 1054, 0.456, 650.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.037, 332.143, 0.8 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.083, 0.083
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 1108, 0.473
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 1135, 0.457, 702.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 0.039, 209.652, 1.734 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.311, 0.311
#
# ************
# Executing [1] circuits with num_qubits = 29
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 1191, 0.474
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 1219, 0.459, 756.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 0.041, 170.862, 2.608 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.323, 0.323
#
# ************
# Executing [1] circuits with num_qubits = 30

# %% [markdown]
# ### HHL Linear Solver

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Sep 05, 2024 12:14:50 UTC
# ************
# Executing 1 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Executing 1 circuits with 9 qubits, using 2 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 225, 0.27
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 405, 0.332, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.013, 1.804, 1.542 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.999, 0.998
#
# ************
# Executing 1 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 311, 0.278
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 552, 0.336, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.016, 1.074, 0.788 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.999, 0.998
#
# ************
# Executing 1 circuits with 11 qubits, using 3 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 237, 0.26
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 501, 0.335, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.8, 1.461, 1.032 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 12 qubits, using 3 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 343, 0.265
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 686, 0.336, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 1.033, 2.081, 1.641 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.998, 0.997
#
# ************
# Executing 1 circuits with 13 qubits, using 4 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 454, 0.28
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 885, 0.341, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.029, 1.952, 1.399 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 14 qubits, using 4 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 359, 0.259
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 814, 0.337, 652.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 1.407, 1.949, 1.405 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 15 qubits, using 4 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 454, 0.276
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 1039, 0.341, 828.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 1.424, 2.786, 2.033 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 16 qubits, using 5 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 574, 0.284
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 1306, 0.345, 1024.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.046, 1.326, 0.534 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 17 qubits, using 5 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 494, 0.259
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 1205, 0.34, 1012.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.042, 84.579, 83.677 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 18 qubits, using 5 input qubits and 7 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 622, 0.275
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 1498, 0.344, 1244.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 83.7, 85.857, 84.741 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 19 qubits, using 6 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 835, 0.279
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 1865, 0.348, 1512.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 84.798, 91.818, 90.715 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 20 qubits, using 6 input qubits and 7 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 670, 0.273
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 1696, 0.344, 1464.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 90.735, 106.034, 104.672 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.06, 0.033
#
# ************
# Executing 1 circuits with 21 qubits, using 6 input qubits and 8 clock qubits
# /home/girish/Quantum_Computing_Benchmarks/qc-app-oriented-benchmarks/hhl/qiskit/hhl_benchmark.py:813: RuntimeWarning: overflow encountered in scalar multiply
#   s_int = 1000 * (i+1) + (2**off_diag_index)*(3**b)
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 891, 0.277
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 2095, 0.347, 1768.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 104.846, 132.241, 130.437 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 22 qubits, using 7 input qubits and 7 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 1241, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 2626, 0.353, 2140.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.217, 146.466, 144.82 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.0, 0.0
#
# ************
# Executing 1 circuits with 23 qubits, using 7 input qubits and 8 clock qubits

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian Simulation Benchmark Program - Qiskit
# ... execution starting at Sep 06, 2024 03:32:52 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 50, 0.286
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 44, 0.312, 63.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.062, 0.665, 0.554 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.997, 0.997
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 50, 0.287
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 44, 0.309, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.009, 0.131, 0.006 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.995, 0.995
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 50, 0.288
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 44, 0.315, 81.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.008, 0.405, 0.27 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.993, 0.993
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 50, 0.288
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 44, 0.312, 90.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.279, 0.148, 0.012 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.995, 0.995
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 50, 0.289
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 44, 0.317, 99.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.01, 0.156, 0.012 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.988, 0.988
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 50, 0.29
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 44, 0.315, 108.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.017, 0.171, 0.018 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.989, 0.989
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 50, 0.29
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 44, 0.319, 117.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.011, 0.246, 0.015 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.987, 0.987
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 50, 0.29
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 44, 0.317, 126.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.012, 0.201, 0.015 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.991, 0.991
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 50, 0.291
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 44, 0.32, 135.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.013, 0.281, 0.066 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.002, 0.002
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 50, 0.291
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 44, 0.318, 144.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.015, 0.639, 0.386 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 50, 0.291
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 44, 0.321, 153.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.015, 0.258, 0.049 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 50, 0.291
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 44, 0.319, 162.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.06, 0.33, 0.057 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 44, 0.321, 171.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.018, 0.292, 0.065 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 44, 0.32, 180.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.068, 0.313, 0.074 secs
# Average Transpiling, Validating, Running Times for group 21 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 44, 0.322, 189.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.083, 0.62, 0.37 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 44, 0.32, 198.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.02, 0.422, 0.093 secs
# Average Transpiling, Validating, Running Times for group 23 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 25
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 44, 0.322, 207.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.098, 0.387, 0.12 secs
# Average Transpiling, Validating, Running Times for group 24 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 25 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 25 qubit group = 44, 0.321, 216.0
# Average Creation, Elapsed, Execution Time for the 25 qubit group = 0.021, 0.955, 0.686 secs
# Average Transpiling, Validating, Running Times for group 25 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 25 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 27
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 50, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 44, 0.323, 225.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 0.692, 1.605, 1.245 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 28
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 27 qubit group = 50, 0.292
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 27 qubit group = 44, 0.321, 234.0
# Average Creation, Elapsed, Execution Time for the 27 qubit group = 1.258, 1.551, 1.251 secs
# Average Transpiling, Validating, Running Times for group 27 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 27 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 29
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 28 qubit group = 50, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 28 qubit group = 44, 0.323, 243.0
# Average Creation, Elapsed, Execution Time for the 28 qubit group = 1.259, 4.226, 3.913 secs
# Average Transpiling, Validating, Running Times for group 28 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 28 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 29 qubit group = 50, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 29 qubit group = 44, 0.322, 252.0
# Average Creation, Elapsed, Execution Time for the 29 qubit group = 0.024, 6.098, 5.716 secs
# Average Transpiling, Validating, Running Times for group 29 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 29 qubit group = 0.0, 0.0
#
# ************
# Executing [1] circuits with num_qubits = 31
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 50, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 44, 0.323, 261.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 5.727, 13.327, 12.98 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.0, 0.0
# IOStream.flush timed out
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 31 qubit group = 50, 0.293
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 31 qubit group = 44, 0.322, 270.0
# Average Creation, Elapsed, Execution Time for the 31 qubit group = 12.992, 33.315, 33.109 secs
# Average Transpiling, Validating, Running Times for group 31 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 31 qubit group = 0.0, 0.0
#
# ... execution complete at Sep 06, 2024 03:33:57 UTC in 65.314 secs
#
# Sample Circuit:
#       ┌───┐ ░  ┌───────────────┐  ┌──────────────┐ ░ ┌─────────────┐»
# q1_0: ┤ X ├─░──┤ Rx(-0.025609) ├──┤ Rz(0.009192) ├─░─┤0            ├»
#       └───┘ ░  ├───────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q1_1: ──────░──┤ Rx(0.0025855) ├─┤ Rz(-0.057871) ├─░─┤1            ├»
#       ┌───┐ ░  └┬──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# q1_2: ┤ X ├─░───┤ Rx(0.035773) ├──┤ Rz(0.051748) ├─░─┤0            ├»
#       └───┘ ░   ├──────────────┤  ├──────────────┤ ░ │  xxyyzz_opt │»
# q1_3: ──────░───┤ Rx(0.038563) ├──┤ Rz(0.057288) ├─░─┤1            ├»
#       ┌───┐ ░   ├──────────────┤  ├──────────────┤ ░ ├─────────────┤»
# q1_4: ┤ X ├─░───┤ Rx(0.049408) ├──┤ Rz(0.023959) ├─░─┤0            ├»
#       └───┘ ░   ├──────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q1_5: ──────░───┤ Rx(-0.04161) ├─┤ Rz(0.0059034) ├─░─┤1            ├»
#       ┌───┐ ░  ┌┴──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# q1_6: ┤ X ├─░──┤ Rx(-0.030733) ├──┤ Rz(-0.04162) ├─░─┤0            ├»
#       └───┘ ░ ┌┴───────────────┴┐ ├──────────────┤ ░ │  xxyyzz_opt │»
# q1_7: ──────░─┤ Rx(-0.00050771) ├─┤ Rz(0.015768) ├─░─┤1            ├»
#             ░ └─────────────────┘ └──────────────┘ ░ └─────────────┘»
# c0: 8/══════════════════════════════════════════════════════════════»
#                                                                     »
# «                      ░  ┌───────────────┐  ┌──────────────┐ ░ ┌─────────────┐»
# «q1_0: ────────────────░──┤ Rx(-0.025609) ├──┤ Rz(0.009192) ├─░─┤0            ├»
# «      ┌─────────────┐ ░  ├───────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q1_1: ┤0            ├─░──┤ Rx(0.0025855) ├─┤ Rz(-0.057871) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░  └┬──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# «q1_2: ┤1            ├─░───┤ Rx(0.035773) ├──┤ Rz(0.051748) ├─░─┤0            ├»
# «      ├─────────────┤ ░   ├──────────────┤  ├──────────────┤ ░ │  xxyyzz_opt │»
# «q1_3: ┤0            ├─░───┤ Rx(0.038563) ├──┤ Rz(0.057288) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░   ├──────────────┤  ├──────────────┤ ░ ├─────────────┤»
# «q1_4: ┤1            ├─░───┤ Rx(0.049408) ├──┤ Rz(0.023959) ├─░─┤0            ├»
# «      ├─────────────┤ ░   ├──────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q1_5: ┤0            ├─░───┤ Rx(-0.04161) ├─┤ Rz(0.0059034) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░  ┌┴──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# «q1_6: ┤1            ├─░──┤ Rx(-0.030733) ├──┤ Rz(-0.04162) ├─░─┤0            ├»
# «      └─────────────┘ ░ ┌┴───────────────┴┐ ├──────────────┤ ░ │  xxyyzz_opt │»
# «q1_7: ────────────────░─┤ Rx(-0.00050771) ├─┤ Rz(0.015768) ├─░─┤1            ├»
# «                      ░ └─────────────────┘ └──────────────┘ ░ └─────────────┘»
# «c0: 8/════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                      ░  ┌───────────────┐  ┌──────────────┐ ░ ┌─────────────┐»
# «q1_0: ────────────────░──┤ Rx(-0.025609) ├──┤ Rz(0.009192) ├─░─┤0            ├»
# «      ┌─────────────┐ ░  ├───────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q1_1: ┤0            ├─░──┤ Rx(0.0025855) ├─┤ Rz(-0.057871) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░  └┬──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# «q1_2: ┤1            ├─░───┤ Rx(0.035773) ├──┤ Rz(0.051748) ├─░─┤0            ├»
# «      ├─────────────┤ ░   ├──────────────┤  ├──────────────┤ ░ │  xxyyzz_opt │»
# «q1_3: ┤0            ├─░───┤ Rx(0.038563) ├──┤ Rz(0.057288) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░   ├──────────────┤  ├──────────────┤ ░ ├─────────────┤»
# «q1_4: ┤1            ├─░───┤ Rx(0.049408) ├──┤ Rz(0.023959) ├─░─┤0            ├»
# «      ├─────────────┤ ░   ├──────────────┤ ┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q1_5: ┤0            ├─░───┤ Rx(-0.04161) ├─┤ Rz(0.0059034) ├─░─┤1            ├»
# «      │  xxyyzz_opt │ ░  ┌┴──────────────┤ └┬──────────────┤ ░ ├─────────────┤»
# «q1_6: ┤1            ├─░──┤ Rx(-0.030733) ├──┤ Rz(-0.04162) ├─░─┤0            ├»
# «      └─────────────┘ ░ ┌┴───────────────┴┐ ├──────────────┤ ░ │  xxyyzz_opt │»
# «q1_7: ────────────────░─┤ Rx(-0.00050771) ├─┤ Rz(0.015768) ├─░─┤1            ├»
# «                      ░ └─────────────────┘ └──────────────┘ ░ └─────────────┘»
# «c0: 8/════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                      ░ ┌─┐
# «q1_0: ────────────────░─┤M├─────────────────────
# «      ┌─────────────┐ ░ └╥┘┌─┐
# «q1_1: ┤0            ├─░──╫─┤M├──────────────────
# «      │  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q1_2: ┤1            ├─░──╫──╫─┤M├───────────────
# «      ├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q1_3: ┤0            ├─░──╫──╫──╫─┤M├────────────
# «      │  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q1_4: ┤1            ├─░──╫──╫──╫──╫─┤M├─────────
# «      ├─────────────┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q1_5: ┤0            ├─░──╫──╫──╫──╫──╫─┤M├──────
# «      │  xxyyzz_opt │ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q1_6: ┤1            ├─░──╫──╫──╫──╫──╫──╫─┤M├───
# «      └─────────────┘ ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q1_7: ────────────────░──╫──╫──╫──╫──╫──╫──╫─┤M├
# «                      ░  ║  ║  ║  ║  ║  ║  ║ └╥┘
# «c0: 8/═══════════════════╩══╩══╩══╩══╩══╩══╩══╩═
# «                         0  1  2  3  4  5  6  7
#
# XXYYZZ_opt =
#                        ┌───┐┌─────────────┐                    ┌───┐»
# q1724_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#          ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q1724_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#          └────────────┘      └────────────┘└───┘└─────────────┘     »
# «         ┌─────────────┐
# «q1724_0: ┤ Rz(-1.5708) ├
# «         └─────────────┘
# «q1724_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Sep 06, 2024 03:34:00 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 26, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1543, 0.692, 1280.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.1, 1.912, 0.086 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.998, 0.998
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 50, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 3932, 0.733, 3360.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.229, 4.421, 0.129 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.995, 0.994
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 101, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 9928, 0.763, 8640.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.178, 1.855, 0.27 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.979, 0.978
#
# ... execution complete at Sep 06, 2024 03:34:07 UTC in 6.504 secs
#
# Sample Circuit:
#   ... too large!
#
# Hartree Fock Generator 'Hf' =
#  ... too large!
#
# Cluster Operator Example 'Cluster Op' =
#  ... too large!

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (1) Benchmark - Qiskit
# ... execution starting at Sep 06, 2024 03:34:08 UTC
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 904, 0.536
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 2732, 0.425, 1644.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.385, 4.516, 0.34 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 2759, 0.588
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 8196, 0.43, 5070.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 1.264, 10.143, 0.22 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.998, 0.998
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 6478, 0.63
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 21267, 0.44, 13752.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 2.094, 20.208, 0.527 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.208, 0.198
#
# ************
# Executing [1] circuits with num_qubits = 26
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 12997, 0.664
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 39122, 0.442, 25122.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 3.843, 37.819, 1.613 secs
# Average Transpiling, Validating, Running Times for group 22 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 0.674, 0.673
#
# ************
# Executing [1] circuits with num_qubits = 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 26 qubit group = 23444, 0.693
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 26 qubit group = 70320, 0.446, 45444.0
# Average Creation, Elapsed, Execution Time for the 26 qubit group = 7.732, 78.713, 17.612 secs
# Average Transpiling, Validating, Running Times for group 26 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 26 qubit group = 0.262, 0.262
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 30 qubit group = 39139, 0.717
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 30 qubit group = 117080, 0.45, 75966.0
# Average Creation, Elapsed, Execution Time for the 30 qubit group = 27.506, 1110.495, 1100.026 secs
# Average Transpiling, Validating, Running Times for group 30 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 30 qubit group = 0.234, 0.234
#
# ... execution complete at Sep 06, 2024 03:54:51 UTC in 1242.158 secs
#
# Sample Circuit:
#          ┌───┐ ░                                ┌──────────┐ ░ ┌──────────┐┌─┐»
# q1792_0: ┤ H ├─░────────────────────────────────┤0         ├─░─┤0         ├┤M├»
#          ├───┤ ░                     ┌─────────┐│          │ ░ │          │└╥┘»
# q1792_1: ┤ H ├─░─────────────────────┤0        ├┤          ├─░─┤1         ├─╫─»
#          ├───┤ ░           ┌────────┐│         ││          │ ░ │  inv_qft │ ║ »
# q1792_2: ┤ H ├─░───────────┤0       ├┤         ├┤          ├─░─┤2         ├─╫─»
#          ├───┤ ░ ┌────────┐│        ││         ││          │ ░ │          │ ║ »
# q1792_3: ┤ H ├─░─┤0       ├┤        ├┤         ├┤          ├─░─┤3         ├─╫─»
#          ├───┤ ░ │        ││        ││         ││          │ ░ └──────────┘ ║ »
# q1793_0: ┤ X ├─░─┤1       ├┤1       ├┤1        ├┤1         ├─░──────────────╫─»
#          └───┘ ░ │        ││        ││         ││  C-U^256 │ ░              ║ »
# q1793_1: ──────░─┤2       ├┤2       ├┤2 C-U^16 ├┤2         ├─░──────────────╫─»
#                ░ │        ││  C-U^4 ││         ││          │ ░              ║ »
# q1794_0: ──────░─┤3 C-U^2 ├┤3       ├┤3        ├┤3         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q1794_1: ──────░─┤4       ├┤4       ├┤4        ├┤4         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q1794_2: ──────░─┤5       ├┤5       ├┤5        ├┤5         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q1794_3: ──────░─┤6       ├┤6       ├┤6        ├┤6         ├─░──────────────╫─»
#                ░ └────────┘└────────┘└─────────┘└──────────┘ ░              ║ »
#   c24: 4/═══════════════════════════════════════════════════════════════════╩═»
#                                                                             0 »
# «
# «q1792_0: ─────────
# «         ┌─┐
# «q1792_1: ┤M├──────
# «         └╥┘┌─┐
# «q1792_2: ─╫─┤M├───
# «          ║ └╥┘┌─┐
# «q1792_3: ─╫──╫─┤M├
# «          ║  ║ └╥┘
# «q1793_0: ─╫──╫──╫─
# «          ║  ║  ║
# «q1793_1: ─╫──╫──╫─
# «          ║  ║  ║
# «q1794_0: ─╫──╫──╫─
# «          ║  ║  ║
# «q1794_1: ─╫──╫──╫─
# «          ║  ║  ║
# «q1794_2: ─╫──╫──╫─
# «          ║  ║  ║
# «q1794_3: ─╫──╫──╫─
# «          ║  ║  ║
# «  c24: 4/═╩══╩══╩═
# «          1  2  3
#
# Controlled Ua Operator 'cUa' =
#          ┌─────────────┐      ┌─────────────────┐
#   q1999: ┤0            ├─■──■─┤0                ├
#          │             │ │  │ │                 │
# q2000_0: ┤1            ├─X──┼─┤1                ├
#          │             │ │  │ │                 │
# q2000_1: ┤2            ├─┼──X─┤2                ├
#          │             │ │  │ │                 │
# q2001_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#          │             │    │ │                 │
# q2001_1: ┤4            ├────X─┤4                ├
#          │             │      │                 │
# q2002_0: ┤5            ├──────┤5                ├
#          │             │      │                 │
# q2002_1: ┤6            ├──────┤6                ├
#          └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                  ┌─────────────┐┌─────────────┐
#   q2031: ────────┤0            ├┤0            ├────────────
#                  │             ││             │
# q2032_0: ────────┤1            ├┤             ├────────────
#                  │             ││             │
# q2032_1: ────────┤             ├┤1            ├────────────
#          ┌──────┐│             ││             │┌──────────┐
# q2033_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#          │      ││             ││             ││          │
# q2033_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#          │      ││             ││             ││          │
# q2033_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#          └──────┘│             ││             │└──────────┘
#   q2034: ────────┤5            ├┤5            ├────────────
#                  └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                              »
# q2047_0: ────■────────────────────────────────────────────────────────■──────»
#              │                                                        │      »
# q2047_1: ────■────────────────────────────────────────────────────────■──────»
#          ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q2048_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#          │       ││           ││          │     │      ││       ││          │»
# q2048_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#          │       ││           ││          │     │      ││       ││          │»
# q2048_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#          └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q2049: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                            └───┘                             »
# «
# «q2047_0: ───────────────────────────────────────■────
# «                                                │
# «q2047_1: ───────────────────────────────────────■────
# «         ┌──────────┐               ┌──────┐┌───┴───┐
# «q2048_0: ┤0         ├───────────────┤0     ├┤0      ├
# «         │          │               │      ││       │
# «q2048_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «         │          │┌───┐     ┌───┐│      ││       │
# «q2048_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «         └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q2049: ─────────────────┤ X ├──────────────────────
# «                          └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                ░                  ░                       ┌───┐ ░
# q2068_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q2068_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q2068_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=16, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (2) Benchmark - Qiskit
# ... execution starting at Sep 09, 2024 05:00:45 UTC
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 881, 0.527
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 2752, 0.413, 1632.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.292, 7.399, 3.274 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 2720, 0.578
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 8368, 0.416, 5040.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.902, 16.302, 6.643 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 6513, 0.611
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 22248, 0.422, 13696.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 8.351, 36.198, 16.441 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.527, 0.522
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 13619, 0.624
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 43717, 0.404, 25032.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 19.817, 72.228, 33.563 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 26866, 0.604
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 89948, 0.371, 45312.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 39.545, 31.853, 25.888 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.999, 0.999
#
# ... execution complete at Sep 09, 2024 05:03:20 UTC in 154.355 secs
#
# Sample Circuit:
#             ░  ┌───┐ ┌───┐┌──────────┐┌──────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
#   q1: ──────░──┤ X ├─┤ H ├┤0         ├┤ P(0) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
#       ┌───┐ ░  └─╥─┘ └───┘│          │└──╥───┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# q2_0: ┤ X ├─░────╫────────┤1         ├───╫──────────╫──╫──░────╫────────»
#       └───┘ ░    ║        │          │   ║          ║  ║  ░    ║        »
# q2_1: ──────░────╫────────┤2         ├───╫──────────╫──╫──░────╫────────»
#             ░    ║        │          │   ║          ║  ║  ░    ║        »
# q3_0: ──────░────╫────────┤3 C-U^256 ├───╫──────────╫──╫──░────╫────────»
#             ░    ║        │          │   ║          ║  ║  ░    ║        »
# q3_1: ──────░────╫────────┤4         ├───╫──────────╫──╫──░────╫────────»
#             ░    ║        │          │   ║          ║  ║  ░    ║        »
# q3_2: ──────░────╫────────┤5         ├───╫──────────╫──╫──░────╫────────»
#             ░    ║        │          │   ║          ║  ║  ░    ║        »
# q3_3: ──────░────╫────────┤6         ├───╫──────────╫──╫──░────╫────────»
#             ░    ║        └──────────┘┌──╨──┐       ║  ║  ░    ║        »
# c0: 4/═══════════╬════════════════════╡ 0x0 ╞═══════╩══╬═══════╬════════»
#               ┌──╨──┐                 └─────┘       0  ║    ┌──╨──┐     »
# c1: 1/════════╡ 0x1 ╞══════════════════════════════════╩════╡ 0x1 ╞═════»
#               └─────┘                                  0    └─────┘     »
# «      ┌─────────┐┌──────┐┌────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐┌────────┐»
# «  q1: ┤0        ├┤ P(0) ├┤ P(π/2) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├┤0       ├»
# «      │         │└──╥───┘└───╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘│        │»
# «q2_0: ┤1        ├───╫────────╫───────────╫──╫──░────╫────────┤1       ├»
# «      │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q2_1: ┤2        ├───╫────────╫───────────╫──╫──░────╫────────┤2       ├»
# «      │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q3_0: ┤3 C-U^16 ├───╫────────╫───────────╫──╫──░────╫────────┤3 C-U^4 ├»
# «      │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q3_1: ┤4        ├───╫────────╫───────────╫──╫──░────╫────────┤4       ├»
# «      │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q3_2: ┤5        ├───╫────────╫───────────╫──╫──░────╫────────┤5       ├»
# «      │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q3_3: ┤6        ├───╫────────╫───────────╫──╫──░────╫────────┤6       ├»
# «      └─────────┘┌──╨──┐  ┌──╨──┐        ║  ║  ░    ║        └────────┘»
# «c0: 4/═══════════╡ 0x0 ╞══╡ 0x1 ╞════════╩══╬═══════╬══════════════════»
# «                 └─────┘  └─────┘        1  ║    ┌──╨──┐               »
# «c1: 1/══════════════════════════════════════╩════╡ 0x1 ╞═══════════════»
# «                                            0    └─────┘               »
# «      ┌──────┐┌────────┐┌────────┐┌─────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
# «  q1: ┤ P(0) ├┤ P(π/4) ├┤ P(π/2) ├┤ P(3π/4) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
# «      └──╥───┘└───╥────┘└───╥────┘└────╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# «q2_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ║        ║         ║          ║           ║  ║  ░    ║        »
# «q2_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ║        ║         ║          ║           ║  ║  ░    ║        »
# «q3_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ║        ║         ║          ║           ║  ║  ░    ║        »
# «q3_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ║        ║         ║          ║           ║  ║  ░    ║        »
# «q3_2: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ║        ║         ║          ║           ║  ║  ░    ║        »
# «q3_3: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «      ┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐        ║  ║  ░    ║        »
# «c0: 4/╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞════════╩══╬═══════╬════════»
# «      └─────┘  └─────┘   └─────┘    └─────┘        2  ║    ┌──╨──┐     »
# «c1: 1/════════════════════════════════════════════════╩════╡ 0x1 ╞═════»
# «                                                      0    └─────┘     »
# «      ┌────────┐┌──────┐┌────────┐┌────────┐┌─────────┐┌────────┐┌─────────┐»
# «  q1: ┤0       ├┤ P(0) ├┤ P(π/8) ├┤ P(π/4) ├┤ P(3π/8) ├┤ P(π/2) ├┤ P(5π/8) ├»
# «      │        │└──╥───┘└───╥────┘└───╥────┘└────╥────┘└───╥────┘└────╥────┘»
# «q2_0: ┤1       ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      │        │   ║        ║         ║          ║         ║          ║     »
# «q2_1: ┤2       ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      │        │   ║        ║         ║          ║         ║          ║     »
# «q3_0: ┤3 C-U^2 ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      │        │   ║        ║         ║          ║         ║          ║     »
# «q3_1: ┤4       ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      │        │   ║        ║         ║          ║         ║          ║     »
# «q3_2: ┤5       ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      │        │   ║        ║         ║          ║         ║          ║     »
# «q3_3: ┤6       ├───╫────────╫─────────╫──────────╫─────────╫──────────╫─────»
# «      └────────┘┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐   ┌──╨──┐    ┌──╨──┐  »
# «c0: 4/══════════╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞═══╡ 0x4 ╞════╡ 0x5 ╞══»
# «                └─────┘  └─────┘   └─────┘    └─────┘   └─────┘    └─────┘  »
# «c1: 1/══════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «      ┌─────────┐┌─────────┐┌───┐┌─┐┌─┐
# «  q1: ┤ P(3π/4) ├┤ P(7π/8) ├┤ H ├┤M├┤M├
# «      └────╥────┘└────╥────┘└───┘└╥┘└╥┘
# «q2_0: ─────╫──────────╫───────────╫──╫─
# «           ║          ║           ║  ║
# «q2_1: ─────╫──────────╫───────────╫──╫─
# «           ║          ║           ║  ║
# «q3_0: ─────╫──────────╫───────────╫──╫─
# «           ║          ║           ║  ║
# «q3_1: ─────╫──────────╫───────────╫──╫─
# «           ║          ║           ║  ║
# «q3_2: ─────╫──────────╫───────────╫──╫─
# «           ║          ║           ║  ║
# «q3_3: ─────╫──────────╫───────────╫──╫─
# «        ┌──╨──┐    ┌──╨──┐        ║  ║
# «c0: 4/══╡ 0x6 ╞════╡ 0x7 ╞════════╩══╬═
# «        └─────┘    └─────┘        3  ║
# «c1: 1/═══════════════════════════════╩═
# «                                     0
#
# Controlled Ua Operator 'cUa' =
#         ┌─────────────┐      ┌─────────────────┐
#   q208: ┤0            ├─■──■─┤0                ├
#         │             │ │  │ │                 │
# q209_0: ┤1            ├─X──┼─┤1                ├
#         │             │ │  │ │                 │
# q209_1: ┤2            ├─┼──X─┤2                ├
#         │             │ │  │ │                 │
# q210_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#         │             │    │ │                 │
# q210_1: ┤4            ├────X─┤4                ├
#         │             │      │                 │
# q211_0: ┤5            ├──────┤5                ├
#         │             │      │                 │
# q211_1: ┤6            ├──────┤6                ├
#         └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                 ┌─────────────┐┌─────────────┐
#   q240: ────────┤0            ├┤0            ├────────────
#                 │             ││             │
# q241_0: ────────┤1            ├┤             ├────────────
#                 │             ││             │
# q241_1: ────────┤             ├┤1            ├────────────
#         ┌──────┐│             ││             │┌──────────┐
# q242_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#         │      ││             ││             ││          │
# q242_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#         │      ││             ││             ││          │
# q242_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#         └──────┘│             ││             │└──────────┘
#   q243: ────────┤5            ├┤5            ├────────────
#                 └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                             »
# q256_0: ────■────────────────────────────────────────────────────────■──────»
#             │                                                        │      »
# q256_1: ────■────────────────────────────────────────────────────────■──────»
#         ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q257_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#         │       ││           ││          │     │      ││       ││          │»
# q257_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#         │       ││           ││          │     │      ││       ││          │»
# q257_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#         └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q258: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                           └───┘                             »
# «
# «q256_0: ───────────────────────────────────────■────
# «                                               │
# «q256_1: ───────────────────────────────────────■────
# «        ┌──────────┐               ┌──────┐┌───┴───┐
# «q257_0: ┤0         ├───────────────┤0     ├┤0      ├
# «        │          │               │      ││       │
# «q257_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «        │          │┌───┐     ┌───┐│      ││       │
# «q257_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «        └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q258: ─────────────────┤ X ├──────────────────────
# «                         └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#               ░                  ░                       ┌───┐ ░
# q276_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#               ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q276_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#         ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q276_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#         └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)

# %%
# ### Plot Metrics for a specific application

# metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Deutsch-Jozsa", apiname="Qiskit", filters=None, options=None, suffix="")
# # metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Bernstein-Vazirani (1)", apiname="Qiskit", filters=None, options=None, suffix="")
