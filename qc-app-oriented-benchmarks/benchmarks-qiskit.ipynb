# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
min_qubits=2
max_qubits=10
skip_qubits=1
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = {}
# exec_options = {"device" : "GPU"}  # firstly install ---> pip install qiskit-aer-gpu

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples illustrate other backend execution options

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider (backend_id=CPU/QPU, device=cpu/qpu)
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":"cpu" }

# # An example using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # Fire Opal can be used to manage executions on other backends, as illustrated here
# import _common.executors.fire_opal_executor as fire_opal_executor
# from _common.executors.fire_opal_executor import FireOpalBackend
# ibm_backend_id = "ibmq_jakarta"
# backend_id = f"fire_opal_{ibm_backend_id}"
# provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
# exec_options = {"executor": fire_opal_executor.run}

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### If qiskit-provider-aer module not found error is coming, try to uninstall and re-install qiskit-aer module

# %%
# pip uninstall qiskit-aer -y

# %%
# pip install qiskit-aer

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:48:41 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [2] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 7, 0.083
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 7, 0.071, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.061, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.8, 0.733
#
# ************
# Executing [2] circuits with num_qubits = 5
# ************
# Executing [2] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.088
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 8, 0.071, 1.5
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.096, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.71, 0.669
#
# ************
# Executing [2] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 8, 0.077, 2.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.313, 0.002 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.641, 0.617
#
# ************
# Executing [2] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.076, 2.5
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.439, 0.002 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.567, 0.553
#
# ************
# Executing [2] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 10, 0.107
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 10, 0.079, 3.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.446, 0.004 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.514, 0.507
#
# ************
# Executing [2] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 10, 0.106
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 10, 0.078, 3.5
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.46, 0.004 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.472, 0.467
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 10, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 10, 0.08, 4.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.467, 0.016 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.417, 0.415
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 11, 0.11
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 11, 0.079, 4.5
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.32, 0.011 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.377, 0.376
#
# ... execution complete at Aug 08, 2024 09:48:43 UTC in 2.117 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q93_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q93_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q93_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#        ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q93_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q93_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q93_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c7: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                             0  1  2  3  4
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
#
# Balanced Oracle 'Uf' =
#      ┌───┐ ░                           ░ ┌───┐
# q_0: ┤ X ├─░───■───────────────────────░─┤ X ├
#      └───┘ ░   │                       ░ └───┘
# q_1: ──────░───┼────■──────────────────░──────
#      ┌───┐ ░   │    │                  ░ ┌───┐
# q_2: ┤ X ├─░───┼────┼────■─────────────░─┤ X ├
#      └───┘ ░   │    │    │             ░ └───┘
# q_3: ──────░───┼────┼────┼────■────────░──────
#      ┌───┐ ░   │    │    │    │        ░ ┌───┐
# q_4: ┤ X ├─░───┼────┼────┼────┼────■───░─┤ X ├
#      └───┘ ░ ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐ ░ └───┘
# q_5: ──────░─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░──────
#            ░ └───┘└───┘└───┘└───┘└───┘ ░

# %%
# import sys
# sys.path.insert(1, "_common")
# import metrics
# ### Plot Metrics for a specific application

# metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Deutsch-Jozsa", apiname="Qiskit", filters=None, options=None, suffix="")
# # metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Bernstein-Vazirani (1)", apiname="Qiskit", filters=None, options=None, suffix="")

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:48:44 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 6, 0.141
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.116, 1.333
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.132, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.804, 0.739
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 6, 0.061
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.044, 0.667
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.469, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.732, 0.694
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 7, 0.121
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.084, 1.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.553, 0.002 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.672, 0.65
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.175
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.119, 3.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.558, 0.002 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.578, 0.564
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 9, 0.183
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 9, 0.122, 3.667
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.564, 0.005 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.548, 0.541
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.153
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8, 0.099, 3.333
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.568, 0.011 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.495, 0.491
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 10, 0.199
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 10, 0.128, 5.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.573, 0.013 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.459, 0.457
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 9, 0.153
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 9, 0.095, 4.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.392, 0.012 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.402, 0.4
#
# ... execution complete at Aug 08, 2024 09:48:48 UTC in 3.99 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q390_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q390_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q390_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q390_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q390_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q390_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c27: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                              0  1  2  3  4
#
# Quantum Oracle 'Uf' =
#
# q391_0: ──────────
#
# q391_1: ──────────
#
# q391_2: ──■───────
#           │
# q391_3: ──┼────■──
#           │    │
# q391_4: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q391_5: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (2) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:48:50 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.114
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 10, 0.093, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.142, 0.003 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.889, 0.852
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 13, 0.163
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 15, 0.132, 1.667
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.478, 0.004 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.822, 0.797
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 18, 0.178
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 22, 0.137, 2.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.55, 0.005 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.738, 0.72
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 19, 0.133
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 23, 0.099, 2.333
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.554, 0.005 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.783, 0.776
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 21, 0.154
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 25, 0.124, 2.333
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.558, 0.005 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.744, 0.74
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 27, 0.181
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 33, 0.137, 3.667
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.558, 0.01 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.641, 0.638
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 26, 0.144
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 30, 0.116, 2.667
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.561, 0.006 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.728, 0.727
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 36, 0.196
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 46, 0.144, 5.333
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.385, 0.011 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.546, 0.545
#
# ... execution complete at Aug 08, 2024 09:48:54 UTC in 3.958 secs
#
# Sample Circuit:
#                    ░ ┌───┐     ┌───┐┌─┐     ┌─┐     ┌───┐     ┌───┐┌─┐     »
# q787_0: ───────────░─┤ H ├──■──┤ H ├┤M├─|0>─┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─»
#         ┌───┐┌───┐ ░ └───┘┌─┴─┐└───┘└╥┘     └╥┘     └───┘┌─┴─┐└───┘└╥┘     »
# q787_1: ┤ X ├┤ H ├─░──────┤ X ├──────╫───────╫───────────┤ X ├──────╫──────»
#         └───┘└───┘ ░      └───┘      ║       ║           └───┘      ║      »
#  c51: 5/═════════════════════════════╩═══════╩══════════════════════╩══════»
#                                      0       1                      2      »
# «        ┌───┐     ┌───┐┌─┐     ┌───┐     ┌───┐┌─┐
# «q787_0: ┤ H ├──■──┤ H ├┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─
# «        └───┘┌─┴─┐└───┘└╥┘     └───┘┌─┴─┐└───┘└╥┘
# «q787_1: ─────┤ X ├──────╫───────────┤ X ├──────╫──────
# «             └───┘      ║           └───┘      ║
# « c51: 5/════════════════╩══════════════════════╩══════
# «                        3                      4

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:48:55 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.189
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 16, 0.091, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.135, 0.002 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.588, 0.451
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.215
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 16, 0.094, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.521, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.337, 0.292
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.192
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 17, 0.09, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 0.569, 0.003 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.192, 0.179
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.204
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 17, 0.09, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.583, 0.006 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.11, 0.107
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 8, 0.19
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 17, 0.09, 10.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.402, 0.03 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.065, 0.064
#
# ... execution complete at Aug 08, 2024 09:48:57 UTC in 2.397 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q1166_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├───────────────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q1166_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├────────────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q1166_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├─────────
#          ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q1166_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├──────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q1166_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├───
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q1166_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├
#          └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║ └╥┘
#   c72: 6/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                       0  1  2  3  4  5
#
# Quantum Oracle 'Uf' =
#
# q1167_0: ──────■──────
#          ┌───┐ │ ┌───┐
# q1167_1: ┤ X ├─■─┤ X ├
#          ├───┤   ├───┤
# q1167_2: ┤ X ├─■─┤ X ├
#          └───┘ │ └───┘
# q1167_3: ──────■──────
#          ┌───┐   ┌───┐
# q1167_4: ┤ X ├─■─┤ X ├
#          └───┘ │ └───┘
# q1167_5: ──────■──────
#
#
# Quantum Oracle 'Ug' =
#
# q1168_0: ─■─
#           │
# q1168_1: ─■─
#
# q1168_2: ─■─
#           │
# q1168_3: ─■─
#
# q1168_4: ─■─
#           │
# q1168_5: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:48:58 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 11, 8
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 19, 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 9, 0.215
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 18, 0.207, 4.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.142, 0.003 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.697, 0.596
#
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 29, 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 15, 0.368
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.298, 12.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.487, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.522, 0.453
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 42, 32
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 23, 0.474
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.346, 24.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 0.585, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.348, 0.304
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 58, 44
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 33, 0.531
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.372, 40.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.001, 0.646, 0.004 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.213, 0.188
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 74, 58
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 45, 0.577
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 122, 0.39, 60.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 0.648, 0.009 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.125, 0.111
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 59, 0.64
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 163, 0.408, 84.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.004, 0.673, 0.028 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.079, 0.072
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 111, 92
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 75, 0.664
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.417, 112.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.011, 0.695, 0.023 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.041, 0.037
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 134, 112
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 93, 0.701
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 263, 0.428, 144.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.003, 0.847, 0.116 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.027, 0.025
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 113, 0.718
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 322, 0.433, 180.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.004, 0.565, 0.148 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.01, 0.009
#
# ... execution complete at Aug 08, 2024 09:49:04 UTC in 5.529 secs
#
# Sample Circuit:
#                ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q1499_0: ──────░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#          ┌───┐ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q1499_1: ┤ X ├─░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#          └───┘ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q1499_2: ──────░─┤2 qft ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#          ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q1499_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#          └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q1499_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#                ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#   c90: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                            0  1  2  3  4
#
# QFT Circuit =
#                ░                  ░                             ░            »
# q1500_0: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1500_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#                ░                  ░                       ┌───┐ ░      │     »
# q1500_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q1500_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q1500_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                     ░                                   »
# «q1500_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                               ┌───┐ ░      │           │          │     »
# «q1500_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «              │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q1500_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «         ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q1500_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «         └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q1500_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                     ░ └──────────┘                      »
# «                    ┌───┐ ░
# «q1500_0: ─────■─────┤ H ├─░─
# «         ┌────┴────┐└───┘ ░
# «q1500_1: ┤ Rz(π/2) ├──────░─
# «         └─────────┘      ░
# «q1500_2: ─────────────────░─
# «                          ░
# «q1500_3: ─────────────────░─
# «                          ░
# «q1500_4: ─────────────────░─
# «                          ░
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1501_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1501_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1501_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1501_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1501_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1501_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1501_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1501_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1501_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1501_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1501_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1501_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1501_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1501_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1501_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (2) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:49:05 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 9, 5
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.262, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.135, 0.002 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.853, 0.804
#
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.327, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.473, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.722, 0.683
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.36, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.561, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.583, 0.555
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 39, 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.382, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.001, 0.572, 0.003 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.437, 0.419
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 49, 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 24, 0.455
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 58, 0.395, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 0.578, 0.005 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.321, 0.31
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 60, 38
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 31, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 78, 0.412, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.002, 0.597, 0.018 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.227, 0.221
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 72, 47
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 39, 0.538
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.42, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.676, 0.017 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.159, 0.156
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 85, 57
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 48, 0.571
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.427, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.001, 0.653, 0.052 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.107, 0.105
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 58, 0.6
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 156, 0.433, 90.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.002, 0.412, 0.073 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.071, 0.07
#
# ... execution complete at Aug 08, 2024 09:49:10 UTC in 4.859 secs
#
# Sample Circuit:
#          ┌───┐┌─────────┐ ┌──────────┐┌─┐
# q2028_0: ┤ H ├┤ Rz(10π) ├─┤0         ├┤M├────────────
#          ├───┤└┬────────┤ │          │└╥┘┌─┐
# q2028_1: ┤ H ├─┤ Rz(5π) ├─┤1         ├─╫─┤M├─────────
#          ├───┤┌┴────────┴┐│          │ ║ └╥┘┌─┐
# q2028_2: ┤ H ├┤ Rz(5π/2) ├┤2 inv_qft ├─╫──╫─┤M├──────
#          ├───┤├──────────┤│          │ ║  ║ └╥┘┌─┐
# q2028_3: ┤ H ├┤ Rz(5π/4) ├┤3         ├─╫──╫──╫─┤M├───
#          ├───┤├──────────┤│          │ ║  ║  ║ └╥┘┌─┐
# q2028_4: ┤ H ├┤ Rz(5π/8) ├┤4         ├─╫──╫──╫──╫─┤M├
#          └───┘└──────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#  c117: 5/══════════════════════════════╩══╩══╩══╩══╩═
#                                        0  1  2  3  4
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q2029_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q2029_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q2029_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q2029_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q2029_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q2029_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q2029_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q2029_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q2029_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q2029_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q2029_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q2029_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q2029_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q2029_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q2029_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# INFO: Grover's Search benchmark is limited to a maximum of 8 qubits.
# ... execution starting at Aug 08, 2024 09:49:11 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 13, 0.116
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 13, 0.123, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 0.16, 0.002 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.681, 0.574
#
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 25, 0.083
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.303, 24.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.531, 0.003 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.458, 0.207
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 38, 0.072
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 167, 0.394, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 0.699, 0.005 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.207, 0.022
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 47, 0.064
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 604, 0.379, 288.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.003, 0.945, 0.018 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.045, 0.006
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 70, 0.056
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1877, 0.474, 1104.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.006, 2.013, 0.102 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.03, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 87, 0.048
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 5062, 0.484, 3008.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.006, 9.737, 0.854 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.023, 0.001
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 122, 0.045
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 15271, 0.492, 9120.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.013, 10.388, 6.431 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.005, 0.001
#
# ... execution complete at Aug 08, 2024 09:49:42 UTC in 31.119 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q2633_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2633_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2633_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2633_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2633_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#          └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#  c144: 5/══════════════════════════════════════════════════════════════»
#                                                                        »
# «         ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐
# «q2633_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├────────────
# «         │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐
# «q2633_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├─────────
# «         │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐
# «q2633_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├──────
# «         │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐
# «q2633_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├───
# «         │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘┌─┐
# «q2633_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─┤M├
# «         └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# « c144: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                                0  1  2  3  4
#
# Oracle =
#          ┌───┐                ░ ┌───┐
# q2640_0: ┤ X ├───────■────────░─┤ X ├
#          ├───┤       │        ░ ├───┤
# q2640_1: ┤ X ├───────■────────░─┤ X ├
#          └───┘       │        ░ └───┘
# q2640_2: ────────────■────────░──────
#                      │        ░
# q2640_3: ────────────■────────░──────
#          ┌───┐┌───┐┌─┴─┐┌───┐ ░ ┌───┐
# q2640_4: ┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├
#          └───┘└───┘└───┘└───┘ ░ └───┘
#
# Diffuser =
#          ┌───┐┌───┐                ░ ┌───┐┌───┐
# q2641_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2641_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2641_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2641_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q2641_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#          └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:49:43 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 14, 0.207, 4.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.002, 0.057, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.728, 0.637
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 30, 0.295, 11.333
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 0.346, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.549, 0.485
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 43, 0.324, 18.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.003, 0.611, 0.003 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.41, 0.371
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 59, 0.344, 27.333
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.005, 0.629, 0.004 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.291, 0.268
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 78, 0.408
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 82, 0.364, 40.667
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.004, 0.663, 0.017 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.199, 0.186
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 109, 0.378, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.005, 0.727, 0.012 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.114, 0.107
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 127, 0.426
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.388, 67.333
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.006, 0.774, 0.047 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.085, 0.081
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 156, 0.433
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 163, 0.398, 88.667
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.007, 0.453, 0.082 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.051, 0.049
#
# ... execution complete at Aug 08, 2024 09:49:48 UTC in 4.471 secs
#
# Sample Circuit:
#          ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q3207_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#          ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q3207_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#          ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q3207_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#          ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q3207_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#          ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q3207_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#          └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#  c161: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                 0  1  2  3
#
# Phase Operator 'U' =
#    ┌────────┐
# q: ┤ P(π/4) ├
#    └────────┘
#
# Inverse QFT Circuit =
#          ┌───┐                                     ░                  »
# q3214_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#          └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q3214_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#               └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q3214_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                           └──────────┘┌────┴─────┐ ░      └──────────┘»
# q3214_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                       └──────────┘ ░                  »
# «                      ░                   ░       ░
# «q3214_0: ─────────────░───────────────────░───────░─
# «                      ░                   ░       ░
# «q3214_1: ─────■───────░───────────────────░───────░─
# «              │       ░ ┌───┐             ░       ░
# «q3214_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «         ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q3214_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### HHL Linear Solver

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:49:49 UTC
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.002, 0.326, 0.055 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.907, 0.13
#
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.003, 0.689, 0.088 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.918, 0.182
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.004, 0.874, 0.128 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.908, 0.107
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 272, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.004, 0.941, 0.141 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.473, 0.045
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.052, 1.716, 0.368 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.446, 0.032
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 505, 0.334, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.186, 1.15, 0.508 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.225, 0.007
#
# ... execution complete at Aug 08, 2024 09:49:55 UTC in 6.314 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#  c177: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#  c178: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# « c177: 1/═════════════════════════════╩═
# «                                      0
# « c178: 1/═══════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q3743: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q3744: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q3745: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q3746: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q3743: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q3744: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q3745: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q3746: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q3743: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q3744: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q3745: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q3746: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q3743: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q3744: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q3745: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3746: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q3743: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q3744: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q3745: ─────────────────────────────────
# «
# «q3746: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q3751: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q3752: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#                └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q3753: ──────■──────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q3754: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#        └───┘             └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q3751: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q3752: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q3753: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q3754: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                 ┌───────────┐┌──────────┐┌───────────┐»
# «q3751: ┤ Rz(-3π/2) ├──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q3752: ────┤ X ├──────■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │           │      └───┘     └────────┘  └──────────┘»
# «q3753: ───────────────┼───■───────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(π) ┌─┴─┐                                      »
# «q3754: ─────────────┤ X ├─■─────┤ X ├──────────────────────────────────────»
# «                    └───┘       └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q3751: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q3752: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q3753: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3754: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q3751: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q3752: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q3753: ─────────────────────────────────
# «
# «q3754: ─────────────────────────────────
# «
#
# QFT Circuit =
#        ┌───┐ ░
# q3750: ┤ H ├─░─
#        └───┘ ░
#
# Inverse QFT Circuit =
#        ┌───┐ ░
# q3747: ┤ H ├─░─
#        └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q3748: ─────────────────■────────────────────■──
#        ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q3749: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#        └─────────────┘└───┘└──────────────┘└───┘

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# INFO: Amplitude Estimation benchmark is limited to a maximum of 8 qubits.
# ... execution starting at Aug 08, 2024 09:49:56 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.005, 0.141, 0.003 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.556, 0.113
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.006, 0.613, 0.004 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.432, 0.023
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.01, 1.237, 0.011 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.254, 0.015
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.043, 1.986, 0.05 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.121, 0.019
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.036, 5.236, 0.26 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.062, 0.004
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.13, 4.391, 1.709 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.031, 0.001
#
# ... execution complete at Aug 08, 2024 09:50:11 UTC in 14.981 secs
#
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q4981_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q4981_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q4981_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q4980_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q4980_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c220: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q4981_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q4981_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q4981_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q4980_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q4980_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# « c220: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q5348: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q4988_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q4988_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q4988_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling (2) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:50:13 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.007, 0.525, 0.009 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.486, 0.001
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.014, 1.355, 0.015 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.262, 0.017
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.019, 2.408, 0.05 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.129, 0.007
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2049, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2086, 0.382, 982.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.027, 5.923, 0.312 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.053, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4144, 0.403
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 4214, 0.382, 1984.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.176, 39.901, 1.736 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.03, 0.001
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 8322, 0.403
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 8457, 0.383, 3980.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.697, 89.471, 31.471 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.013, 0.001
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 16663, 0.403
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 16927, 0.383, 7962.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 11.262, 20.423, 9.04 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.008, 0.002
#
# ... execution complete at Aug 08, 2024 09:53:03 UTC in 170.144 secs
#
# Sample Circuit:
#          ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q5598_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q5598_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#          ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q5599_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q5599_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#          ├───┤ │      │└──────┘└──────┘                                 ░ »
# q5599_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#          └───┘ └──────┘                                                 ░ »
#  c235: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «                      ░
# «q5598_0: ─────────────░──────────
# «                      ░
# «q5598_1: ─────────────░──────────
# «         ┌──────────┐ ░ ┌─┐
# «q5599_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q5599_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q5599_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# « c235: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q6092: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#          ┌────┐┌────┐
# q6083_0: ┤0   ├┤0   ├
#          │  R ││  F │
# q6083_1: ┤1   ├┤1   ├
#          └────┘└────┘
#
# Distribution Generator 'R' =
#          ┌───┐
# q6084_0: ┤ H ├
#          └───┘
# q6084_1: ─────
#
#
# Function Generator 'F' =
#
# q6085_0: ──■──
#          ┌─┴─┐
# q6085_1: ┤ X ├
#          └───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q5605_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q5605_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q5605_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian Simulation Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:53:04 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 29, 0.243
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 29, 0.243, 9.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 0.17, 0.003 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.559, 0.393
#
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 44, 0.265
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 44, 0.265, 18.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.519, 0.002 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.349, 0.244
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 50, 0.276
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 44, 0.293, 27.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.002, 0.621, 0.003 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.279, 0.217
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 50, 0.279
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 44, 0.293, 36.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 0.649, 0.004 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.187, 0.147
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 50, 0.283
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 44, 0.306, 45.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.003, 0.671, 0.009 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.15, 0.126
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 50, 0.284
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 44, 0.303, 54.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.003, 0.697, 0.022 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.086, 0.071
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 50, 0.286
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 44, 0.312, 63.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.004, 0.716, 0.015 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.077, 0.069
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 50, 0.287
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 44, 0.309, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.004, 0.783, 0.052 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.048, 0.043
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 50, 0.288
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 44, 0.315, 81.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.006, 0.474, 0.088 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.032, 0.03
#
# ... execution complete at Aug 08, 2024 09:53:10 UTC in 5.545 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q6537_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#          └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q6537_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#          ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q6537_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q6537_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#          ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# q6537_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q6537_5: ──────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
#                ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
#  c265: 6/════════════════════════════════════════════════════════════»
#                                                                      »
# «                         ░ ┌───────────────┐ ┌──────────────┐ ░ »
# «q6537_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─»
# «         ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ »
# «q6537_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─»
# «         │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ »
# «q6537_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─»
# «         ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q6537_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─»
# «         │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q6537_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─»
# «         └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ »
# «q6537_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─»
# «                         ░  └──────────────┘└───────────────┘ ░ »
# « c265: 6/═══════════════════════════════════════════════════════»
# «                                                                »
# «         ┌─────────────┐                ░ ┌───────────────┐ ┌──────────────┐»
# «q6537_0: ┤0            ├────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├»
# «         │  xxyyzz_opt │┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤»
# «q6537_1: ┤1            ├┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤»
# «q6537_2: ┤0            ├┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├»
# «         │  xxyyzz_opt │├─────────────┤ ░  ├──────────────┤ ├──────────────┤»
# «q6537_3: ┤1            ├┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤»
# «q6537_4: ┤0            ├┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├»
# «         │  xxyyzz_opt │└─────────────┘ ░  ├──────────────┤┌┴──────────────┤»
# «q6537_5: ┤1            ├────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├»
# «         └─────────────┘                ░  └──────────────┘└───────────────┘»
# « c265: 6/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─────────────┐                ░ ┌─┐
# «q6537_0: ─░─┤0            ├────────────────░─┤M├───────────────
# «          ░ │  xxyyzz_opt │┌─────────────┐ ░ └╥┘┌─┐
# «q6537_1: ─░─┤1            ├┤0            ├─░──╫─┤M├────────────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q6537_2: ─░─┤0            ├┤1            ├─░──╫──╫─┤M├─────────
# «          ░ │  xxyyzz_opt │├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q6537_3: ─░─┤1            ├┤0            ├─░──╫──╫──╫─┤M├──────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q6537_4: ─░─┤0            ├┤1            ├─░──╫──╫──╫──╫─┤M├───
# «          ░ │  xxyyzz_opt │└─────────────┘ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q6537_5: ─░─┤1            ├────────────────░──╫──╫──╫──╫──╫─┤M├
# «          ░ └─────────────┘                ░  ║  ║  ║  ║  ║ └╥┘
# « c265: 6/═════════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                              0  1  2  3  4  5
#
# XXYYZZ_opt =
#                        ┌───┐┌─────────────┐                    ┌───┐»
# q7074_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#          ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q7074_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#          └────────────┘      └────────────┘└───┘└─────────────┘     »
# «         ┌─────────────┐
# «q7074_0: ┤ Rz(-1.5708) ├
# «         └─────────────┘
# «q7074_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Aug 08, 2024 09:53:11 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 76, 0.533, 56.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.05, 0.29, 0.011 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.394, 0.265
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 10, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 341, 0.63, 272.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.09, 2.418, 0.025 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.087, 0.023
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 26, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1543, 0.692, 1280.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.064, 49.625, 1.168 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.058, 0.003
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 50, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 3932, 0.733, 3360.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 1.269, 73.633, 44.14 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.03, 0.0
#
# ... execution complete at Aug 08, 2024 09:55:33 UTC in 141.933 secs
#
# Sample Circuit:
#          ┌─────┐┌────────────────────┐┌────────────────────┐»
# q7137_0: ┤0    ├┤0                   ├┤0                   ├»
#          │     ││                    ││                    │»
# q7137_1: ┤1    ├┤1                   ├┤1                   ├»
#          │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q7137_2: ┤2    ├┤2                   ├┤2                   ├»
#          │     ││                    ││                    │»
# q7137_3: ┤3    ├┤3                   ├┤3                   ├»
#          └─────┘└────────────────────┘└────────────────────┘»
#  meas: 4/═══════════════════════════════════════════════════»
#                                                             »
# «         ┌──────────────────────────┐ ░ ┌─┐
# «q7137_0: ┤0                         ├─░─┤M├─────────
# «         │                          │ ░ └╥┘┌─┐
# «q7137_1: ┤1                         ├─░──╫─┤M├──────
# «         │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q7137_2: ┤2                         ├─░──╫──╫─┤M├───
# «         │                          │ ░  ║  ║ └╥┘┌─┐
# «q7137_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «         └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# « meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                         0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (1) Benchmark - Qiskit
# ... execution starting at Aug 08, 2024 09:55:34 UTC
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 904, 0.536
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 2732, 0.425, 1644.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.251, 1.776, 1.284 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.116, 0.0
#
# ... execution complete at Aug 08, 2024 09:55:36 UTC in 2.52 secs
#
# Sample Circuit:
#          ┌───┐ ░                                ┌──────────┐ ░ ┌──────────┐┌─┐»
# q7435_0: ┤ H ├─░────────────────────────────────┤0         ├─░─┤0         ├┤M├»
#          ├───┤ ░                     ┌─────────┐│          │ ░ │          │└╥┘»
# q7435_1: ┤ H ├─░─────────────────────┤0        ├┤          ├─░─┤1         ├─╫─»
#          ├───┤ ░           ┌────────┐│         ││          │ ░ │  inv_qft │ ║ »
# q7435_2: ┤ H ├─░───────────┤0       ├┤         ├┤          ├─░─┤2         ├─╫─»
#          ├───┤ ░ ┌────────┐│        ││         ││          │ ░ │          │ ║ »
# q7435_3: ┤ H ├─░─┤0       ├┤        ├┤         ├┤          ├─░─┤3         ├─╫─»
#          ├───┤ ░ │        ││        ││         ││          │ ░ └──────────┘ ║ »
# q7436_0: ┤ X ├─░─┤1       ├┤1       ├┤1        ├┤1         ├─░──────────────╫─»
#          └───┘ ░ │        ││        ││         ││  C-U^256 │ ░              ║ »
# q7436_1: ──────░─┤2       ├┤2       ├┤2 C-U^16 ├┤2         ├─░──────────────╫─»
#                ░ │        ││  C-U^4 ││         ││          │ ░              ║ »
# q7437_0: ──────░─┤3 C-U^2 ├┤3       ├┤3        ├┤3         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q7437_1: ──────░─┤4       ├┤4       ├┤4        ├┤4         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q7437_2: ──────░─┤5       ├┤5       ├┤5        ├┤5         ├─░──────────────╫─»
#                ░ │        ││        ││         ││          │ ░              ║ »
# q7437_3: ──────░─┤6       ├┤6       ├┤6        ├┤6         ├─░──────────────╫─»
#                ░ └────────┘└────────┘└─────────┘└──────────┘ ░              ║ »
#  c278: 4/═══════════════════════════════════════════════════════════════════╩═»
#                                                                             0 »
# «
# «q7435_0: ─────────
# «         ┌─┐
# «q7435_1: ┤M├──────
# «         └╥┘┌─┐
# «q7435_2: ─╫─┤M├───
# «          ║ └╥┘┌─┐
# «q7435_3: ─╫──╫─┤M├
# «          ║  ║ └╥┘
# «q7436_0: ─╫──╫──╫─
# «          ║  ║  ║
# «q7436_1: ─╫──╫──╫─
# «          ║  ║  ║
# «q7437_0: ─╫──╫──╫─
# «          ║  ║  ║
# «q7437_1: ─╫──╫──╫─
# «          ║  ║  ║
# «q7437_2: ─╫──╫──╫─
# «          ║  ║  ║
# «q7437_3: ─╫──╫──╫─
# «          ║  ║  ║
# « c278: 4/═╩══╩══╩═
# «          1  2  3
#
# Controlled Ua Operator 'cUa' =
#          ┌─────────────┐      ┌─────────────────┐
#   q7642: ┤0            ├─■──■─┤0                ├
#          │             │ │  │ │                 │
# q7643_0: ┤1            ├─X──┼─┤1                ├
#          │             │ │  │ │                 │
# q7643_1: ┤2            ├─┼──X─┤2                ├
#          │             │ │  │ │                 │
# q7644_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#          │             │    │ │                 │
# q7644_1: ┤4            ├────X─┤4                ├
#          │             │      │                 │
# q7645_0: ┤5            ├──────┤5                ├
#          │             │      │                 │
# q7645_1: ┤6            ├──────┤6                ├
#          └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                  ┌─────────────┐┌─────────────┐
#   q7674: ────────┤0            ├┤0            ├────────────
#                  │             ││             │
# q7675_0: ────────┤1            ├┤             ├────────────
#                  │             ││             │
# q7675_1: ────────┤             ├┤1            ├────────────
#          ┌──────┐│             ││             │┌──────────┐
# q7676_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#          │      ││             ││             ││          │
# q7676_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#          │      ││             ││             ││          │
# q7676_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#          └──────┘│             ││             │└──────────┘
#   q7677: ────────┤5            ├┤5            ├────────────
#                  └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                              »
# q7690_0: ────■────────────────────────────────────────────────────────■──────»
#              │                                                        │      »
# q7690_1: ────■────────────────────────────────────────────────────────■──────»
#          ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q7691_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#          │       ││           ││          │     │      ││       ││          │»
# q7691_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#          │       ││           ││          │     │      ││       ││          │»
# q7691_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#          └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q7692: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                            └───┘                             »
# «
# «q7690_0: ───────────────────────────────────────■────
# «                                                │
# «q7690_1: ───────────────────────────────────────■────
# «         ┌──────────┐               ┌──────┐┌───┴───┐
# «q7691_0: ┤0         ├───────────────┤0     ├┤0      ├
# «         │          │               │      ││       │
# «q7691_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «         │          │┌───┐     ┌───┐│      ││       │
# «q7691_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «         └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q7692: ─────────────────┤ X ├──────────────────────
# «                          └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                ░                  ░                       ┌───┐ ░
# q7711_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q7711_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q7711_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (2) Benchmark - Qiskit
# ... execution starting at Aug 08, 2024 09:55:37 UTC
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 881, 0.527
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2752, 0.413, 1632.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.254, 5.305, 1.655 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.105, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 2720, 0.578
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 8368, 0.416, 5040.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 2.11, 6.125, 4.82 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.037, 0.006
#
# ... execution complete at Aug 08, 2024 09:55:48 UTC in 10.979 secs
#
# Sample Circuit:
#                ░  ┌───┐ ┌───┐┌──────────┐┌──────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
#   q7751: ──────░──┤ X ├─┤ H ├┤0         ├┤ P(0) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
#          ┌───┐ ░  └─╥─┘ └───┘│          │└──╥───┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# q7752_0: ┤ X ├─░────╫────────┤1         ├───╫──────────╫──╫──░────╫────────»
#          └───┘ ░    ║        │          │   ║          ║  ║  ░    ║        »
# q7752_1: ──────░────╫────────┤2         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q7753_0: ──────░────╫────────┤3 C-U^256 ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q7753_1: ──────░────╫────────┤4         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q7753_2: ──────░────╫────────┤5         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q7753_3: ──────░────╫────────┤6         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        └──────────┘┌──╨──┐       ║  ║  ░    ║        »
#  c279: 4/═══════════╬════════════════════╡ 0x0 ╞═══════╩══╬═══════╬════════»
#                  ┌──╨──┐                 └─────┘       0  ║    ┌──╨──┐     »
#  c280: 1/════════╡ 0x1 ╞══════════════════════════════════╩════╡ 0x1 ╞═════»
#                  └─────┘                                  0    └─────┘     »
# «         ┌─────────┐┌──────┐┌────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐┌────────┐»
# «  q7751: ┤0        ├┤ P(0) ├┤ P(π/2) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├┤0       ├»
# «         │         │└──╥───┘└───╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘│        │»
# «q7752_0: ┤1        ├───╫────────╫───────────╫──╫──░────╫────────┤1       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q7752_1: ┤2        ├───╫────────╫───────────╫──╫──░────╫────────┤2       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q7753_0: ┤3 C-U^16 ├───╫────────╫───────────╫──╫──░────╫────────┤3 C-U^4 ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q7753_1: ┤4        ├───╫────────╫───────────╫──╫──░────╫────────┤4       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q7753_2: ┤5        ├───╫────────╫───────────╫──╫──░────╫────────┤5       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q7753_3: ┤6        ├───╫────────╫───────────╫──╫──░────╫────────┤6       ├»
# «         └─────────┘┌──╨──┐  ┌──╨──┐        ║  ║  ░    ║        └────────┘»
# « c279: 4/═══════════╡ 0x0 ╞══╡ 0x1 ╞════════╩══╬═══════╬══════════════════»
# «                    └─────┘  └─────┘        1  ║    ┌──╨──┐               »
# « c280: 1/══════════════════════════════════════╩════╡ 0x1 ╞═══════════════»
# «                                               0    └─────┘               »
# «         ┌──────┐┌────────┐┌────────┐┌─────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
# «  q7751: ┤ P(0) ├┤ P(π/4) ├┤ P(π/2) ├┤ P(3π/4) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
# «         └──╥───┘└───╥────┘└───╥────┘└────╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# «q7752_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q7752_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q7753_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q7753_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q7753_2: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q7753_3: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐        ║  ║  ░    ║        »
# « c279: 4/╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞════════╩══╬═══════╬════════»
# «         └─────┘  └─────┘   └─────┘    └─────┘        2  ║    ┌──╨──┐     »
# « c280: 1/════════════════════════════════════════════════╩════╡ 0x1 ╞═════»
# «                                                         0    └─────┘     »
# «         ┌────────┐┌──────┐┌────────┐┌────────┐┌─────────┐┌────────┐»
# «  q7751: ┤0       ├┤ P(0) ├┤ P(π/8) ├┤ P(π/4) ├┤ P(3π/8) ├┤ P(π/2) ├»
# «         │        │└──╥───┘└───╥────┘└───╥────┘└────╥────┘└───╥────┘»
# «q7752_0: ┤1       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q7752_1: ┤2       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q7753_0: ┤3 C-U^2 ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q7753_1: ┤4       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q7753_2: ┤5       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q7753_3: ┤6       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         └────────┘┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐   ┌──╨──┐  »
# « c279: 4/══════════╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞═══╡ 0x4 ╞══»
# «                   └─────┘  └─────┘   └─────┘    └─────┘   └─────┘  »
# « c280: 1/═══════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌─────────┐┌─────────┐┌─────────┐┌───┐┌─┐┌─┐
# «  q7751: ┤ P(5π/8) ├┤ P(3π/4) ├┤ P(7π/8) ├┤ H ├┤M├┤M├
# «         └────╥────┘└────╥────┘└────╥────┘└───┘└╥┘└╥┘
# «q7752_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q7752_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q7753_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q7753_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q7753_2: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q7753_3: ─────╫──────────╫──────────╫───────────╫──╫─
# «           ┌──╨──┐    ┌──╨──┐    ┌──╨──┐        ║  ║
# « c279: 4/══╡ 0x5 ╞════╡ 0x6 ╞════╡ 0x7 ╞════════╩══╬═
# «           └─────┘    └─────┘    └─────┘        3  ║
# « c280: 1/══════════════════════════════════════════╩═
# «                                                   0
#
# Controlled Ua Operator 'cUa' =
#          ┌─────────────┐      ┌─────────────────┐
#   q7958: ┤0            ├─■──■─┤0                ├
#          │             │ │  │ │                 │
# q7959_0: ┤1            ├─X──┼─┤1                ├
#          │             │ │  │ │                 │
# q7959_1: ┤2            ├─┼──X─┤2                ├
#          │             │ │  │ │                 │
# q7960_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#          │             │    │ │                 │
# q7960_1: ┤4            ├────X─┤4                ├
#          │             │      │                 │
# q7961_0: ┤5            ├──────┤5                ├
#          │             │      │                 │
# q7961_1: ┤6            ├──────┤6                ├
#          └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                  ┌─────────────┐┌─────────────┐
#   q7990: ────────┤0            ├┤0            ├────────────
#                  │             ││             │
# q7991_0: ────────┤1            ├┤             ├────────────
#                  │             ││             │
# q7991_1: ────────┤             ├┤1            ├────────────
#          ┌──────┐│             ││             │┌──────────┐
# q7992_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#          │      ││             ││             ││          │
# q7992_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#          │      ││             ││             ││          │
# q7992_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#          └──────┘│             ││             │└──────────┘
#   q7993: ────────┤5            ├┤5            ├────────────
#                  └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                              »
# q8006_0: ────■────────────────────────────────────────────────────────■──────»
#              │                                                        │      »
# q8006_1: ────■────────────────────────────────────────────────────────■──────»
#          ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q8007_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#          │       ││           ││          │     │      ││       ││          │»
# q8007_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#          │       ││           ││          │     │      ││       ││          │»
# q8007_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#          └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q8008: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                            └───┘                             »
# «
# «q8006_0: ───────────────────────────────────────■────
# «                                                │
# «q8006_1: ───────────────────────────────────────■────
# «         ┌──────────┐               ┌──────┐┌───┴───┐
# «q8007_0: ┤0         ├───────────────┤0     ├┤0      ├
# «         │          │               │      ││       │
# «q8007_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «         │          │┌───┐     ┌───┐│      ││       │
# «q8007_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «         └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q8008: ─────────────────┤ X ├──────────────────────
# «                          └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                ░                  ░                       ┌───┐ ░
# q8026_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q8026_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q8026_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)

# %%
# ### Plot Metrics for a specific application

# metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Deutsch-Jozsa", apiname="Qiskit", filters=None, options=None, suffix="")
# # metrics.plot_metrics_for_app(backend_id = "qasm_simulator", appname = "Bernstein-Vazirani (1)", apiname="Qiskit", filters=None, options=None, suffix="")
