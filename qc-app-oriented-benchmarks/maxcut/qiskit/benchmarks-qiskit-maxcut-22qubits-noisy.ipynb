# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version - Max-Cut
# The notebook contains Max-Cut application-oriented benchmark for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one variation on the benchmark.

# %%
min_qubits=4
max_qubits=20
max_circuits=1
num_shots=1000

backend_id="qasm_simulator"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = {}

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples create a provider instance and get a backend from it

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import sys
# sys.path.insert(1, "../..")
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":'cpu' }

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# %%
# Custom optimization options can be specified in this cell (below is an example)

import sys
sys.path.insert(1, "../../")

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### Maxcut - Method 1

# %% [markdown]
# This method creates an ansatz circuit for the MaxCut problem at each width, executes it, and then compares its performance against a classically computed expectation for that size problem. Note that the computation of the expectation can be very slow for qubit widths larger than 16. The do_fidelites argument can be set to False to disable the computation, but this will result in all fidelities = 1.

# %%
import sys
sys.path.insert(1, "maxcut/qiskit")
import maxcut_benchmark

# set noise to None for testing
# import execute
# execute.set_noise_model(None)

maxcut_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=1, rounds=1, do_fidelities=True,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options
)
# Out:
# MaxCut (1) Benchmark Program - Qiskit
# ... execution starting at Oct 10, 2024 03:59:49 UTC
# ************
# Executing [1] circuits for num_qubits = 4
# ************
# Executing [1] circuits for num_qubits = 6
# ************
# Executing [1] circuits for num_qubits = 8
# ************
# Executing [1] circuits for num_qubits = 10
# ************
# Executing [1] circuits for num_qubits = 12
# ************
# Executing [1] circuits for num_qubits = 14
# ************
# Executing [1] circuits for num_qubits = 16
# ************
# Executing [1] circuits for num_qubits = 18
# ************
# Executing [1] circuits for num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 21, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 22, 0.4, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.262, 24.554, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.988, 0.973
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 18, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 19, 0.4, 18.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.007, 24.8, 0.004 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.959, 0.908
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 27, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 28, 0.4, 24.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.007, 25.047, 0.74 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.902, 0.66
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 21, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 22, 0.4, 30.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.015, 1.036, 0.031 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.659, 0.475
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 30, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 31, 0.4, 36.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.04, 2.393, 0.116 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.298, 0.209
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 33, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 34, 0.4, 42.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.18, 10.389, 0.426 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.1, 0.089
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 33, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 34, 0.4, 48.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.85, 10.019, 1.596 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.005, 0.005
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 30, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 31, 0.4, 54.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 4.069, 43.502, 8.229 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.005, 0.005
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 33, 0.462
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 34, 0.4, 60.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 18.509, 35.5, 34.906 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.005, 0.005
#
# ... execution complete at Oct 10, 2024 04:01:01 UTC in 72.146 secs
#
# Sample Circuit:
#         ┌───┐                                                               »
#    q_0: ┤ H ├─■────────■─────────────────■──────────────────────────────────»
#         ├───┤ │ZZ(-1)  │                 │                                  »
#    q_1: ┤ H ├─■────────┼────────■────────┼────────■─────────────────────────»
#         ├───┤          │        │ZZ(-1)  │        │                         »
#    q_2: ┤ H ├──────────┼────────■────────┼────────┼────────■────────■───────»
#         ├───┤          │                 │        │        │ZZ(-1)  │       »
#    q_3: ┤ H ├──────────┼─────────────────┼────────┼────────■────────┼───────»
#         ├───┤          │ZZ(-1)           │        │ZZ(-1)           │       »
#    q_4: ┤ H ├──────────■─────────────────┼────────■─────────────────┼───────»
#         ├───┤                            │ZZ(-1)                    │ZZ(-1) »
#    q_5: ┤ H ├────────────────────────────■──────────────────────────■───────»
#         └───┘                                                               »
# meas: 6/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                           ░ ┌───────┐ ░ ┌─┐
# «   q_0: ───────────────────░─┤ Rx(2) ├─░─┤M├───────────────
# «                           ░ ├───────┤ ░ └╥┘┌─┐
# «   q_1: ───────────────────░─┤ Rx(2) ├─░──╫─┤M├────────────
# «                           ░ ├───────┤ ░  ║ └╥┘┌─┐
# «   q_2: ───────────────────░─┤ Rx(2) ├─░──╫──╫─┤M├─────────
# «                           ░ ├───────┤ ░  ║  ║ └╥┘┌─┐
# «   q_3: ─■────────■────────░─┤ Rx(2) ├─░──╫──╫──╫─┤M├──────
# «         │ZZ(-1)  │        ░ ├───────┤ ░  ║  ║  ║ └╥┘┌─┐
# «   q_4: ─■────────┼────────░─┤ Rx(2) ├─░──╫──╫──╫──╫─┤M├───
# «                  │ZZ(-1)  ░ ├───────┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# «   q_5: ──────────■────────░─┤ Rx(2) ├─░──╫──╫──╫──╫──╫─┤M├
# «                           ░ └───────┘ ░  ║  ║  ║  ║  ║ └╥┘
# «meas: 6/══════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                          0  1  2  3  4  5

# %% [markdown]
# ### Maxcut - Method 2 - Degree 3 - Approximation Ratio as Objective Function

# %% [markdown]
# The method (2) cells execute the full QAOA algorithm, attempting to converge on best parameters to solve the problem.

# %%
import sys
sys.path.insert(1, "maxcut/qiskit")
import maxcut_benchmark

# # set noise to None for testing
# import execute
# execute.set_noise_model(None)

# execute and display options
objective_func_type = 'approx_ratio'
score_metric=['approx_ratio', 'cvar_ratio']
x_metric=['cumulative_elapsed_time', 'cumulative_exec_time', 'cumulative_opt_exec_time']

# Note: the plots produced by this benchmark only use the last of the problems at each width

maxcut_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2, rounds=2, degree=3, do_fidelities=False, parameterized=False, use_fixed_angles=False,
    score_metric=score_metric, x_metric=x_metric, save_res_to_file=True, comfort=True,
    objective_func_type = objective_func_type,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options
)
# Out:
# MaxCut (2) Benchmark Program - Qiskit
# ... execution starting at Oct 10, 2024 04:01:03 UTC
# ************
# Executing [1] restarts for num_qubits = 4
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 40, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 41, 0.462, 24.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.022, 0.002 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 6
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 34, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 35, 0.462, 36.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.031, 0.005 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 8
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 52, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 53, 0.462, 48.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.001, 0.039, 0.01 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 10
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 40, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 41, 0.462, 60.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.001, 0.093, 0.053 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 12
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 58, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 59, 0.462, 72.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.002, 0.232, 0.184 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 14
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 64, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 65, 0.462, 84.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.001, 0.835, 0.786 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 16
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 64, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 65, 0.462, 96.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.001, 2.703, 2.648 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 18
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 58, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 59, 0.462, 108.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.001, 11.353, 11.273 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] restarts for num_qubits = 20
#
# ..............................
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 64, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 65, 0.462, 120.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.001, 50.026, 49.94 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ... execution complete at Oct 10, 2024 04:33:28 UTC in 1945.74 secs
#
# Sample Circuit:
#         ┌───┐                                                            »
#    q_0: ┤ H ├─■──────────────■─────────────────────────────■─────────────»
#         ├───┤ │ZZ(-0.73509)  │                             │             »
#    q_1: ┤ H ├─■──────────────┼──────────────■──────────────┼─────────────»
#         ├───┤                │              │ZZ(-0.73509)  │             »
#    q_2: ┤ H ├────────────────┼──────────────■──────────────┼─────────────»
#         ├───┤                │                             │             »
#    q_3: ┤ H ├────────────────┼─────────────────────────────┼─────────────»
#         ├───┤                │ZZ(-0.73509)                 │             »
#    q_4: ┤ H ├────────────────■─────────────────────────────┼─────────────»
#         ├───┤                                              │ZZ(-0.73509) »
#    q_5: ┤ H ├──────────────────────────────────────────────■─────────────»
#         └───┘                                                            »
# meas: 6/═════════════════════════════════════════════════════════════════»
#                                                                          »
# «                                                                    »
# «   q_0: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «   q_1: ─■──────────────────────────────────────────────────────────»
# «         │                                                          »
# «   q_2: ─┼──────────────■──────────────■────────────────────────────»
# «         │              │ZZ(-0.73509)  │                            »
# «   q_3: ─┼──────────────■──────────────┼──────────────■─────────────»
# «         │ZZ(-0.73509)                 │              │ZZ(-0.73509) »
# «   q_4: ─■─────────────────────────────┼──────────────■─────────────»
# «                                       │ZZ(-0.73509)                »
# «   q_5: ───────────────────────────────■────────────────────────────»
# «                                                                    »
# «meas: 6/════════════════════════════════════════════════════════════»
# «                                                                    »
# «                        ░ ┌────────────┐                            »
# «   q_0: ────────────────░─┤ Rx(2.9073) ├─■─────────────■────────────»
# «                        ░ ├────────────┤ │ZZ(0.16032)  │            »
# «   q_1: ────────────────░─┤ Rx(2.9073) ├─■─────────────┼────────────»
# «                        ░ ├────────────┤               │            »
# «   q_2: ────────────────░─┤ Rx(2.9073) ├───────────────┼────────────»
# «                        ░ ├────────────┤               │            »
# «   q_3: ─■──────────────░─┤ Rx(2.9073) ├───────────────┼────────────»
# «         │              ░ ├────────────┤               │ZZ(0.16032) »
# «   q_4: ─┼──────────────░─┤ Rx(2.9073) ├───────────────■────────────»
# «         │ZZ(-0.73509)  ░ ├────────────┤                            »
# «   q_5: ─■──────────────░─┤ Rx(2.9073) ├────────────────────────────»
# «                        ░ └────────────┘                            »
# «meas: 6/════════════════════════════════════════════════════════════»
# «                                                                    »
# «                                                                              »
# «   q_0: ───────────────■──────────────────────────────────────────────────────»
# «                       │                                                      »
# «   q_1: ─■─────────────┼─────────────■────────────────────────────────────────»
# «         │ZZ(0.16032)  │             │                                        »
# «   q_2: ─■─────────────┼─────────────┼─────────────■─────────────■────────────»
# «                       │             │             │ZZ(0.16032)  │            »
# «   q_3: ───────────────┼─────────────┼─────────────■─────────────┼────────────»
# «                       │             │ZZ(0.16032)                │            »
# «   q_4: ───────────────┼─────────────■───────────────────────────┼────────────»
# «                       │ZZ(0.16032)                              │ZZ(0.16032) »
# «   q_5: ───────────────■─────────────────────────────────────────■────────────»
# «                                                                              »
# «meas: 6/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                     ░ ┌────────────┐ ░ ┌─┐
# «   q_0: ─────────────────────────────░─┤ Rx(3.9873) ├─░─┤M├───────────────
# «                                     ░ ├────────────┤ ░ └╥┘┌─┐
# «   q_1: ─────────────────────────────░─┤ Rx(3.9873) ├─░──╫─┤M├────────────
# «                                     ░ ├────────────┤ ░  ║ └╥┘┌─┐
# «   q_2: ─────────────────────────────░─┤ Rx(3.9873) ├─░──╫──╫─┤M├─────────
# «                                     ░ ├────────────┤ ░  ║  ║ └╥┘┌─┐
# «   q_3: ─■─────────────■─────────────░─┤ Rx(3.9873) ├─░──╫──╫──╫─┤M├──────
# «         │ZZ(0.16032)  │             ░ ├────────────┤ ░  ║  ║  ║ └╥┘┌─┐
# «   q_4: ─■─────────────┼─────────────░─┤ Rx(3.9873) ├─░──╫──╫──╫──╫─┤M├───
# «                       │ZZ(0.16032)  ░ ├────────────┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# «   q_5: ───────────────■─────────────░─┤ Rx(3.9873) ├─░──╫──╫──╫──╫──╫─┤M├
# «                                     ░ └────────────┘ ░  ║  ║  ║  ║  ║ └╥┘
# «meas: 6/═════════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                                         0  1  2  3  4  5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 16
#      12 x_metric=['cumulative_elapsed_time', 'cumulative_exec_time', 'cumulative_opt_exec_time']
#      14 # Note: the plots produced by this benchmark only use the last of the problems at each width
# ---> 16 maxcut_benchmark.run(
#      17     min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
#      18     method=2, rounds=2, degree=3, do_fidelities=False, parameterized=False, use_fixed_angles=False,
#      19     score_metric=score_metric, x_metric=x_metric, save_res_to_file=True, comfort=True,
#      20     objective_func_type = objective_func_type,
#      21     backend_id=backend_id, provider_backend=provider_backend,
#      22     hub=hub, group=group, project=project, exec_options=exec_options
#      23 )
#
# File ~/Girish/Quantum_Computing_Benchmarks-master/qc-app-oriented-benchmarks/maxcut/qiskit/maxcut_benchmark.py:1344, in run(min_qubits, max_qubits, skip_qubits, max_circuits, num_shots, method, rounds, degree, alpha, thetas_array, parameterized, do_fidelities, max_iter, score_metric, x_metric, y_metric, fixed_metrics, num_x_bins, y_size, x_size, use_fixed_angles, objective_func_type, plot_results, save_res_to_file, save_final_counts, detailed_save_names, comfort, backend_id, provider_backend, eta, hub, group, project, exec_options, context, _instances)
#    1341 elif method == 2:
#    1342     #metrics.print_all_circuit_metrics()
#    1343     if plot_results:
# -> 1344         plot_results_from_data(**dict_of_inputs)
#
# File ~/Girish/Quantum_Computing_Benchmarks-master/qc-app-oriented-benchmarks/maxcut/qiskit/maxcut_benchmark.py:1389, in plot_results_from_data(num_shots, rounds, degree, max_iter, max_circuits, objective_func_type, method, use_fixed_angles, score_metric, x_metric, y_metric, fixed_metrics, num_x_bins, y_size, x_size, x_min, x_max, offset_flag, detailed_save_names, **kwargs)
#    1386 list_of_widths = [all_widths[-1]]
#    1387 metrics.plot_cutsize_distribution(suptitle=suptitle,options=options, suffix=suffix, list_of_widths = list_of_widths)
# -> 1389 metrics.plot_angles_polar(suptitle = suptitle, options = options, suffix = suffix)
#
# File ~/Girish/Quantum_Computing_Benchmarks-master/qc-app-oriented-benchmarks/maxcut/qiskit/../../_common/metrics.py:2662, in plot_angles_polar(suptitle, options, suffix)
#    2659 rounds = len(angles_arr[0]) // 2
#    2661 fulltitle = get_full_title(suptitle=suptitle, options=options)
# -> 2662 cmap_beta = cm.get_cmap('autumn')
#    2663 cmap_gamma = cm.get_cmap('winter')
#    2664 colors = np.linspace(0.05,0.95, rounds)
#
# AttributeError: module 'matplotlib.cm' has no attribute 'get_cmap'

# %% [markdown]
# ### Load Data From File and Regenerate Plots
# This cell can be used to re-load the data stored during benchmark execution and plot the results.
#
# Be sure to first execute the initial cell which sets the backend_id

# %%
import os, maxcut_benchmark
backend_id = "qasm_simulator"
maxcut_benchmark.load_data_and_plot(os.path.join('__results', backend_id, 'approx_ratio'),
                score_metric=['approx_ratio', 'cvar_ratio'],
                x_metric=['cumulative_elapsed_time', 'cumulative_exec_time', 'cumulative_opt_exec_time'])

# %% [markdown]
# ### Maxcut - Method 2 - Degree 3 - CVaR Objective Function

# %%
import sys
sys.path.insert(1, "maxcut/qiskit")
import maxcut_benchmark

# set noise to None for testing
import execute
execute.set_noise_model(None)

objective_func_type = 'cvar_ratio'
score_metric=[objective_func_type]
x_metric=['cumulative_exec_time']

# Note: the plots produced by this benchmark only use the last of the problems at each width

maxcut_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2, rounds=2, degree=3, alpha = 0.1,
    objective_func_type = objective_func_type, do_fidelities = False,
    score_metric=score_metric, x_metric=x_metric, num_x_bins=15, max_iter=30,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options
)

# %% [markdown]
# ### Maxcut - Method 2 - Degree 3 - Gibbs Objective function

# %%
import sys
sys.path.insert(1, "maxcut/qiskit")
import maxcut_benchmark

# set noise to None for testing
import execute
execute.set_noise_model(None)

objective_func_type = 'gibbs_ratio'
score_metric=[objective_func_type] #, 'fidelity'
x_metric=['cumulative_exec_time'] #, , 'cumulative_create_time' 'cumulative_opt_exec_time'

# Note: the plots produced by this benchmark only use the last of the problems at each width

maxcut_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2, rounds=2, degree=3, eta=0.5,
    score_metric=score_metric, x_metric=x_metric, num_x_bins=15, max_iter=30,
    objective_func_type = objective_func_type, do_fidelities = False,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options
)

# %% [markdown]
# ### Maxcut - Method 2 - Degree -3

# %%
import sys
sys.path.insert(1, "maxcut/qiskit")
import maxcut_benchmark

# set noise to None for testing
import execute
execute.set_noise_model(None)

score_metric=['approx_ratio', 'fidelity']
x_metric=['cumulative_create_time', 'cumulative_exec_time', 'cumulative_opt_exec_time']

# Note: the plots produced by this benchmark only use the last of the problems at each width

maxcut_benchmark.run(
    min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
    method=2, rounds=1, degree=-3,
    score_metric=score_metric, x_metric=x_metric, num_x_bins=15, max_iter=30,
    backend_id=backend_id, provider_backend=provider_backend,
    hub=hub, group=group, project=project, exec_options=exec_options
)

# %% [markdown]
# ### Expected Measurement Distribution Example
#
# The next cell is an auto-generated circuit with beta and gamma set to the optimal parameters (in terms of pi)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

beta = 0.08
gamma = -0.094
cycle_time = 0

qr = QuantumRegister(4)
cr = ClassicalRegister(4)
qc = QuantumCircuit(qr, cr, name="main")
qc.h(qr[0])
qc.h(qr[1])
qc.h(qr[2])
qc.h(qr[3])
qc.cx(qr[0], qr[1])
qc.rz(2*3.14159*gamma, qr[1])
qc.cx(qr[0], qr[1])
qc.cx(qr[0], qr[3])
qc.rz(2*3.14159*gamma, qr[3])
qc.cx(qr[0], qr[3])
qc.cx(qr[0], qr[2])
qc.rz(2*3.14159*gamma, qr[2])
qc.cx(qr[0], qr[2])
qc.cx(qr[1], qr[2])
qc.rz(2*3.14159*gamma, qr[2])
qc.cx(qr[1], qr[2])
qc.cx(qr[1], qr[3])
qc.rz(2*3.14159*gamma, qr[3])
qc.cx(qr[1], qr[3])
qc.cx(qr[2], qr[3])
qc.rz(2*3.14159*gamma, qr[3])
qc.cx(qr[2], qr[3])
qc.rx(2*3.14159*beta, qr[0])
qc.rx(2*3.14159*beta, qr[1])
qc.rx(2*3.14159*beta, qr[2])
qc.rx(2*3.14159*beta, qr[3])
qc.measure(qr[0], cr[0])
qc.measure(qr[1], cr[1])
qc.measure(qr[2], cr[2])
qc.measure(qr[3], cr[3])

from qiskit import execute, Aer
backend = Aer.get_backend("qasm_simulator")  # Use Aer qasm_simulator

job = execute(qc, backend, shots=1000)
result = job.result()
counts = result.get_counts(qc)
print("Total counts are:", counts)

# Draw the circuit
print(qc)

# Plot a histogram
from qiskit.visualization import plot_histogram
plot_histogram(counts)
