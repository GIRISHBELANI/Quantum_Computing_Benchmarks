# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
pip install qiskit-ibmq-provider
# Out:
# Requirement already satisfied: qiskit-ibmq-provider in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (0.20.2)
# Requirement already satisfied: qiskit-terra>=0.18.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (0.45.1)
# Requirement already satisfied: requests>=2.19 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (2.31.0)
# Requirement already satisfied: requests-ntlm<=1.1.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.1.0)
# Requirement already satisfied: numpy<1.24 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.7.0)
# Requirement already satisfied: websockets>=10.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-ibmq-provider) (12.0)
# Requirement already satisfied: six>=1.5 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.13.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (3.11)
# Requirement already satisfied: psutil>=5 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.9.6)
# Requirement already satisfied: scipy>=1.5 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.12)
# Requirement already satisfied: dill>=0.3 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.1.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.11.0)
# Requirement already satisfied: typing-extensions in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (2023.11.17)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.3.0)
# Requirement already satisfied: pycparser in /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
min_qubits=4
max_qubits=17   # max_qubits=17 to execute upto 16 qubits for fake_guadalupe, if you take it 16 then max_clock_qubits=5, which is not sufficient for 15th qubits, as a result 15th qubit get skipped by use__best_width condition in run2
max_circuits=3
num_shots=1000

backend_id='fake_guadalupe'           # A fake 16 qubit backend.
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('MY_API_TOKEN')

from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account(token='9f77e2cae821d2b8fbb8aa9555078ce6ae3a9dd373c58b42cdf3faf267e64ae96bdbc3afcf9549fee34e78fb737b35410c1707d5cc0c582be44e8b36801d6dab', overwrite=True)


# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples create a provider instance and get a backend from it

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import sys
# sys.path.insert(1, "../..")
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":'cpu' }

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# Need this path set for imports used below
import sys
sys.path[1:1] = [ "../..", "../../_common" ]

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %%
import sys
sys.path.insert(1, "hhl/fake_backend")
import hhl_benchmark_fake_guadalupe

hhl_benchmark_fake_guadalupe.verbose=False
hhl_benchmark_fake_guadalupe.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# ... input, clock qubit width range: 1 : 5, 1 : 6
# HHL Benchmark Program - Qiskit
# ... execution starting at Jun 21, 2024 04:32:34 UTC
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 0.553, 0.142 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.951, 0.505
#
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.006, 0.781, 0.131 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.907, 0.076
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.011, 0.906, 0.156 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.885, 0.0
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 272, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.011, 1.043, 0.202 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.506, 0.506
#
# ************
# Executing 3 circuits with 9 qubits, using 2 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.013, 1.929, 0.354 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.466, 0.466
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 556, 0.335, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.018, 3.8, 0.913 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.502, 0.502
#
# ************
# Executing 3 circuits with 11 qubits, using 3 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 501, 0.336, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.022, 15.98, 1.664 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.231, 0.231
#
# ************
# Executing 3 circuits with 12 qubits, using 3 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 684, 0.337, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.048, 77.395, 8.305 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.242, 0.242
#
# ************
# Executing 3 circuits with 13 qubits, using 4 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 881, 0.341, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.031, 93.529, 48.981 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.25, 0.25
#
# ************
# Executing 3 circuits with 14 qubits, using 4 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 812, 0.338, 652.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.03, 123.882, 32.489 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.128, 0.128
#
# ************
# Executing 3 circuits with 15 qubits, using 4 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 1043, 0.341, 828.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 13.519, 310.139, 50.945 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.122, 0.122
#
# ************
# Executing 3 circuits with 16 qubits, using 5 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 21, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 1308, 0.344, 1024.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 17.265, 638.862, 184.823 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.118, 0.118
#
# ************
# Executing 3 circuits with 17 qubits, using 5 input qubits and 6 clock qubits
# ERROR: Failed to execute circuit 17 41278243816
# ... exception = 'Number of qubits (17) in hhl-17-9 is greater than maximum (16) in the coupling_map'
# ERROR: Failed to execute circuit 17 25389989169104
# ... exception = 'Number of qubits (17) in hhl-17-18 is greater than maximum (16) in the coupling_map'
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 1203, 0.341, 1012.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.07, 779.107, 373.108 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.076, 0.076
#
# ERROR: Failed to execute circuit 17 251832
# ... exception = 'Number of qubits (17) in hhl-17-5 is greater than maximum (16) in the coupling_map'
# ... execution complete at Jun 21, 2024 05:07:55 UTC in 2120.187 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#    c0: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#    c1: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# «   c0: 1/═════════════════════════════╩═
# «                                      0
# «   c1: 1/═══════════════════════════════
# «
#
# U Circuit =
#     ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q1: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#     └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q2: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#            └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q3: ──────■─────────────────────────────────────────────────────────────»
#     ┌───┐ │P(3π/2)   ┌───┐                                              »
# q4: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#     └───┘            └───┘                                              »
# «     ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# «q1: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «    ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───┬───┬───┘»
# «q2: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──────┤ X ├────»
# «    └───────────┘  └────────┘ └───┘└──────────┘└──────────┘         └───┘    »
# «q3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q4: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «                      ┌───────────┐┌──────────┐┌───────────┐               »
# «q1: ──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├────────────■──»
# «      │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤┌────────┐┌─┴─┐»
# «q2: ──■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├┤ Rz(-π) ├┤ X ├»
# «      │            │      └───┘     └────────┘  └──────────┘└────────┘└───┘»
# «q3: ──┼───■────────┼───────────────────────────────────────────────────────»
# «    ┌─┴─┐ │P(-π) ┌─┴─┐                                                     »
# «q4: ┤ X ├─■──────┤ X ├─────────────────────────────────────────────────────»
# «    └───┘        └───┘                                                     »
# «     ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# «q1: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «    ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───────────┘»
# «q2: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■───────────────»
# «    └───────────┘  └────────┘ └───┘└──────────┘└──────────┘                  »
# «q3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q4: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «    ┌───┐     ┌───┐
# «q1: ┤ X ├──■──┤ X ├
# «    └───┘┌─┴─┐└───┘
# «q2: ─────┤ X ├─────
# «         └───┘
# «q3: ───────────────
# «
# «q4: ───────────────
# «
#
# U^-1 Circuit =
#      ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
#  q9: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#      └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q10: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#              └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q11: ──────■──────────────────────────────────────────────────────────────»
#      ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q12: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#      └───┘             └───┘                                              »
# «      ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# « q9: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «     ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───┬───┬───┘»
# «q10: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──────┤ X ├────»
# «     └───────────┘  └────────┘ └───┘└──────────┘└──────────┘         └───┘    »
# «q11: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q12: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                      ┌───────────┐┌──────────┐┌───────────┐               »
# « q9: ──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├────────────■──»
# «       │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤┌────────┐┌─┴─┐»
# «q10: ──■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├┤ Rz(-π) ├┤ X ├»
# «       │           │      └───┘     └────────┘  └──────────┘└────────┘└───┘»
# «q11: ──┼───■───────┼───────────────────────────────────────────────────────»
# «     ┌─┴─┐ │P(π) ┌─┴─┐                                                     »
# «q12: ┤ X ├─■─────┤ X ├─────────────────────────────────────────────────────»
# «     └───┘       └───┘                                                     »
# «      ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# « q9: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «     ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───────────┘»
# «q10: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■───────────────»
# «     └───────────┘  └────────┘ └───┘└──────────┘└──────────┘                  »
# «q11: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q12: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «     ┌───┐     ┌───┐
# « q9: ┤ X ├──■──┤ X ├
# «     └───┘┌─┴─┐└───┘
# «q10: ─────┤ X ├─────
# «          └───┘
# «q11: ───────────────
# «
# «q12: ───────────────
# «
#
# QFT Circuit =
#     ┌───┐ ░
# q8: ┤ H ├─░─
#     └───┘ ░
#
# Inverse QFT Circuit =
#     ┌───┐ ░
# q5: ┤ H ├─░─
#     └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q6: ─────────────────■────────────────────■──
#     ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q7: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#     └─────────────┘└───┘└──────────────┘└───┘

# %%
import sys
sys.path.insert(1, "hhl/fake_backend")
import hhl_benchmark_fake_guadalupe

hhl_benchmark_fake_guadalupe.verbose=False

# This run2 method allows you to specify an arbitrary range of input and clock qubit sizes

min_input_qubits=1
max_input_qubits=5   # changed according to requirement (for run upto 16 qubits)
min_clock_qubits=2
max_clock_qubits=5   # changed according to requirement (for run upto 16 qubits)

hhl_benchmark_fake_guadalupe.run2(min_input_qubits=min_input_qubits, max_input_qubits=max_input_qubits,
                 min_clock_qubits=min_clock_qubits, max_clock_qubits=max_clock_qubits,
                 max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Jun 21, 2024 05:07:57 UTC
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.004, 0.691, 0.13 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.901, 0.153
#
# ************
# Executing 3 circuits with 7 qubits, using 1 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.009, 0.949, 0.175 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.895, 0.009
#
# ************
# Executing 3 circuits with 8 qubits, using 1 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 430, 0.33, 208.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.007, 1.234, 0.252 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.889, 0.016
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 565, 0.338, 276.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.016, 1.29, 0.368 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.891, 0.04
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 430, 0.33, 208.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.007, 1.234, 0.252 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.889, 0.016
#
# ************
# Executing 3 circuits with 9 qubits, using 2 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 565, 0.338, 276.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.016, 1.29, 0.368 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.891, 0.04
#
# ************
# Executing 3 circuits with 10 qubits, using 2 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 558, 0.335, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.048, 4.418, 0.964 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.44, 0.44
#
# ************
# Executing 3 circuits with 9 qubits, using 3 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 725, 0.34, 460.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.266, 4.919, 2.149 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.462, 0.462
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 558, 0.335, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.048, 4.418, 0.964 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.44, 0.44
#
# ************
# Executing 3 circuits with 11 qubits, using 3 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 725, 0.34, 460.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.266, 4.919, 2.149 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.462, 0.462
#
# ************
# Executing 3 circuits with 12 qubits, using 3 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 684, 0.337, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.546, 72.733, 15.776 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.236, 0.236
#
# ************
# Executing 3 circuits with 11 qubits, using 4 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 883, 0.341, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 1.46, 52.652, 31.6 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.207, 0.207
#
# ************
# Executing 3 circuits with 12 qubits, using 4 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 684, 0.337, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.546, 72.733, 15.776 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.236, 0.236
#
# ************
# Executing 3 circuits with 13 qubits, using 4 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 883, 0.341, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 1.46, 52.652, 31.6 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.207, 0.207
#
# ************
# Executing 3 circuits with 14 qubits, using 4 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 810, 0.338, 652.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 8.902, 168.339, 62.297 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.112, 0.112
#
# ************
# Executing 3 circuits with 13 qubits, using 5 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 1043, 0.34, 828.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 6.623, 195.96, 91.073 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.138, 0.138
#
# ************
# Executing 3 circuits with 14 qubits, using 5 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 810, 0.338, 652.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 8.902, 168.339, 62.297 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.112, 0.112
#
# ************
# Executing 3 circuits with 15 qubits, using 5 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 1043, 0.34, 828.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 6.623, 195.96, 91.073 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.138, 0.138
#
# ************
# Executing 3 circuits with 16 qubits, using 5 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 942, 0.339, 800.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 10.015, 739.184, 164.636 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.072, 0.072
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 1205, 0.34, 1012.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 54.742, 456.784, 347.06 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.067, 0.067
#
# ... execution complete at Jun 21, 2024 05:49:22 UTC in 2485.008 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐┌───────────┐ ░           ░                     »
#   input: ┤ X ├─░─┤0          ├┤0          ├─░───────────░─────────────────────»
#          └───┘ ░ │           ││           │ ░           ░                     »
#  in_anc: ──────░─┤1          ├┤1          ├─░───────────░─────────────────────»
#          ┌───┐ ░ │           ││           │ ░ ┌───────┐ ░      ┌──────────┐   »
# clock_0: ┤ H ├─░─┤2 e^{0iAt} ├┤  e^{1iAt} ├─░─┤0      ├─░──────┤0         ├───»
#          ├───┤ ░ │           ││           │ ░ │  IQFT │ ░      │          │   »
# clock_1: ┤ H ├─░─┤           ├┤2          ├─░─┤1      ├─░──────┤1 INV_ROT ├───»
#          └───┘ ░ │           ││           │ ░ └───────┘ ░      │          │┌─┐»
# ancilla: ──────░─┤3          ├┤3          ├─░───────────░──|0>─┤2         ├┤M├»
#                ░ └───────────┘└───────────┘ ░           ░      └──────────┘└╥┘»
#   c84: 1/═══════════════════════════════════════════════════════════════════╬═»
#                                                                             ║ »
#   c85: 1/═══════════════════════════════════════════════════════════════════╩═»
#                                                                             0 »
# «               ░          ░ ┌────────────┐┌────────────┐ ░       ░ ┌─┐
# «  input: ──────░──────────░─┤0           ├┤0           ├─░───────░─┤M├
# «               ░          ░ │            ││            │ ░       ░ └╥┘
# « in_anc: ──────░──────────░─┤1           ├┤1           ├─░───────░──╫─
# «               ░ ┌──────┐ ░ │            ││            │ ░ ┌───┐ ░  ║
# «clock_0: ──────░─┤0     ├─░─┤  e^{-1iAt} ├┤2 e^{-0iAt} ├─░─┤ H ├─░──╫─
# «               ░ │  QFT │ ░ │            ││            │ ░ ├───┤ ░  ║
# «clock_1: ──────░─┤1     ├─░─┤2           ├┤            ├─░─┤ H ├─░──╫─
# «               ░ └──────┘ ░ │            ││            │ ░ └───┘ ░  ║
# «ancilla: ─|0>──░──────────░─┤3           ├┤3           ├─░───────░──╫─
# «               ░          ░ └────────────┘└────────────┘ ░       ░  ║
# «  c84: 1/═══════════════════════════════════════════════════════════╩═
# «                                                                    0
# «  c85: 1/═════════════════════════════════════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q2566: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q2567: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q2568: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q2569: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q2566: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q2567: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q2568: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q2569: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q2566: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q2567: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q2568: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q2569: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q2566: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q2567: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q2568: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q2569: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q2566: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q2567: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q2568: ─────────────────────────────────
# «
# «q2569: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐           ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q2578: ┤ X ├────■──────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐  ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q2579: ───────┤ X ├──┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘  └────────┘ └──────────┘ └────────┘              └───┘»
# q2580: ──────■────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π)   ┌───┐                                              »
# q2581: ┤ X ├─■─────────┤ X ├──────────────────────────────────────────────»
#        └───┘           └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q2578: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q2579: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q2580: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q2581: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q2578: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q2579: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q2580: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(2π) ┌─┴─┐                                      »
# «q2581: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q2578: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q2579: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q2580: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q2581: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q2578: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q2579: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q2580: ─────────────────────────────────
# «
# «q2581: ─────────────────────────────────
# «
#
# QFT Circuit =
#          ┌───┐               ░
# q2577_0: ┤ H ├─■─────────────░─
#          └───┘ │P(π/2) ┌───┐ ░
# q2577_1: ──────■───────┤ H ├─░─
#                        └───┘ ░
#
# Inverse QFT Circuit =
#                         ┌───┐ ░
# q2574_0: ──────■────────┤ H ├─░─
#          ┌───┐ │P(-π/2) └───┘ ░
# q2574_1: ┤ H ├─■──────────────░─
#          └───┘                ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#                                                                       »
# q2575_0: ─────────────────────────────────────■───────────────────────»
#                                               │                       »
# q2575_1: ────────────────■────────────────────┼────────────────────■──»
#          ┌────────────┐┌─┴─┐┌──────────────┐┌─┴─┐┌──────────────┐┌─┴─┐»
#   q2576: ┤ Ry(1.3435) ├┤ X ├┤ Ry(-0.56718) ├┤ X ├┤ Ry(-0.75094) ├┤ X ├»
#          └────────────┘└───┘└──────────────┘└───┘└──────────────┘└───┘»
# «
# «q2575_0: ─────────────────■──
# «                          │
# «q2575_1: ─────────────────┼──
# «         ┌─────────────┐┌─┴─┐
# «  q2576: ┤ Ry(0.48002) ├┤ X ├
# «         └─────────────┘└───┘

# %%
from qiskit.visualization import plot_histogram

# Get the counts, the frequency of each answer
counts = hhl_benchmark_fake_guadalupe.saved_result.get_counts()

# Display the results
plot_histogram(counts)

# %%
hhl_benchmark_fake_guadalupe.QC_.draw('mpl',scale=1)
#print(circuit)
# Out:
# /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
