# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
#pip install qiskit-ibmq-provider

# %%
min_qubits=4
max_qubits=20
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = {}

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('MY_API_TOKEN')

from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account(token='9f77e2cae821d2b8fbb8aa9555078ce6ae3a9dd373c58b42cdf3faf267e64ae96bdbc3afcf9549fee34e78fb737b35410c1707d5cc0c582be44e8b36801d6dab', overwrite=True)


# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples create a provider instance and get a backend from it

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import sys
# sys.path.insert(1, "../..")
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":'cpu' }

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# Need this path set for imports used below
import sys
sys.path[1:1] = [ "../..", "../../_common" ]

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

# minimum number of qubits for input and clock registers
hhl_benchmark.min_register_qubits=1

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Oct 09, 2024 11:56:23 UTC
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 76, 0.252
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 0.392, 0.053 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.997, 0.972
#
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 148, 0.263
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.005, 0.805, 0.082 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.986, 0.86
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 225, 0.275
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.005, 0.916, 0.118 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.967, 0.666
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 153, 0.259
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 274, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.006, 0.974, 0.135 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.8, 0.637
#
# ************
# Executing 3 circuits with 9 qubits, using 2 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 233, 0.262
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 409, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.051, 1.253, 0.206 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.688, 0.433
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 322, 0.274
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 556, 0.335, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.008, 1.567, 0.303 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.674, 0.408
#
# ************
# Executing 3 circuits with 11 qubits, using 3 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 229, 0.268
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 501, 0.336, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.032, 2.44, 0.375 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.636, 0.53
#
# ************
# Executing 3 circuits with 12 qubits, using 3 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 332, 0.263
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 684, 0.336, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.141, 4.578, 0.941 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.225, 0.014
#
# ************
# Executing 3 circuits with 13 qubits, using 4 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 454, 0.269
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 885, 0.34, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.314, 7.695, 1.741 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.286, 0.086
#
# ************
# Executing 3 circuits with 14 qubits, using 4 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 359, 0.259
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 814, 0.337, 652.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.606, 14.947, 3.162 secs
# Average Transpiling, Validating, Running Times for group 13 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 0.163, 0.08
#
# ************
# Executing 3 circuits with 15 qubits, using 4 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 474, 0.268
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 1045, 0.34, 828.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.023, 23.081, 7.523 secs
# Average Transpiling, Validating, Running Times for group 14 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 0.05, 0.0
#
# ************
# Executing 3 circuits with 16 qubits, using 5 input qubits and 5 clock qubits
# /home/cdac/Girish/Quantum_Computing_Benchmarks-master/qc-app-oriented-benchmarks/hhl/qiskit/hhl_benchmark.py:813: RuntimeWarning: overflow encountered in long_scalars
#   s_int = 1000 * (i+1) + (2**off_diag_index)*(3**b)
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 622, 0.276
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 1312, 0.344, 1024.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.034, 23.68, 6.403 secs
# Average Transpiling, Validating, Running Times for group 15 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 0.209, 0.109
#
# ************
# Executing 3 circuits with 17 qubits, using 5 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 481, 0.262
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 1203, 0.34, 1012.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 2.107, 39.286, 9.303 secs
# Average Transpiling, Validating, Running Times for group 16 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 0.032, 0.002
#
# ************
# Executing 3 circuits with 18 qubits, using 5 input qubits and 7 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 638, 0.272
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 1502, 0.343, 1244.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 3.133, 83.695, 18.885 secs
# Average Transpiling, Validating, Running Times for group 17 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 0.025, 0.0
#
# ************
# Executing 3 circuits with 19 qubits, using 6 input qubits and 6 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 844, 0.28
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 1869, 0.348, 1512.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 6.311, 164.769, 43.497 secs
# Average Transpiling, Validating, Running Times for group 18 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 0.034, 0.0
#
# ************
# Executing 3 circuits with 20 qubits, using 6 input qubits and 7 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 654, 0.272
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 1694, 0.343, 1464.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.042, 338.725, 75.652 secs
# Average Transpiling, Validating, Running Times for group 19 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 0.041, 0.014
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 863, 0.276
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 2091, 0.347, 1768.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 25.31, 309.406, 184.665 secs
# Average Transpiling, Validating, Running Times for group 20 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 0.022, 0.001
#
# ... execution complete at Oct 09, 2024 12:14:25 UTC in 1082.175 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#  c138: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#  c139: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# « c138: 1/═════════════════════════════╩═
# «                                      0
# « c139: 1/═══════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q4873: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q4874: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q4875: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q4876: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q4873: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q4874: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q4875: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q4876: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q4873: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q4874: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q4875: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q4876: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q4873: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q4874: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q4875: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q4876: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q4873: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q4874: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q4875: ─────────────────────────────────
# «
# «q4876: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q4881: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q4882: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#                └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q4883: ──────■──────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q4884: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#        └───┘             └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q4881: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q4882: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q4883: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q4884: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                 ┌───────────┐┌──────────┐┌───────────┐»
# «q4881: ┤ Rz(-3π/2) ├──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q4882: ────┤ X ├──────■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │           │      └───┘     └────────┘  └──────────┘»
# «q4883: ───────────────┼───■───────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(π) ┌─┴─┐                                      »
# «q4884: ─────────────┤ X ├─■─────┤ X ├──────────────────────────────────────»
# «                    └───┘       └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q4881: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q4882: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q4883: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q4884: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q4881: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q4882: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q4883: ─────────────────────────────────
# «
# «q4884: ─────────────────────────────────
# «
#
# QFT Circuit =
#        ┌───┐ ░
# q4880: ┤ H ├─░─
#        └───┘ ░
#
# Inverse QFT Circuit =
#        ┌───┐ ░
# q4877: ┤ H ├─░─
#        └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q4878: ─────────────────■────────────────────■──
#        ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q4879: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#        └─────────────┘└───┘└──────────────┘└───┘

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

# This run2 method allows you to specify an arbitrary range of input and clock qubit sizes

min_input_qubits=1
max_input_qubits=3
min_clock_qubits=2
max_clock_qubits=3

hhl_benchmark.run2(min_input_qubits=min_input_qubits, max_input_qubits=max_input_qubits,
                 min_clock_qubits=min_clock_qubits, max_clock_qubits=max_clock_qubits,
                 max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Oct 08, 2024 09:11:12 UTC
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 148, 0.263
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.003, 0.58, 0.086 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.979, 0.792
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 225, 0.275
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.005, 0.861, 0.119 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.973, 0.734
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 156, 0.26
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 276, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.005, 1.029, 0.137 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.792, 0.622
#
# ************
# Executing 3 circuits with 9 qubits, using 3 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 237, 0.27
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.332, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.051, 1.28, 0.233 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.772, 0.586
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 156, 0.255
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 336, 0.333, 252.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.01, 1.852, 0.358 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.333, 0.154
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 237, 0.265
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 501, 0.336, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.01, 1.268, 0.523 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.336, 0.179
#
# ... execution complete at Oct 08, 2024 09:11:19 UTC in 7.558 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐┌───────────┐ ░           ░                     »
#   input: ┤ X ├─░─┤0          ├┤0          ├─░───────────░─────────────────────»
#          └───┘ ░ │           ││           │ ░           ░                     »
#  in_anc: ──────░─┤1          ├┤1          ├─░───────────░─────────────────────»
#          ┌───┐ ░ │           ││           │ ░ ┌───────┐ ░      ┌──────────┐   »
# clock_0: ┤ H ├─░─┤2 e^{0iAt} ├┤  e^{1iAt} ├─░─┤0      ├─░──────┤0         ├───»
#          ├───┤ ░ │           ││           │ ░ │  IQFT │ ░      │          │   »
# clock_1: ┤ H ├─░─┤           ├┤2          ├─░─┤1      ├─░──────┤1 INV_ROT ├───»
#          └───┘ ░ │           ││           │ ░ └───────┘ ░      │          │┌─┐»
# ancilla: ──────░─┤3          ├┤3          ├─░───────────░──|0>─┤2         ├┤M├»
#                ░ └───────────┘└───────────┘ ░           ░      └──────────┘└╥┘»
#  c102: 1/═══════════════════════════════════════════════════════════════════╬═»
#                                                                             ║ »
#  c103: 1/═══════════════════════════════════════════════════════════════════╩═»
#                                                                             0 »
# «               ░          ░ ┌────────────┐┌────────────┐ ░       ░ ┌─┐
# «  input: ──────░──────────░─┤0           ├┤0           ├─░───────░─┤M├
# «               ░          ░ │            ││            │ ░       ░ └╥┘
# « in_anc: ──────░──────────░─┤1           ├┤1           ├─░───────░──╫─
# «               ░ ┌──────┐ ░ │            ││            │ ░ ┌───┐ ░  ║
# «clock_0: ──────░─┤0     ├─░─┤  e^{-1iAt} ├┤2 e^{-0iAt} ├─░─┤ H ├─░──╫─
# «               ░ │  QFT │ ░ │            ││            │ ░ ├───┤ ░  ║
# «clock_1: ──────░─┤1     ├─░─┤2           ├┤            ├─░─┤ H ├─░──╫─
# «               ░ └──────┘ ░ │            ││            │ ░ └───┘ ░  ║
# «ancilla: ─|0>──░──────────░─┤3           ├┤3           ├─░───────░──╫─
# «               ░          ░ └────────────┘└────────────┘ ░       ░  ║
# « c102: 1/═══════════════════════════════════════════════════════════╩═
# «                                                                    0
# « c103: 1/═════════════════════════════════════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q3793: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q3794: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q3795: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q3796: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q3793: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q3794: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q3795: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q3796: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q3793: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q3794: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q3795: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q3796: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q3793: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q3794: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q3795: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3796: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q3793: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q3794: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q3795: ─────────────────────────────────
# «
# «q3796: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐           ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q3805: ┤ X ├────■──────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐  ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q3806: ───────┤ X ├──┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘  └────────┘ └──────────┘ └────────┘              └───┘»
# q3807: ──────■────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π)   ┌───┐                                              »
# q3808: ┤ X ├─■─────────┤ X ├──────────────────────────────────────────────»
#        └───┘           └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q3805: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q3806: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q3807: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q3808: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q3805: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q3806: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q3807: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(2π) ┌─┴─┐                                      »
# «q3808: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q3805: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q3806: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q3807: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3808: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q3805: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q3806: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q3807: ─────────────────────────────────
# «
# «q3808: ─────────────────────────────────
# «
#
# QFT Circuit =
#          ┌───┐               ░
# q3804_0: ┤ H ├─■─────────────░─
#          └───┘ │P(π/2) ┌───┐ ░
# q3804_1: ──────■───────┤ H ├─░─
#                        └───┘ ░
#
# Inverse QFT Circuit =
#                         ┌───┐ ░
# q3801_0: ──────■────────┤ H ├─░─
#          ┌───┐ │P(-π/2) └───┘ ░
# q3801_1: ┤ H ├─■──────────────░─
#          └───┘                ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#                                                                       »
# q3802_0: ─────────────────────────────────────■───────────────────────»
#                                               │                       »
# q3802_1: ────────────────■────────────────────┼────────────────────■──»
#          ┌────────────┐┌─┴─┐┌──────────────┐┌─┴─┐┌──────────────┐┌─┴─┐»
#   q3803: ┤ Ry(1.3435) ├┤ X ├┤ Ry(-0.56718) ├┤ X ├┤ Ry(-0.75094) ├┤ X ├»
#          └────────────┘└───┘└──────────────┘└───┘└──────────────┘└───┘»
# «
# «q3802_0: ─────────────────■──
# «                          │
# «q3802_1: ─────────────────┼──
# «         ┌─────────────┐┌─┴─┐
# «  q3803: ┤ Ry(0.48002) ├┤ X ├
# «         └─────────────┘└───┘

# %%
from qiskit.visualization import plot_histogram

# Get the counts, the frequency of each answer
counts = hhl_benchmark.saved_result.get_counts()

# Display the results
plot_histogram(counts)

# %%
hhl_benchmark.QC_.draw('mpl',scale=1)
#print(circuit)
# Out:
# /home/cdac/anaconda3/envs/qiskit/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
